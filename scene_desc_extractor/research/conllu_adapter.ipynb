# %%
import re

# %% [markdown]
# # Entity marks ##

# %% [markdown]
# For flat entities:
#
# I - Word is inside a phrase of type TYPE
# B - If two phrases of the same type immediately follow each other, the first word of the second phrase will have tag B-TYPE
# O - Word is not part of a phrase
# E - End ( E will not appear in a prefix-only partial match )
# S - Single

# %% [markdown]
# For nested entities:
#
# B - Begin: The first word of a multi-word entity.
# I - Inside: Any non-initial word of a multi-word entity. (M - middle)
# L - Last: The last word of a multi-word entity. (E - end)
# U - Unit: A single-word entity.
# O - Outside: A word that is not part of any entity. (S / Single)
#
# BILOU or IOBES

# %%
# Define BILOU tags
bilou_tags = ["B", "I", "L", "U", "O"]

# %% [markdown]
# ## Dependencies ##
#
# https://wiki.gucorpling.org/gum/dependencies
#
# List of dependency function labels used in GUM
#
#     acl
#     acl:relcl
#     advcl
#     advcl:relcl
#     advmod
#     amod
#     appos
#     aux
#     aux:pass
#     case
#     cc
#     cc:preconj
#     ccomp
#     compound
#     compound:prt
#     conj
#     cop
#     csubj
#     csubj:pass
#     dep
#     det
#     det:predet
#     discourse
#     dislocated
#     expl
#     fixed
#     flat
#     goeswith
#     iobj
#     list
#     mark
#     nmod
#     nmod:npmod
#     nmod:tmod
#     nmod:poss
#     nsubj
#     nsubj:pass
#     nummod
#     obj
#     obl
#     obl:agent
#     obl:npmod
#     obl:tmod
#     orphan
#     parataxis
#     punct
#     reparandum
#     root
#     vocative
#     xcomp

# %% [markdown]
# ## Entities types
#
# https://wiki.gucorpling.org/gum/entities
#
# There are 10 entity type:
#
#     person - any person, including fictitious figures, groups of people, and semi-human entities (Pinocchio)
#     place - a country (Iceland), region (Sahara)), or other place being referred to as a location (the factory - when used as a place, not to refer to the physical building)
#     organization - a company, government, sports team and others
#     object - a concrete tangible object
#     event - includes reference to nouns ('War', 'the performance') and clauses that are referred back to ('that John came')
#     time - dates, times of day, days, years...
#     substance - water, mercury, gas, poison ... includes context-dependent substances, such as Skittles or baking chocolate
#     animal - any animal, potentially including bacteria, aliens and others construed as animals
#     plant - interpreted broadly to include fruits, seeds and other living plant parts, but not substances (e.g. 'wood' is not classified as a plant)
#     abstract - abstract notions (luck), emotions (excitement) or intangible properties (predisposition)

# %% [markdown]
# ## Entity salience
#
# https://wiki.gucorpling.org/gum/entities
#
# An entity is considered salient if and only if it appears in the summary of a document
# Annotate the first mention of a salient entity as salient, there is no need to annotate subsequent mentions as salient
#
# In the header:
#
# meta::salientEntities = 1, 2, 36, 41, 42, 46, 76, 99

# %% [markdown]
# ## Coreference
#
# https://wiki.gucorpling.org/gum/entities

# %%
import scene_desc as sd

# %%
TEXT_MARKER = "# text = "
TEXT_MARKER_LEN = len(TEXT_MARKER)
ENTITY_START_MARKER = "Entity="
ENTITY_STOP_MARKER = "|"

entity_marker_len = len(ENTITY_START_MARKER)
        
def extract_entity_info(text: str) -> list[(str,str)]:
    entity_matches = []
    entity_start_mark_index = text.find(ENTITY_START_MARKER)
    if entity_start_mark_index != -1:
        entity_stop_mark_index = text.find(ENTITY_STOP_MARKER)                
        entity_tag = text[entity_start_mark_index + entity_marker_len:entity_stop_mark_index] if entity_start_mark_index != -1 else '_'
        entity_matches = re.findall(r'(\(\d+-\w+-\w+)(?=-|\:)|(\d*?\))', entity_tag) #parts[9])
    return entity_matches
    
def convert_conllu(file_path) -> (str, sd.SceneDesc):    
    scene_desc = sd.SceneDesc()
    
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()      
        
        text = ""
        word_info_list = []
        
        # Iterate through each line in the file
        for line in lines:
            # collect text
            if line.startswith(TEXT_MARKER):
                text += line[TEXT_MARKER_LEN:] + " "
                
            # collect line info
            if line[0].isdigit():
                parts = line.split("\t")
                lemma = sd.Lemma(sentence_id=0, lemma_id=parts[0], lemma=parts[1],lemma_init=parts[2],
                                 pos_tag=parts[3], dep_type=parts[7], dep_parent_id=parts[6])                
                entity_matches = extract_entity_info(text=parts[9])     
                
                #word_info_list.append((word_number, word, entity_match))
        return text.strip(), word_info_list

# %%
entity_tag = 'Entity=(4-place-giv:act-cf3-1-coref-Russia)14)'
re.findall(r'(\(\d+-\w+-\w+)(?=-|\:)|(\d*?\))', entity_tag)
# Out:
# [('(4-place-giv', ''), ('', ')'), ('', '14)')]

# %%
text, word_info_list = convert_conllu('../datasets/gum/dep/GUM_fiction_error.conllu')
for word_number, word, entity_tag in word_info_list:
    print(f"Word Number: {word_number}, Word: {word}, Entity Tag: {entity_tag}")
# Out:
# Word Number: 10, Word: When, Entity Tag: []
# Word Number: 10, Word: Tyler, Entity Tag: [('(1-person-new', ''), ('', ')')]
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: very, Entity Tag: []
# Word Number: 10, Word: young, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: []
# Word Number: 10, Word: grandmother, Entity Tag: [('', '2)')]
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(2-person-giv', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: favorite, Entity Tag: []
# Word Number: 10, Word: person, Entity Tag: [('', '2)')]
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(3-place-acc', '')]
# Word Number: 10, Word: world, Entity Tag: [('', '3)')]
# Word Number: 10, Word: because, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: unlike, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(4-person-new', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: parents, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: who, Entity Tag: []
# Word Number: 10, Word: believed, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: children, Entity Tag: [('(5-person-new', ''), ('', ')')]
# Word Number: 10, Word: should, Entity Tag: []
# Word Number: 10, Word: always, Entity Tag: []
# Word Number: 10, Word: be, Entity Tag: []
# Word Number: 10, Word: told, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(6-abstract-new', '')]
# Word Number: 10, Word: truth, Entity Tag: [('', '6)')]
# Word Number: 10, Word: as, Entity Tag: []
# Word Number: 10, Word: adults, Entity Tag: [('(7-person-new', ''), ('', ')')]
# Word Number: 10, Word: understood, Entity Tag: []
# Word Number: 10, Word: it, Entity Tag: [('(6-abstract-giv', ''), ('', ')'), ('', '4)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: she, Entity Tag: []
# Word Number: 10, Word: would, Entity Tag: []
# Word Number: 10, Word: fill, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(8-abstract-new', '')]
# Word Number: 10, Word: gaps, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(9-abstract-new', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: knowledge, Entity Tag: [('', '9)'), ('', '8)')]
# Word Number: 10, Word: —, Entity Tag: []
# Word Number: 10, Word: Santa, Entity Tag: []
# Word Number: 10, Word: Claus, Entity Tag: [('', '10)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: []
# Word Number: 10, Word: Easter, Entity Tag: []
# Word Number: 10, Word: Bunny, Entity Tag: [('', '11)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: God, Entity Tag: []
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: His, Entity Tag: []
# Word Number: 10, Word: parents, Entity Tag: [('', '4)')]
# Word Number: 10, Word: were, Entity Tag: []
# Word Number: 10, Word: always, Entity Tag: []
# Word Number: 10, Word: too, Entity Tag: []
# Word Number: 10, Word: busy, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: often, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: []
# Word Number: 10, Word: little, Entity Tag: []
# Word Number: 10, Word: too, Entity Tag: []
# Word Number: 10, Word: serious, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: but, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(2-person-giv', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: grandmother, Entity Tag: [('', '2)')]
# Word Number: 10, Word: had, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(13-abstract-new', '')]
# Word Number: 10, Word: sense, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: peace, Entity Tag: [('(14-abstract-new', ''), ('', ')'), ('', '13)')]
# Word Number: 10, Word: about, Entity Tag: []
# Word Number: 10, Word: her, Entity Tag: [('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(15-abstract-new', '')]
# Word Number: 10, Word: lightness, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: lifted, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(16-abstract-new', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: spirit, Entity Tag: [('', '16)'), ('', '15)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: A, Entity Tag: []
# Word Number: 10, Word: few, Entity Tag: []
# Word Number: 10, Word: times, Entity Tag: [('', '17)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: when, Entity Tag: []
# Word Number: 10, Word: Tyler’s, Entity Tag: []
# Word Number: 10, Word: Tyler, Entity Tag: [('(4-person-giv', ''), ('(1-person-giv', '')]
# Word Number: 10, Word: ’s, Entity Tag: [('', '1)')]
# Word Number: 10, Word: parents, Entity Tag: [('', '4)')]
# Word Number: 10, Word: were, Entity Tag: []
# Word Number: 10, Word: away, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: she, Entity Tag: []
# Word Number: 10, Word: took, Entity Tag: []
# Word Number: 10, Word: him, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: with, Entity Tag: []
# Word Number: 10, Word: her, Entity Tag: [('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: church, Entity Tag: [('(18-place-new', ''), ('', ')')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: He, Entity Tag: []
# Word Number: 10, Word: remembered, Entity Tag: []
# Word Number: 10, Word: liking, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: []
# Word Number: 10, Word: singing, Entity Tag: [('', '19)')]
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: []
# Word Number: 10, Word: colorful, Entity Tag: []
# Word Number: 10, Word: windows, Entity Tag: [('', '20)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: how, Entity Tag: []
# Word Number: 10, Word: safe, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: felt, Entity Tag: []
# Word Number: 10, Word: there, Entity Tag: [('(18-place-giv', ''), ('', ')')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: [('(18-place-giv', '')]
# Word Number: 10, Word: large, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: empty, Entity Tag: []
# Word Number: 10, Word: space, Entity Tag: [('', '18)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: sitting, Entity Tag: []
# Word Number: 10, Word: on, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(21-object-new', '')]
# Word Number: 10, Word: hard, Entity Tag: []
# Word Number: 10, Word: bench, Entity Tag: [('', '21)')]
# Word Number: 10, Word: next, Entity Tag: []
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: her, Entity Tag: [('(22-abstract-new', ''), ('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: warmth, Entity Tag: [('', '22)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: When, Entity Tag: []
# Word Number: 10, Word: she, Entity Tag: [('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: died, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: grief, Entity Tag: []
# Word Number: 10, Word: overwhelmed, Entity Tag: []
# Word Number: 10, Word: Tyler, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: But, Entity Tag: []
# Word Number: 10, Word: like, Entity Tag: []
# Word Number: 10, Word: most, Entity Tag: [('(24-person-new', '')]
# Word Number: 10, Word: adults, Entity Tag: [('', '24)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: when, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: grew, Entity Tag: []
# Word Number: 10, Word: older, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: []
# Word Number: 10, Word: could, Entity Tag: []
# Word Number: 10, Word: only, Entity Tag: []
# Word Number: 10, Word: recall, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(25-abstract-new', '')]
# Word Number: 10, Word: intensity, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: [('(26-abstract-new', '')]
# Word Number: 10, Word: love, Entity Tag: [('', '26)')]
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: childhood, Entity Tag: [('(27-time-new', ''), ('', ')'), ('', '25)')]
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: an, Entity Tag: [('(28-abstract-new', '')]
# Word Number: 10, Word: abstract, Entity Tag: []
# Word Number: 10, Word: way, Entity Tag: [('', '28)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: He, Entity Tag: []
# Word Number: 10, Word: made, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(29-abstract-new', '')]
# Word Number: 10, Word: common, Entity Tag: []
# Word Number: 10, Word: error, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: identifying, Entity Tag: []
# Word Number: 10, Word: maturity, Entity Tag: [('(30-abstract-new', ''), ('', ')')]
# Word Number: 10, Word: with, Entity Tag: []
# Word Number: 10, Word: worth, Entity Tag: [('(31-abstract-new', ''), ('', ')'), ('', '29)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: assumed, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(26-abstract-giv', '')]
# Word Number: 10, Word: love, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: []
# Word Number: 10, Word: had, Entity Tag: []
# Word Number: 10, Word: for, Entity Tag: []
# Word Number: 10, Word: her, Entity Tag: [('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: as, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(1-person-giv', '')]
# Word Number: 10, Word: young, Entity Tag: []
# Word Number: 10, Word: child, Entity Tag: [('', '1)'), ('', '26)')]
# Word Number: 10, Word: must, Entity Tag: []
# Word Number: 10, Word: have, Entity Tag: []
# Word Number: 10, Word: been, Entity Tag: []
# Word Number: 10, Word: lacking, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: strength, Entity Tag: [('(32-abstract-new', ''), ('', ')')]
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: depth, Entity Tag: [('(33-abstract-new', ''), ('', ')')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: For, Entity Tag: []
# Word Number: 10, Word: many, Entity Tag: [('(34-time-new', '')]
# Word Number: 10, Word: years, Entity Tag: []
# Word Number: 10, Word: after, Entity Tag: []
# Word Number: 10, Word: her, Entity Tag: [('(35-event-new', ''), ('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: death, Entity Tag: [('', '35)'), ('', '34)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: however, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: Tyler, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: tortured, Entity Tag: []
# Word Number: 10, Word: by, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(36-abstract-new', '')]
# Word Number: 10, Word: memory, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(37-event-new', '')]
# Word Number: 10, Word: certain, Entity Tag: []
# Word Number: 10, Word: visit, Entity Tag: []
# Word Number: 10, Word: from, Entity Tag: []
# Word Number: 10, Word: her, Entity Tag: [('(2-person-giv', ''), ('', ')'), ('', '37)'), ('', '36)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: He, Entity Tag: []
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: five, Entity Tag: [('(38-abstract-new', ''), ('', ')')]
# Word Number: 10, Word: or, Entity Tag: []
# Word Number: 10, Word: so, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: they, Entity Tag: [('(39-person-acc', ''), ('', ')')]
# Word Number: 10, Word: were, Entity Tag: []
# Word Number: 10, Word: playing, Entity Tag: []
# Word Number: 10, Word: some, Entity Tag: [('(40-abstract-new', '')]
# Word Number: 10, Word: board, Entity Tag: []
# Word Number: 10, Word: game, Entity Tag: [('', '40)')]
# Word Number: 10, Word: at, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(41-object-acc', '')]
# Word Number: 10, Word: kitchen, Entity Tag: [('(42-place-new', ''), ('', ')')]
# Word Number: 10, Word: table, Entity Tag: [('', '41)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: As, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: swung, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(43-object-new', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: legs, Entity Tag: [('', '43)')]
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(44-abstract-new', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: excitement, Entity Tag: [('', '44)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: []
# Word Number: 10, Word: kicked, Entity Tag: []
# Word Number: 10, Word: her, Entity Tag: [('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: repeatedly, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: []
# Word Number: 10, Word: shins, Entity Tag: [('', '45)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: She, Entity Tag: []
# Word Number: 10, Word: asked, Entity Tag: []
# Word Number: 10, Word: him, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: stop, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: refused, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: giggling, Entity Tag: []
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: When, Entity Tag: []
# Word Number: 10, Word: she, Entity Tag: [('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: finally, Entity Tag: []
# Word Number: 10, Word: frowned, Entity Tag: []
# Word Number: 10, Word: at, Entity Tag: []
# Word Number: 10, Word: him, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: threatened, Entity Tag: []
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: stop, Entity Tag: []
# Word Number: 10, Word: playing, Entity Tag: []
# Word Number: 10, Word: if, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: didn’t, Entity Tag: []
# Word Number: 10, Word: did, Entity Tag: []
# Word Number: 10, Word: n’t, Entity Tag: []
# Word Number: 10, Word: stop, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: []
# Word Number: 10, Word: told, Entity Tag: []
# Word Number: 10, Word: her, Entity Tag: [('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: go, Entity Tag: []
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: Hell, Entity Tag: [('(46-place-new', ''), ('', ')')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: In, Entity Tag: []
# Word Number: 10, Word: Tyler’s, Entity Tag: []
# Word Number: 10, Word: Tyler, Entity Tag: [('(47-abstract-new', ''), ('(1-person-giv', '')]
# Word Number: 10, Word: ’s, Entity Tag: [('', '1)')]
# Word Number: 10, Word: mind, Entity Tag: [('', '47)')]
# Word Number: 10, Word: he, Entity Tag: [('(1-person-acc', ''), ('', ')')]
# Word Number: 10, Word: could, Entity Tag: []
# Word Number: 10, Word: see, Entity Tag: []
# Word Number: 10, Word: her, Entity Tag: [('(48-object-new', ''), ('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: face, Entity Tag: [('', '48)')]
# Word Number: 10, Word: grow, Entity Tag: []
# Word Number: 10, Word: taut, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: lose, Entity Tag: []
# Word Number: 10, Word: color, Entity Tag: [('(49-abstract-new', ''), ('', ')')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: then, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: for, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(50-time-new', '')]
# Word Number: 10, Word: only, Entity Tag: []
# Word Number: 10, Word: time, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: []
# Word Number: 10, Word: could, Entity Tag: []
# Word Number: 10, Word: remember, Entity Tag: [('', '50)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: she, Entity Tag: []
# Word Number: 10, Word: began, Entity Tag: []
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: cry, Entity Tag: []
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: He, Entity Tag: []
# Word Number: 10, Word: also, Entity Tag: []
# Word Number: 10, Word: remembered, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(51-abstract-new', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: own, Entity Tag: []
# Word Number: 10, Word: utter, Entity Tag: []
# Word Number: 10, Word: confusion, Entity Tag: [('', '51)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: His, Entity Tag: []
# Word Number: 10, Word: parents, Entity Tag: [('', '4)')]
# Word Number: 10, Word: did, Entity Tag: []
# Word Number: 10, Word: not, Entity Tag: []
# Word Number: 10, Word: have, Entity Tag: []
# Word Number: 10, Word: much, Entity Tag: [('(52-abstract-new', '')]
# Word Number: 10, Word: use, Entity Tag: []
# Word Number: 10, Word: for, Entity Tag: []
# Word Number: 10, Word: religion, Entity Tag: [('(53-abstract-new', ''), ('', ')'), ('', '52)')]
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: so, Entity Tag: []
# Word Number: 10, Word: for, Entity Tag: []
# Word Number: 10, Word: him, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: Hell, Entity Tag: [('(54-abstract-new', ''), ('', ')')]
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(54-abstract-giv', '')]
# Word Number: 10, Word: word, Entity Tag: []
# Word Number: 10, Word: without, Entity Tag: []
# Word Number: 10, Word: much, Entity Tag: [('(55-abstract-new', '')]
# Word Number: 10, Word: mystery, Entity Tag: [('', '55)')]
# Word Number: 10, Word: or, Entity Tag: []
# Word Number: 10, Word: power, Entity Tag: [('(56-abstract-new', ''), ('', ')'), ('', '54)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: At, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: [('(57-time-acc', '')]
# Word Number: 10, Word: time, Entity Tag: [('', '57)')]
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: knew, Entity Tag: []
# Word Number: 10, Word: only, Entity Tag: []
# Word Number: 10, Word: vaguely, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: Hell, Entity Tag: [('(46-place-giv', ''), ('', ')')]
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(46-place-giv', '')]
# Word Number: 10, Word: place, Entity Tag: []
# Word Number: 10, Word: you, Entity Tag: []
# Word Number: 10, Word: did, Entity Tag: []
# Word Number: 10, Word: not, Entity Tag: []
# Word Number: 10, Word: want, Entity Tag: []
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: go, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: like, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(59-place-acc', '')]
# Word Number: 10, Word: dark, Entity Tag: []
# Word Number: 10, Word: basement, Entity Tag: [('', '59)')]
# Word Number: 10, Word: or, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(60-place-acc', '')]
# Word Number: 10, Word: even, Entity Tag: []
# Word Number: 10, Word: darker, Entity Tag: []
# Word Number: 10, Word: attic, Entity Tag: [('', '60)'), ('', '46)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: He, Entity Tag: []
# Word Number: 10, Word: remembered, Entity Tag: []
# Word Number: 10, Word: feeling, Entity Tag: []
# Word Number: 10, Word: resentful, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: she, Entity Tag: [('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: crying, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: did, Entity Tag: []
# Word Number: 10, Word: not, Entity Tag: []
# Word Number: 10, Word: even, Entity Tag: []
# Word Number: 10, Word: understand, Entity Tag: []
# Word Number: 10, Word: why, Entity Tag: []
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: Tyler, Entity Tag: []
# Word Number: 10, Word: felt, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(61-abstract-new', '')]
# Word Number: 10, Word: guilt, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: this, Entity Tag: [('(36-abstract-giv', '')]
# Word Number: 10, Word: memory, Entity Tag: [('', '36)'), ('', '61)')]
# Word Number: 10, Word: even, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(62-time-new', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: teenage, Entity Tag: []
# Word Number: 10, Word: years, Entity Tag: [('', '62)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: For, Entity Tag: []
# Word Number: 10, Word: him, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: it, Entity Tag: [('(36-abstract-giv', ''), ('', ')')]
# Word Number: 10, Word: summed, Entity Tag: []
# Word Number: 10, Word: up, Entity Tag: []
# Word Number: 10, Word: all, Entity Tag: [('(63-abstract-new', '')]
# Word Number: 10, Word: his, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: insecurities, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: fears, Entity Tag: []
# Word Number: 10, Word: about, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(64-abstract-new', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: own, Entity Tag: []
# Word Number: 10, Word: cruelty, Entity Tag: [('', '64)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: ignorance, Entity Tag: [('(65-abstract-new', ''), ('', ')')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(66-abstract-new', '')]
# Word Number: 10, Word: possibility, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: reality, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: not, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(67-person-new', '')]
# Word Number: 10, Word: good, Entity Tag: []
# Word Number: 10, Word: person, Entity Tag: [('', '67)'), ('', '66)'), ('', '63)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: The, Entity Tag: []
# Word Number: 10, Word: fact, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: had, Entity Tag: []
# Word Number: 10, Word: caused, Entity Tag: []
# Word Number: 10, Word: someone, Entity Tag: [('(2-person-giv', '')]
# Word Number: 10, Word: who, Entity Tag: []
# Word Number: 10, Word: loved, Entity Tag: []
# Word Number: 10, Word: him, Entity Tag: [('(1-person-giv', ''), ('', ')'), ('', '2)')]
# Word Number: 10, Word: such, Entity Tag: []
# Word Number: 10, Word: pain, Entity Tag: [('', '69)')]
# Word Number: 10, Word: with, Entity Tag: []
# Word Number: 10, Word: so, Entity Tag: [('(70-abstract-new', '')]
# Word Number: 10, Word: little, Entity Tag: []
# Word Number: 10, Word: effort, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: understanding, Entity Tag: [('', '70)'), ('', '68)')]
# Word Number: 10, Word: troubled, Entity Tag: []
# Word Number: 10, Word: him, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: deeply, Entity Tag: []
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: One, Entity Tag: []
# Word Number: 10, Word: day, Entity Tag: []
# Word Number: 10, Word: Tyler, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: looked, Entity Tag: []
# Word Number: 10, Word: through, Entity Tag: []
# Word Number: 10, Word: an, Entity Tag: [('(71-object-new', '')]
# Word Number: 10, Word: old, Entity Tag: []
# Word Number: 10, Word: family, Entity Tag: []
# Word Number: 10, Word: photo, Entity Tag: [('(73-object-new', ''), ('', ')')]
# Word Number: 10, Word: album, Entity Tag: [('', '71)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: it, Entity Tag: [('(71-object-giv', ''), ('', ')')]
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(74-object-new', '')]
# Word Number: 10, Word: picture, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(42-place-giv', '')]
# Word Number: 10, Word: kitchen, Entity Tag: [('', '42)')]
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(75-place-new', '')]
# Word Number: 10, Word: house, Entity Tag: []
# Word Number: 10, Word: they, Entity Tag: []
# Word Number: 10, Word: used, Entity Tag: []
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: live, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: [('', '75)'), ('', '74)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: He, Entity Tag: []
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: surprised, Entity Tag: []
# Word Number: 10, Word: to, Entity Tag: [('(76-event-new', '')]
# Word Number: 10, Word: discover, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(77-abstract-new', ''), ('(42-place-giv', '')]
# Word Number: 10, Word: small, Entity Tag: []
# Word Number: 10, Word: kitchen, Entity Tag: [('', '42)')]
# Word Number: 10, Word: contained, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(78-object-new', '')]
# Word Number: 10, Word: central, Entity Tag: []
# Word Number: 10, Word: island, Entity Tag: [('', '78)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: had, Entity Tag: []
# Word Number: 10, Word: no, Entity Tag: [('(79-place-new', '')]
# Word Number: 10, Word: space, Entity Tag: []
# Word Number: 10, Word: for, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(41-object-giv', '')]
# Word Number: 10, Word: table, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(80-abstract-new', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: memory, Entity Tag: [('', '80)'), ('', '41)'), ('', '79)')]
# Word Number: 10, Word: at, Entity Tag: []
# Word Number: 10, Word: all, Entity Tag: [('', '77)'), ('', '76)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: With, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(76-event-giv', '')]
# Word Number: 10, Word: discovery, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: [('(77-abstract-acc', '')]
# Word Number: 10, Word: single, Entity Tag: []
# Word Number: 10, Word: error, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(80-abstract-giv', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: memory, Entity Tag: [('', '80)'), ('', '77)'), ('', '76)')]
# Word Number: 10, Word: came, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(81-abstract-new', '')]
# Word Number: 10, Word: cascade, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: other, Entity Tag: [('(82-abstract-new', '')]
# Word Number: 10, Word: revelations, Entity Tag: [('', '82)'), ('', '81)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: Now, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: remembered, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: they, Entity Tag: [('(72-person-giv', ''), ('', ')')]
# Word Number: 10, Word: always, Entity Tag: []
# Word Number: 10, Word: ate, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: []
# Word Number: 10, Word: dining, Entity Tag: []
# Word Number: 10, Word: room, Entity Tag: [('', '83)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: when, Entity Tag: []
# Word Number: 10, Word: they, Entity Tag: [('(72-person-giv', ''), ('', ')')]
# Word Number: 10, Word: did, Entity Tag: []
# Word Number: 10, Word: play, Entity Tag: [('(84-event-new', '')]
# Word Number: 10, Word: board, Entity Tag: [('(85-abstract-new', '')]
# Word Number: 10, Word: games, Entity Tag: [('', '85)'), ('', '84)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: it, Entity Tag: []
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: always, Entity Tag: []
# Word Number: 10, Word: on, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(86-object-new', '')]
# Word Number: 10, Word: coffee, Entity Tag: []
# Word Number: 10, Word: table, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: []
# Word Number: 10, Word: living, Entity Tag: []
# Word Number: 10, Word: room, Entity Tag: [('', '87)'), ('', '86)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: The, Entity Tag: []
# Word Number: 10, Word: memory, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: had, Entity Tag: []
# Word Number: 10, Word: caused, Entity Tag: []
# Word Number: 10, Word: him, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: such, Entity Tag: [('(88-abstract-new', '')]
# Word Number: 10, Word: pain, Entity Tag: [('', '88)')]
# Word Number: 10, Word: over, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(34-time-giv', '')]
# Word Number: 10, Word: years, Entity Tag: [('', '34)'), ('', '36)')]
# Word Number: 10, Word: could, Entity Tag: []
# Word Number: 10, Word: not, Entity Tag: []
# Word Number: 10, Word: possibly, Entity Tag: []
# Word Number: 10, Word: have, Entity Tag: []
# Word Number: 10, Word: occurred, Entity Tag: []
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: Somehow, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: must, Entity Tag: []
# Word Number: 10, Word: have, Entity Tag: []
# Word Number: 10, Word: manufactured, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(36-abstract-giv', '')]
# Word Number: 10, Word: whole, Entity Tag: []
# Word Number: 10, Word: scene, Entity Tag: [('', '36)')]
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(89-abstract-new', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: imagination, Entity Tag: [('', '89)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: It, Entity Tag: []
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: not, Entity Tag: []
# Word Number: 10, Word: very, Entity Tag: []
# Word Number: 10, Word: hard, Entity Tag: []
# Word Number: 10, Word: to, Entity Tag: [('(90-abstract-acc', '')]
# Word Number: 10, Word: explain, Entity Tag: []
# Word Number: 10, Word: what, Entity Tag: []
# Word Number: 10, Word: really, Entity Tag: []
# Word Number: 10, Word: happened, Entity Tag: [('', '90)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: []
# Word Number: 10, Word: thought, Entity Tag: []
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: The, Entity Tag: []
# Word Number: 10, Word: death, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(2-person-giv', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: grandmother, Entity Tag: [('', '2)'), ('', '35)')]
# Word Number: 10, Word: had, Entity Tag: []
# Word Number: 10, Word: probably, Entity Tag: []
# Word Number: 10, Word: caused, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: him, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: feelings, Entity Tag: [('(91-abstract-new', '')]
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: abandonment, Entity Tag: [('(92-abstract-new', ''), ('', ')')]
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: guilt, Entity Tag: [('(93-abstract-new', ''), ('', ')'), ('', '91)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: In, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(94-abstract-new', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: confusion, Entity Tag: [('', '94)')]
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: had, Entity Tag: []
# Word Number: 10, Word: taken, Entity Tag: []
# Word Number: 10, Word: elements, Entity Tag: [('(95-abstract-new', ''), ('', ')')]
# Word Number: 10, Word: from, Entity Tag: []
# Word Number: 10, Word: storybooks, Entity Tag: [('(96-abstract-new', ''), ('', ')')]
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: imagined, Entity Tag: []
# Word Number: 10, Word: out, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: nothing, Entity Tag: []
# Word Number: 10, Word: this, Entity Tag: [('(36-abstract-giv', '')]
# Word Number: 10, Word: memory, Entity Tag: [('', '36)')]
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: punish, Entity Tag: []
# Word Number: 10, Word: himself, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: This, Entity Tag: []
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(36-abstract-giv', '')]
# Word Number: 10, Word: sort, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: fantasy, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: could, Entity Tag: []
# Word Number: 10, Word: have, Entity Tag: []
# Word Number: 10, Word: occurred, Entity Tag: []
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: any, Entity Tag: [('(97-person-new', '')]
# Word Number: 10, Word: young, Entity Tag: []
# Word Number: 10, Word: child, Entity Tag: []
# Word Number: 10, Word: who, Entity Tag: []
# Word Number: 10, Word: lost, Entity Tag: []
# Word Number: 10, Word: an, Entity Tag: [('(98-person-new', '')]
# Word Number: 10, Word: important, Entity Tag: []
# Word Number: 10, Word: relative, Entity Tag: [('', '98)'), ('', '97)'), ('', '36)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: With, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: [('(76-event-giv', '')]
# Word Number: 10, Word: realization, Entity Tag: [('', '76)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(99-abstract-new', '')]
# Word Number: 10, Word: image, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(2-person-giv', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: grandmother, Entity Tag: [('', '2)')]
# Word Number: 10, Word: crying, Entity Tag: []
# Word Number: 10, Word: faded, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(80-abstract-giv', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: memory, Entity Tag: [('', '80)')]
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: became, Entity Tag: []
# Word Number: 10, Word: less, Entity Tag: []
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: less, Entity Tag: []
# Word Number: 10, Word: believable, Entity Tag: []
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: Tyler, Entity Tag: []
# Word Number: 10, Word: thought, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: []
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: very, Entity Tag: []
# Word Number: 10, Word: lucky, Entity Tag: []
# Word Number: 10, Word: to, Entity Tag: [('(76-event-giv', '')]
# Word Number: 10, Word: have, Entity Tag: []
# Word Number: 10, Word: discovered, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(77-abstract-giv', '')]
# Word Number: 10, Word: single, Entity Tag: []
# Word Number: 10, Word: error, Entity Tag: []
# Word Number: 10, Word: in, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(99-abstract-giv', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: false, Entity Tag: []
# Word Number: 10, Word: memory, Entity Tag: [('', '99)'), ('', '77)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: which, Entity Tag: []
# Word Number: 10, Word: enabled, Entity Tag: []
# Word Number: 10, Word: him, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: reason, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: way, Entity Tag: []
# Word Number: 10, Word: into, Entity Tag: []
# Word Number: 10, Word: distinguishing, Entity Tag: []
# Word Number: 10, Word: between, Entity Tag: []
# Word Number: 10, Word: reality, Entity Tag: [('(100-abstract-new', ''), ('', ')')]
# Word Number: 10, Word: and, Entity Tag: []
# Word Number: 10, Word: fantasy, Entity Tag: [('(101-abstract-new', ''), ('', ')'), ('', '76)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: He, Entity Tag: []
# Word Number: 10, Word: felt, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: it, Entity Tag: [('(76-event-giv', ''), ('', ')')]
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(76-event-giv', '')]
# Word Number: 10, Word: coming, Entity Tag: []
# Word Number: 10, Word: -, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: -, Entity Tag: []
# Word Number: 10, Word: age, Entity Tag: []
# Word Number: 10, Word: moment, Entity Tag: [('', '76)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: Nonetheless, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: []
# Word Number: 10, Word: admitted, Entity Tag: []
# Word Number: 10, Word: to, Entity Tag: []
# Word Number: 10, Word: himself, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: he, Entity Tag: [('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: []
# Word Number: 10, Word: little, Entity Tag: []
# Word Number: 10, Word: sad, Entity Tag: []
# Word Number: 10, Word: also, Entity Tag: []
# Word Number: 10, Word: at, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(76-event-giv', '')]
# Word Number: 10, Word: discovery, Entity Tag: [('', '76)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: For, Entity Tag: []
# Word Number: 10, Word: however, Entity Tag: []
# Word Number: 10, Word: imaginary, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: [('(99-abstract-giv', '')]
# Word Number: 10, Word: memory, Entity Tag: [('', '99)')]
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: it, Entity Tag: []
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: also, Entity Tag: []
# Word Number: 10, Word: a, Entity Tag: [('(99-abstract-giv', '')]
# Word Number: 10, Word: part, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(26-abstract-giv', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: love, Entity Tag: []
# Word Number: 10, Word: for, Entity Tag: []
# Word Number: 10, Word: his, Entity Tag: [('(2-person-giv', ''), ('(1-person-giv', ''), ('', ')')]
# Word Number: 10, Word: grandmother, Entity Tag: [('', '2)'), ('', '26)'), ('', '99)')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: When, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: [('(99-abstract-giv', '')]
# Word Number: 10, Word: memory, Entity Tag: [('', '99)')]
# Word Number: 10, Word: lost, Entity Tag: []
# Word Number: 10, Word: its, Entity Tag: [('(102-abstract-new', ''), ('(99-abstract-giv', ''), ('', ')')]
# Word Number: 10, Word: compelling, Entity Tag: []
# Word Number: 10, Word: aura, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: truth, Entity Tag: [('(103-abstract-new', ''), ('', ')'), ('', '102)')]
# Word Number: 10, Word: ,, Entity Tag: []
# Word Number: 10, Word: it, Entity Tag: []
# Word Number: 10, Word: was, Entity Tag: []
# Word Number: 10, Word: like, Entity Tag: []
# Word Number: 10, Word: another, Entity Tag: []
# Word Number: 10, Word: part, Entity Tag: []
# Word Number: 10, Word: of, Entity Tag: []
# Word Number: 10, Word: her, Entity Tag: [('(2-person-giv', ''), ('', ')')]
# Word Number: 10, Word: died, Entity Tag: []
# Word Number: 10, Word: with, Entity Tag: []
# Word Number: 10, Word: it, Entity Tag: [('(99-abstract-giv', ''), ('', ')')]
# Word Number: 10, Word: ., Entity Tag: []
# Word Number: 10, Word: He, Entity Tag: []
# Word Number: 10, Word: had, Entity Tag: []
# Word Number: 10, Word: no, Entity Tag: [('(104-abstract-new', '')]
# Word Number: 10, Word: name, Entity Tag: []
# Word Number: 10, Word: for, Entity Tag: []
# Word Number: 10, Word: the, Entity Tag: [('(105-abstract-new', '')]
# Word Number: 10, Word: emptiness, Entity Tag: []
# Word Number: 10, Word: that, Entity Tag: []
# Word Number: 10, Word: remained, Entity Tag: [('', '105)'), ('', '104)')]
# Word Number: 10, Word: ., Entity Tag: []
