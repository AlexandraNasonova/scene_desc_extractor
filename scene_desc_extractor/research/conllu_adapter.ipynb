# %%
import re

# %% [markdown]
# # Entity marks ##

# %% [markdown]
# For flat entities:
#
# I - Word is inside a phrase of type TYPE
# B - If two phrases of the same type immediately follow each other, the first word of the second phrase will have tag B-TYPE
# O - Word is not part of a phrase
# E - End ( E will not appear in a prefix-only partial match )
# S - Single

# %% [markdown]
# For nested entities:
#
# B - Begin: The first word of a multi-word entity.
# I - Inside: Any non-initial word of a multi-word entity. (M - middle)
# L - Last: The last word of a multi-word entity. (E - end)
# U - Unit: A single-word entity.
# O - Outside: A word that is not part of any entity. (S / Single)
#
# BILOU or IOBES

# %%
# Define BILOU tags
bilou_tags = ["B", "I", "L", "U", "O"]
START_SENTENCE_TOKEN = '[CLS]'
SEP_SENTENCE_TOKEN = '[SEP]'

# %% [markdown]
# ## Dependencies ##
#
# https://wiki.gucorpling.org/gum/dependencies
#
# List of dependency function labels used in GUM
#
#     acl
#     acl:relcl
#     advcl
#     advcl:relcl
#     advmod
#     amod
#     appos
#     aux
#     aux:pass
#     case
#     cc
#     cc:preconj
#     ccomp
#     compound
#     compound:prt
#     conj
#     cop
#     csubj
#     csubj:pass
#     dep
#     det
#     det:predet
#     discourse
#     dislocated
#     expl
#     fixed
#     flat
#     goeswith
#     iobj
#     list
#     mark
#     nmod
#     nmod:npmod
#     nmod:tmod
#     nmod:poss
#     nsubj
#     nsubj:pass
#     nummod
#     obj
#     obl
#     obl:agent
#     obl:npmod
#     obl:tmod
#     orphan
#     parataxis
#     punct
#     reparandum
#     root
#     vocative
#     xcomp

# %% [markdown]
# ## Entities types
#
# https://wiki.gucorpling.org/gum/entities
#
# There are 10 entity type:
#
#     person - any person, including fictitious figures, groups of people, and semi-human entities (Pinocchio)
#     place - a country (Iceland), region (Sahara)), or other place being referred to as a location (the factory - when used as a place, not to refer to the physical building)
#     organization - a company, government, sports team and others
#     object - a concrete tangible object
#     event - includes reference to nouns ('War', 'the performance') and clauses that are referred back to ('that John came')
#     time - dates, times of day, days, years...
#     substance - water, mercury, gas, poison ... includes context-dependent substances, such as Skittles or baking chocolate
#     animal - any animal, potentially including bacteria, aliens and others construed as animals
#     plant - interpreted broadly to include fruits, seeds and other living plant parts, but not substances (e.g. 'wood' is not classified as a plant)
#     abstract - abstract notions (luck), emotions (excitement) or intangible properties (predisposition)

# %% [markdown]
# ## Entity salience
#
# https://wiki.gucorpling.org/gum/entities
#
# An entity is considered salient if and only if it appears in the summary of a document
# Annotate the first mention of a salient entity as salient, there is no need to annotate subsequent mentions as salient
#
# In the header:
#
# meta::salientEntities = 1, 2, 36, 41, 42, 46, 76, 99

# %% [markdown]
# ## Coreference
#
# https://wiki.gucorpling.org/gum/entities

# %%
import scene_desc as sd
import conllu_converter
import re

# %%
TEXT_MARKER = "# text = "
SENTENCE_ID_MARKER = "# sent_id = "
TEXT_MARKER_LEN = len(TEXT_MARKER)
ENTITY_START_MARKER = "Entity="
ENTITY_STOP_MARKER = "|"

entity_marker_len = len(ENTITY_START_MARKER)
max_level = 5

def extract_entity_info(text: str) -> (str, list[(str,str)]):
    entity_start_mark_index = text.find(ENTITY_START_MARKER)
    if entity_start_mark_index == -1:
        return '_', []
    
    entity_stop_mark_index = text.find(ENTITY_STOP_MARKER)          
    if entity_stop_mark_index > entity_start_mark_index:
         entity_tag = text[entity_start_mark_index + entity_marker_len:entity_stop_mark_index]
    else:
        entity_tag = text[entity_start_mark_index + entity_marker_len:]
    entity_matches = re.findall(r'(\(\d+-\w+)(?=-|\:)|(\d*?\))', entity_tag)
    
    return entity_tag, entity_matches


def append_still_open_entities_to_result(word_id: int, open_entities: list[sd.Entity], 
                            result_entities = list[sd.Entity]):    
    for entity in open_entities:
        if entity.word_id == word_id:
                continue            
        entity = sd.Entity(word_id=word_id,coref_id=entity.coref_id, bilou_tag='I', level=entity.level)
        result_entities.insert(entity.level, entity)

    
def convert_entity_matches(word_id: int,
                           entity_matches: list[(str,str)],
                           coref_entities: dict[int, str],
                           open_entities: list[sd.Entity]) -> list[sd.Entity]:
    
    result_entities = []
    # if no openings or closings or already opened entities return tag O (Outside)
    if len(entity_matches) == 0 and len(open_entities) == 0:
            return [sd.Entity(word_id=word_id, coref_id=0, bilou_tag='O', level=0)]
    
    #if there are some openings or closings for entities
    for match in entity_matches:
        entity_start, entity_end = match[0], match[1]
        
        # for an opening
        if entity_start != '':
            spl = entity_start[1:].split('-')
            (coref_id, entity_type) = int(spl[0]), spl[1]            
            #get new level
            level = 0 if len(open_entities) == 0 else open_entities[-1].level + 1            
            # all levels deeper than max_level should be ignored 
            if level <= max_level:               
                # if opening is newly mentioned, update coreference dictionary
                if coref_id not in coref_entities:
                    coref_entities[coref_id] = entity_type                
                #create a new entity with B - Begin BILOU tag as default
                entity = sd.Entity(word_id=word_id, coref_id=coref_id, bilou_tag='B', level=level)
                open_entities.append(entity)
                result_entities.append(entity)
                
        # for a closing            
        elif len(open_entities) > 0:
            spl = entity_end[:-1]
            # if not links to coref_if then the last opening should be tagged U (Unique) if its level is not ignored
            if spl == '':
                if len(result_entities) > 0:
                    result_entities[-1].bilou_tag = 'U'
                    open_entities.pop()
            
            # if there is the link to coref_if, then tag L (Last) should be used
            else:
                coref_id = int(spl)        
                open_entity_index = -100
                for i, o in enumerate(open_entities):
                    if o.coref_id == coref_id:
                        open_entity_index = i
                        break
                if open_entity_index >= 0:
                    entity = sd.Entity(word_id=word_id, coref_id=coref_id, bilou_tag='L', 
                              level=open_entities[open_entity_index].level)
                    result_entities.insert(open_entities[open_entity_index].level, entity)
                    open_entities.pop(open_entity_index)

    #update already opened entities with nested info
    append_still_open_entities_to_result(word_id=word_id, open_entities=open_entities, 
                                        result_entities=result_entities)
    return  result_entities 
            
        
    
def convert_from_conllu_file(file_path):      
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()      
        
        text = sd.Text(text_full="", sentences=[], coref_entities={})
        open_entities = []   
        sentence_text = ''  
        sentence = None
        # Iterate through each line in the file
        for line in lines:
            # collect text
            if line.startswith(TEXT_MARKER):
                sentence_text = line[TEXT_MARKER_LEN:-1]
                text.text_full += sentence_text + " "
            
            # init new sentence
            if line.startswith(SENTENCE_ID_MARKER):
                if sentence is not None:
                    text.sentences.append(sentence)
                sentence_id = int(line[(line.rfind('-') + 1):])
                sentence = sd.Sentence(sentence_id = sentence_id, sentence_text = sentence_text,
                                       words=[])
                
            # collect line info for words and punctuation
            if line[0].isdigit():                
                parts = line.split("\t")
                word_id=parts[0]
                entity_tag, entity_matches = extract_entity_info(text=parts[9])
                # get BILOU entities for each words 
                entities = convert_entity_matches(word_id=word_id, 
                                                  entity_matches=entity_matches, 
                                                  coref_entities=text.coref_entities, 
                                                  open_entities=open_entities)
                # collect word info
                word = sd.Word(word_id=word_id, word=parts[1], lemma_init=parts[2],
                                pos_tag=parts[3], dep_type=parts[7], dep_parent_id=parts[6],
                                entities=entities)           
                
                print(f'{sentence_id}_{word_id}\t{parts[1]}\t{entity_tag}\n'
                      f'\t\t[{" | ".join("(" + str(e) + ")" for e in entities)}]\n'
                      f'\t\t[{" | ".join("(" + str(e) + ")" for e in open_entities)}]'
                      )
                
                #append word to current sentence
                sentence.words.append(word)
        
        if sentence is not None:
            text.sentences.append(sentence)
        text.text_full = text.text_full.strip()
        return text

# %%
def text_to_labels(text: sd.Text, cls_tag='[CLS]', sep_tag='[SEP]'):
    lines = []
    
    for sentence in text.sentences:
        sentence_id = sentence.sentence_id
        
        #append [CLS] Tag
        if cls_tag is not None and cls_tag != '':
            line = sd.LabelLine(sentence_id=sentence_id,
                                      word=sd.Word(word_id=0, word='[CLS]',
                                                   lemma_init='[CLS]', pos_tag='_', 
                                                   dep_type='_', dep_parent_id=-1, 
                                                   entities=None),
                                      max_level=max_level)
            lines.append(str(line))
        
        #append words lines        
        for word in sentence.words:
            line = sd.LabelLine(sentence_id=sentence_id, word=word, max_level=max_level)            
            for entity in word.entities:
                if entity.bilou_tag == 'O':
                    line.entities.append((-1, 'O'))
                else:
                    bilou_tag = entity.bilou_tag + '-' + text.coref_entities[entity.coref_id]
                    line.entities.append((entity.coref_id, bilou_tag))               
            lines.append(str(line))
            
        #append [CLS] Tag
        if sep_tag is not None and sep_tag != '':
            line = sd.LabelLine(sentence_id=sentence_id,
                                      word=sd.Word(word_id=len(sentence.words) + 1, 
                                                   word='[SEP]',
                                                   lemma_init='[SEP]', pos_tag='_', 
                                                   dep_type='_', dep_parent_id=-1, 
                                                   entities=None),
                                      max_level=max_level) 
            lines.append(str(line))
        
    return '\n'.join(lines)

# %%
entity_tag = 'Entity=(6-abstract-giv:act-cf2-1-ana)4)'
re.findall(r'(\(\d+-\w+)(?=-|\:)|(\d*?\))', entity_tag)
# Out:
# [('(6-abstract', ''), ('', ')'), ('', '4)')]

# %%
text = convert_from_conllu_file('../datasets/gum/dep/GUM_fiction_error.conllu')
# Out:
# 1_1	When	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_2	Tyler	(1-person-new-cf3-1-coref)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 1_3	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_4	very	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_5	young	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_6	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_7	his	(2-person-new-cf1-2-coref(1-person-giv:act-cf3-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 2, bilou_tag: B)]
# 1_8	grandmother	2)
# 		[(level: 0, coref_id: 2, bilou_tag: L)]
# 		[]
# 1_9	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_10	his	(2-person-giv:act-cf1-3-coref(1-person-giv:act-cf3-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 2, bilou_tag: B)]
# 1_11	favorite	_
# 		[(level: 0, coref_id: 2, bilou_tag: I)]
# 		[(level: 0, coref_id: 2, bilou_tag: B)]
# 1_12	person	2)
#
# 		[(level: 0, coref_id: 2, bilou_tag: L)]
# 		[]
# 1_13	in	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_14	the	(3-place-acc:com-cf4-2-sgl
#
# 		[(level: 0, coref_id: 3, bilou_tag: B)]
# 		[(level: 0, coref_id: 3, bilou_tag: B)]
# 1_15	world	3)
#
# 		[(level: 0, coref_id: 3, bilou_tag: L)]
# 		[]
# 1_16	because	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_17	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_18	unlike	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_19	his	(4-person-new-cf11-2-coref(1-person-giv:act-cf3-1-ana)
#
# 		[(level: 0, coref_id: 4, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_20	parents	_
# 		[(level: 0, coref_id: 4, bilou_tag: I)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_21	,	_
# 		[(level: 0, coref_id: 4, bilou_tag: I)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_22	who	_
# 		[(level: 0, coref_id: 4, bilou_tag: I)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_23	believed	_
# 		[(level: 0, coref_id: 4, bilou_tag: I)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_24	that	_
# 		[(level: 0, coref_id: 4, bilou_tag: I)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_25	children	(5-person-new-cf8-1-sgl)
# 		[(level: 0, coref_id: 4, bilou_tag: I) | (level: 1, coref_id: 5, bilou_tag: U)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_26	should	_
# 		[(level: 0, coref_id: 4, bilou_tag: I)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_27	always	_
# 		[(level: 0, coref_id: 4, bilou_tag: I)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_28	be	_
# 		[(level: 0, coref_id: 4, bilou_tag: I)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_29	told	_
# 		[(level: 0, coref_id: 4, bilou_tag: I)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_30	the	(6-abstract-new-cf2-2-coref
#
# 		[(level: 0, coref_id: 4, bilou_tag: I) | (level: 1, coref_id: 6, bilou_tag: B)]
# 		[(level: 0, coref_id: 4, bilou_tag: B) | (level: 1, coref_id: 6, bilou_tag: B)]
# 1_31	truth	6)
# 		[(level: 0, coref_id: 4, bilou_tag: I) | (level: 1, coref_id: 6, bilou_tag: L)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_32	as	_
# 		[(level: 0, coref_id: 4, bilou_tag: I)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_33	adults	(7-person-new-cf9-1-sgl)
# 		[(level: 0, coref_id: 4, bilou_tag: I) | (level: 1, coref_id: 7, bilou_tag: U)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_34	understood	_
# 		[(level: 0, coref_id: 4, bilou_tag: I)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 1_35	it	(6-abstract-giv:act-cf2-1-ana)4)
# 		[(level: 0, coref_id: 4, bilou_tag: L) | (level: 1, coref_id: 6, bilou_tag: U)]
# 		[]
# 1_36	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_37	she	(2-person-giv:act-cf1-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 1_38	would	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_39	fill	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_40	in	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_41	the	(8-abstract-new-cf10-2-coref
#
# 		[(level: 0, coref_id: 8, bilou_tag: B)]
# 		[(level: 0, coref_id: 8, bilou_tag: B)]
# 1_42	gaps	_
# 		[(level: 0, coref_id: 8, bilou_tag: I)]
# 		[(level: 0, coref_id: 8, bilou_tag: B)]
# 1_43	in	_
# 		[(level: 0, coref_id: 8, bilou_tag: I)]
# 		[(level: 0, coref_id: 8, bilou_tag: B)]
# 1_44	his	(9-abstract-new-cf12-2-sgl(1-person-giv:act-cf3-1-ana)
#
# 		[(level: 0, coref_id: 8, bilou_tag: I) | (level: 1, coref_id: 9, bilou_tag: B) | (level: 2, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 8, bilou_tag: B) | (level: 1, coref_id: 9, bilou_tag: B)]
# 1_45	knowledge	9)8)
# 		[(level: 0, coref_id: 8, bilou_tag: L) | (level: 1, coref_id: 9, bilou_tag: L)]
# 		[]
# 1_46	—	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_47	Santa	(10-person-acc:inf-cf6-1,2-sgl-Santa_Claus
#
# 		[(level: 0, coref_id: 10, bilou_tag: B)]
# 		[(level: 0, coref_id: 10, bilou_tag: B)]
# 1_48	Claus	10)
# 		[(level: 0, coref_id: 10, bilou_tag: L)]
# 		[]
# 1_49	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_50	the	(11-animal-acc:inf-cf5-2,3-sgl-Easter_Bunny
#
# 		[(level: 0, coref_id: 11, bilou_tag: B)]
# 		[(level: 0, coref_id: 11, bilou_tag: B)]
# 1_51	Easter	_
# 		[(level: 0, coref_id: 11, bilou_tag: I)]
# 		[(level: 0, coref_id: 11, bilou_tag: B)]
# 1_52	Bunny	11)
# 		[(level: 0, coref_id: 11, bilou_tag: L)]
# 		[]
# 1_53	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 1_54	God	(12-person-acc:inf-cf7-1-sgl-God)|SpaceAfter=No
#
# 		[(level: 0, coref_id: 12, bilou_tag: U)]
# 		[]
# 1_55	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_1	His	(4-person-giv:act-cf3-2-coref(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 4, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 2_2	parents	4)
# 		[(level: 0, coref_id: 4, bilou_tag: L)]
# 		[]
# 2_3	were	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_4	always	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_5	too	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_6	busy	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_7	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_8	often	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_9	a	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_10	little	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_11	too	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_12	serious	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_13	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_14	but	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_15	his	(2-person-giv:act-cf2-2-coref(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 2, bilou_tag: B)]
# 2_16	grandmother	2)
# 		[(level: 0, coref_id: 2, bilou_tag: L)]
# 		[]
# 2_17	had	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_18	a	(13-abstract-new-cf4-2-sgl
#
# 		[(level: 0, coref_id: 13, bilou_tag: B)]
# 		[(level: 0, coref_id: 13, bilou_tag: B)]
# 2_19	sense	_
# 		[(level: 0, coref_id: 13, bilou_tag: I)]
# 		[(level: 0, coref_id: 13, bilou_tag: B)]
# 2_20	of	_
# 		[(level: 0, coref_id: 13, bilou_tag: I)]
# 		[(level: 0, coref_id: 13, bilou_tag: B)]
# 2_21	peace	(14-abstract-new-cf6-1-sgl)13)
#
# 		[(level: 0, coref_id: 13, bilou_tag: L) | (level: 1, coref_id: 14, bilou_tag: U)]
# 		[]
# 2_22	about	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_23	her	(2-person-giv:act-cf2-1-ana)
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 2_24	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 2_25	a	(15-abstract-new-cf7-2-sgl
#
# 		[(level: 0, coref_id: 15, bilou_tag: B)]
# 		[(level: 0, coref_id: 15, bilou_tag: B)]
# 2_26	lightness	_
# 		[(level: 0, coref_id: 15, bilou_tag: I)]
# 		[(level: 0, coref_id: 15, bilou_tag: B)]
# 2_27	that	_
# 		[(level: 0, coref_id: 15, bilou_tag: I)]
# 		[(level: 0, coref_id: 15, bilou_tag: B)]
# 2_28	lifted	_
# 		[(level: 0, coref_id: 15, bilou_tag: I)]
# 		[(level: 0, coref_id: 15, bilou_tag: B)]
# 2_29	his	(16-abstract-new-cf5-2-sgl(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 15, bilou_tag: I) | (level: 1, coref_id: 16, bilou_tag: B) | (level: 2, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 15, bilou_tag: B) | (level: 1, coref_id: 16, bilou_tag: B)]
# 2_30	spirit	16)15)
# 		[(level: 0, coref_id: 15, bilou_tag: L) | (level: 1, coref_id: 16, bilou_tag: L)]
# 		[]
# 2_31	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 3_1	A	(17-time-new-cf4-3-sgl
#
# 		[(level: 0, coref_id: 17, bilou_tag: B)]
# 		[(level: 0, coref_id: 17, bilou_tag: B)]
# 3_2	few	_
# 		[(level: 0, coref_id: 17, bilou_tag: I)]
# 		[(level: 0, coref_id: 17, bilou_tag: B)]
# 3_3	times	17)
# 		[(level: 0, coref_id: 17, bilou_tag: L)]
# 		[]
# 3_4	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 3_5	when	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 3_6-7	Tyler’s	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 3_6	Tyler	(4-person-giv:act-cf3-3-coref(1-person-giv:act-cf2-1-coref
#
# 		[(level: 0, coref_id: 4, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: B)]
# 		[(level: 0, coref_id: 4, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: B)]
# 3_7	’s	1)
#
# 		[(level: 0, coref_id: 4, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: L)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 3_8	parents	4)
# 		[(level: 0, coref_id: 4, bilou_tag: L)]
# 		[]
# 3_9	were	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 3_10	away	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 3_11	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 3_12	she	(2-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 3_13	took	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 3_14	him	(1-person-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 3_15	with	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 3_16	her	(2-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 3_17	to	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 3_18	church	(18-place-new-cf5-1-coref)
# 		[(level: 0, coref_id: 18, bilou_tag: U)]
# 		[]
# 3_19	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_1	He	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 4_2	remembered	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_3	liking	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_4	the	(19-event-acc:inf-cf4-2-sgl
#
# 		[(level: 0, coref_id: 19, bilou_tag: B)]
# 		[(level: 0, coref_id: 19, bilou_tag: B)]
# 4_5	singing	19)
# 		[(level: 0, coref_id: 19, bilou_tag: L)]
# 		[]
# 4_6	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_7	the	(20-object-acc:inf-cf5-3-sgl
#
# 		[(level: 0, coref_id: 20, bilou_tag: B)]
# 		[(level: 0, coref_id: 20, bilou_tag: B)]
# 4_8	colorful	_
# 		[(level: 0, coref_id: 20, bilou_tag: I)]
# 		[(level: 0, coref_id: 20, bilou_tag: B)]
# 4_9	windows	20)
# 		[(level: 0, coref_id: 20, bilou_tag: L)]
# 		[]
# 4_10	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_11	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_12	how	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_13	safe	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_14	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 4_15	felt	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_16	there	(18-place-giv:act-cf3-1-coref)
# 		[(level: 0, coref_id: 18, bilou_tag: U)]
# 		[]
# 4_17	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_18	in	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_19	that	(18-place-giv:act-cf3-5-coref
#
# 		[(level: 0, coref_id: 18, bilou_tag: B)]
# 		[(level: 0, coref_id: 18, bilou_tag: B)]
# 4_20	large	_
# 		[(level: 0, coref_id: 18, bilou_tag: I)]
# 		[(level: 0, coref_id: 18, bilou_tag: B)]
# 4_21	,	_
# 		[(level: 0, coref_id: 18, bilou_tag: I)]
# 		[(level: 0, coref_id: 18, bilou_tag: B)]
# 4_22	empty	_
# 		[(level: 0, coref_id: 18, bilou_tag: I)]
# 		[(level: 0, coref_id: 18, bilou_tag: B)]
# 4_23	space	18)
# 		[(level: 0, coref_id: 18, bilou_tag: L)]
# 		[]
# 4_24	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_25	sitting	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_26	on	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_27	a	(21-object-new-cf6-3-sgl
#
# 		[(level: 0, coref_id: 21, bilou_tag: B)]
# 		[(level: 0, coref_id: 21, bilou_tag: B)]
# 4_28	hard	_
# 		[(level: 0, coref_id: 21, bilou_tag: I)]
# 		[(level: 0, coref_id: 21, bilou_tag: B)]
# 4_29	bench	21)
#
# 		[(level: 0, coref_id: 21, bilou_tag: L)]
# 		[]
# 4_30	next	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_31	to	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 4_32	her	(22-abstract-new-cf7-2-sgl(2-person-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 22, bilou_tag: B) | (level: 1, coref_id: 2, bilou_tag: U)]
# 		[(level: 0, coref_id: 22, bilou_tag: B)]
# 4_33	warmth	22)
# 		[(level: 0, coref_id: 22, bilou_tag: L)]
# 		[]
# 4_34	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 5_1	When	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 5_2	she	(2-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 5_3	died	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 5_4	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 5_5	grief	(23-abstract-new-cf3-1-sgl)
#
# 		[(level: 0, coref_id: 23, bilou_tag: U)]
# 		[]
# 5_6	overwhelmed	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 5_7	Tyler	(1-person-giv:act-cf2-1-coref)
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 5_8	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 6_1	But	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 6_2	like	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 6_3	most	(24-person-new-cf4-2-sgl
#
# 		[(level: 0, coref_id: 24, bilou_tag: B)]
# 		[(level: 0, coref_id: 24, bilou_tag: B)]
# 6_4	adults	24)
# 		[(level: 0, coref_id: 24, bilou_tag: L)]
# 		[]
# 6_5	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 6_6	when	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 6_7	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 6_8	grew	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 6_9	older	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 6_10	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 6_11	could	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 6_12	only	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 6_13	recall	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 6_14	the	(25-abstract-new-cf2-2-sgl
#
# 		[(level: 0, coref_id: 25, bilou_tag: B)]
# 		[(level: 0, coref_id: 25, bilou_tag: B)]
# 6_15	intensity	_
# 		[(level: 0, coref_id: 25, bilou_tag: I)]
# 		[(level: 0, coref_id: 25, bilou_tag: B)]
# 6_16	of	_
# 		[(level: 0, coref_id: 25, bilou_tag: I)]
# 		[(level: 0, coref_id: 25, bilou_tag: B)]
# 6_17	that	(26-abstract-new-cf3-2-coref
#
# 		[(level: 0, coref_id: 25, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: B)]
# 		[(level: 0, coref_id: 25, bilou_tag: B) | (level: 1, coref_id: 26, bilou_tag: B)]
# 6_18	love	26)
#
# 		[(level: 0, coref_id: 25, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: L)]
# 		[(level: 0, coref_id: 25, bilou_tag: B)]
# 6_19	in	_
# 		[(level: 0, coref_id: 25, bilou_tag: I)]
# 		[(level: 0, coref_id: 25, bilou_tag: B)]
# 6_20	childhood	(27-time-new-cf5-1-sgl)25)
# 		[(level: 0, coref_id: 25, bilou_tag: L) | (level: 1, coref_id: 27, bilou_tag: U)]
# 		[]
# 6_21	in	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 6_22	an	(28-abstract-new-cf6-3-sgl
#
# 		[(level: 0, coref_id: 28, bilou_tag: B)]
# 		[(level: 0, coref_id: 28, bilou_tag: B)]
# 6_23	abstract	_
# 		[(level: 0, coref_id: 28, bilou_tag: I)]
# 		[(level: 0, coref_id: 28, bilou_tag: B)]
# 6_24	way	28)
# 		[(level: 0, coref_id: 28, bilou_tag: L)]
# 		[]
# 6_25	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_1	He	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 7_2	made	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_3	the	(29-abstract-new-cf4-3-sgl
#
# 		[(level: 0, coref_id: 29, bilou_tag: B)]
# 		[(level: 0, coref_id: 29, bilou_tag: B)]
# 7_4	common	_
# 		[(level: 0, coref_id: 29, bilou_tag: I)]
# 		[(level: 0, coref_id: 29, bilou_tag: B)]
# 7_5	error	_
# 		[(level: 0, coref_id: 29, bilou_tag: I)]
# 		[(level: 0, coref_id: 29, bilou_tag: B)]
# 7_6	of	_
# 		[(level: 0, coref_id: 29, bilou_tag: I)]
# 		[(level: 0, coref_id: 29, bilou_tag: B)]
# 7_7	identifying	_
# 		[(level: 0, coref_id: 29, bilou_tag: I)]
# 		[(level: 0, coref_id: 29, bilou_tag: B)]
# 7_8	maturity	(30-abstract-new-cf5-1-sgl)
# 		[(level: 0, coref_id: 29, bilou_tag: I) | (level: 1, coref_id: 30, bilou_tag: U)]
# 		[(level: 0, coref_id: 29, bilou_tag: B)]
# 7_9	with	_
# 		[(level: 0, coref_id: 29, bilou_tag: I)]
# 		[(level: 0, coref_id: 29, bilou_tag: B)]
# 7_10	worth	(31-abstract-new-cf6-1-sgl)29)
# 		[(level: 0, coref_id: 29, bilou_tag: L) | (level: 1, coref_id: 31, bilou_tag: U)]
# 		[]
# 7_11	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_12	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_13	assumed	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_14	that	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_15	the	(26-abstract-giv:act-cf2-2-coref
#
# 		[(level: 0, coref_id: 26, bilou_tag: B)]
# 		[(level: 0, coref_id: 26, bilou_tag: B)]
# 7_16	love	_
# 		[(level: 0, coref_id: 26, bilou_tag: I)]
# 		[(level: 0, coref_id: 26, bilou_tag: B)]
# 7_17	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 26, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 26, bilou_tag: B)]
# 7_18	had	_
# 		[(level: 0, coref_id: 26, bilou_tag: I)]
# 		[(level: 0, coref_id: 26, bilou_tag: B)]
# 7_19	for	_
# 		[(level: 0, coref_id: 26, bilou_tag: I)]
# 		[(level: 0, coref_id: 26, bilou_tag: B)]
# 7_20	her	(2-person-giv:inact-cf3-1-ana)
#
# 		[(level: 0, coref_id: 26, bilou_tag: I) | (level: 1, coref_id: 2, bilou_tag: U)]
# 		[(level: 0, coref_id: 26, bilou_tag: B)]
# 7_21	as	_
# 		[(level: 0, coref_id: 26, bilou_tag: I)]
# 		[(level: 0, coref_id: 26, bilou_tag: B)]
# 7_22	a	(1-person-giv:act-cf1*-3-pred
#
# 		[(level: 0, coref_id: 26, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: B)]
# 		[(level: 0, coref_id: 26, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: B)]
# 7_23	young	_
# 		[(level: 0, coref_id: 26, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: I)]
# 		[(level: 0, coref_id: 26, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: B)]
# 7_24	child	1)26)
#
# 		[(level: 0, coref_id: 26, bilou_tag: L) | (level: 1, coref_id: 1, bilou_tag: L)]
# 		[]
# 7_25	must	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_26	have	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_27	been	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_28	lacking	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_29	in	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_30	strength	(32-abstract-new-cf7-1-sgl)
# 		[(level: 0, coref_id: 32, bilou_tag: U)]
# 		[]
# 7_31	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 7_32	depth	(33-abstract-new-cf8-1-sgl)
# 		[(level: 0, coref_id: 33, bilou_tag: U)]
# 		[]
# 7_33	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 8_1	For	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 8_2	many	(34-time-new-cf4-2-coref
#
# 		[(level: 0, coref_id: 34, bilou_tag: B)]
# 		[(level: 0, coref_id: 34, bilou_tag: B)]
# 8_3	years	_
# 		[(level: 0, coref_id: 34, bilou_tag: I)]
# 		[(level: 0, coref_id: 34, bilou_tag: B)]
# 8_4	after	_
# 		[(level: 0, coref_id: 34, bilou_tag: I)]
# 		[(level: 0, coref_id: 34, bilou_tag: B)]
# 8_5	her	(35-event-new-cf5-2-coref(2-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 34, bilou_tag: I) | (level: 1, coref_id: 35, bilou_tag: B) | (level: 2, coref_id: 2, bilou_tag: U)]
# 		[(level: 0, coref_id: 34, bilou_tag: B) | (level: 1, coref_id: 35, bilou_tag: B)]
# 8_6	death	35)34)
# 		[(level: 0, coref_id: 34, bilou_tag: L) | (level: 1, coref_id: 35, bilou_tag: L)]
# 		[]
# 8_7	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 8_8	however	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 8_9	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 8_10	Tyler	(1-person-giv:act-cf2-1-coref)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 8_11	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 8_12	tortured	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 8_13	by	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 8_14	the	(36-abstract-new-cf3-2-coref
#
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 8_15	memory	_
# 		[(level: 0, coref_id: 36, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 8_16	of	_
# 		[(level: 0, coref_id: 36, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 8_17	a	(37-event-new-cf6-3-sgl
#
# 		[(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 37, bilou_tag: B)]
# 		[(level: 0, coref_id: 36, bilou_tag: B) | (level: 1, coref_id: 37, bilou_tag: B)]
# 8_18	certain	_
# 		[(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 37, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B) | (level: 1, coref_id: 37, bilou_tag: B)]
# 8_19	visit	_
# 		[(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 37, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B) | (level: 1, coref_id: 37, bilou_tag: B)]
# 8_20	from	_
# 		[(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 37, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B) | (level: 1, coref_id: 37, bilou_tag: B)]
# 8_21	her	(2-person-giv:act-cf1*-1-ana)37)36)
# 		[(level: 0, coref_id: 36, bilou_tag: L) | (level: 2, coref_id: 2, bilou_tag: U) | (level: 1, coref_id: 37, bilou_tag: L)]
# 		[]
# 8_22	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 9_1	He	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 9_2	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 9_3	five	(38-abstract-new-cf5-1-sgl)
#
# 		[(level: 0, coref_id: 38, bilou_tag: U)]
# 		[]
# 9_4	or	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 9_5	so	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 9_6	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 9_7	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 9_8	they	(39-person-acc:aggr-cf2-1-sgl)
# 		[(level: 0, coref_id: 39, bilou_tag: U)]
# 		[]
# 9_9	were	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 9_10	playing	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 9_11	some	(40-abstract-new-cf4-3-sgl
#
# 		[(level: 0, coref_id: 40, bilou_tag: B)]
# 		[(level: 0, coref_id: 40, bilou_tag: B)]
# 9_12	board	_
# 		[(level: 0, coref_id: 40, bilou_tag: I)]
# 		[(level: 0, coref_id: 40, bilou_tag: B)]
# 9_13	game	40)
#
# 		[(level: 0, coref_id: 40, bilou_tag: L)]
# 		[]
# 9_14	at	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 9_15	the	(41-object-acc:com-cf3-3-coref
#
# 		[(level: 0, coref_id: 41, bilou_tag: B)]
# 		[(level: 0, coref_id: 41, bilou_tag: B)]
# 9_16	kitchen	(42-place-new-cf6-1-coref)
#
# 		[(level: 0, coref_id: 41, bilou_tag: I) | (level: 1, coref_id: 42, bilou_tag: U)]
# 		[(level: 0, coref_id: 41, bilou_tag: B)]
# 9_17	table	41)
# 		[(level: 0, coref_id: 41, bilou_tag: L)]
# 		[]
# 9_18	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 10_1	As	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 10_2	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 10_3	swung	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 10_4	his	(43-object-new-cf4-2-sgl(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 43, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 43, bilou_tag: B)]
# 10_5	legs	43)
# 		[(level: 0, coref_id: 43, bilou_tag: L)]
# 		[]
# 10_6	in	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 10_7	his	(44-abstract-new-cf5-2-sgl(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 44, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 44, bilou_tag: B)]
# 10_8	excitement	44)
# 		[(level: 0, coref_id: 44, bilou_tag: L)]
# 		[]
# 10_9	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 10_10	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 10_11	kicked	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 10_12	her	(2-person-giv:inact-cf2-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 10_13	repeatedly	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 10_14	in	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 10_15	the	(45-object-acc:inf-cf3-2-sgl
#
# 		[(level: 0, coref_id: 45, bilou_tag: B)]
# 		[(level: 0, coref_id: 45, bilou_tag: B)]
# 10_16	shins	45)
# 		[(level: 0, coref_id: 45, bilou_tag: L)]
# 		[]
# 10_17	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 11_1	She	(2-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 11_2	asked	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 11_3	him	(1-person-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 11_4	to	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 11_5	stop	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 11_6	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 11_7	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 11_8	he	(1-person-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 11_9	refused	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 11_10	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 11_11	giggling	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 11_12	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_1	When	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_2	she	(2-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 12_3	finally	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_4	frowned	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_5	at	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_6	him	(1-person-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 12_7	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_8	threatened	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_9	to	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_10	stop	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_11	playing	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_12	if	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_13	he	(1-person-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 12_14-15	didn’t	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_14	did	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_15	n’t	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_16	stop	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_17	he	(1-person-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 12_18	told	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_19	her	(2-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 12_20	to	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_21	go	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_22	to	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 12_23	Hell	(46-place-new-cf3-1-coref-Hell)
# 		[(level: 0, coref_id: 46, bilou_tag: U)]
# 		[]
# 12_24	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_1	In	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_2-3	Tyler’s	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_2	Tyler	(47-abstract-new-cf6-3-sgl(1-person-giv:act-cf1*-1-coref
#
# 		[(level: 0, coref_id: 47, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: B)]
# 		[(level: 0, coref_id: 47, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: B)]
# 13_3	’s	1)
#
# 		[(level: 0, coref_id: 47, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: L)]
# 		[(level: 0, coref_id: 47, bilou_tag: B)]
# 13_4	mind	47)
#
# 		[(level: 0, coref_id: 47, bilou_tag: L)]
# 		[]
# 13_5	he	(1-person-acc:com-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 13_6	could	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_7	see	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_8	her	(48-object-new-cf3-2-sgl(2-person-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 48, bilou_tag: B) | (level: 1, coref_id: 2, bilou_tag: U)]
# 		[(level: 0, coref_id: 48, bilou_tag: B)]
# 13_9	face	48)
#
# 		[(level: 0, coref_id: 48, bilou_tag: L)]
# 		[]
# 13_10	grow	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_11	taut	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_12	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_13	lose	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_14	color	(49-abstract-new-cf4-1-sgl)
# 		[(level: 0, coref_id: 49, bilou_tag: U)]
# 		[]
# 13_15	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_16	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_17	then	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_18	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_19	for	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_20	the	(50-time-new-cf5-3-sgl
#
# 		[(level: 0, coref_id: 50, bilou_tag: B)]
# 		[(level: 0, coref_id: 50, bilou_tag: B)]
# 13_21	only	_
# 		[(level: 0, coref_id: 50, bilou_tag: I)]
# 		[(level: 0, coref_id: 50, bilou_tag: B)]
# 13_22	time	_
# 		[(level: 0, coref_id: 50, bilou_tag: I)]
# 		[(level: 0, coref_id: 50, bilou_tag: B)]
# 13_23	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 50, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 50, bilou_tag: B)]
# 13_24	could	_
# 		[(level: 0, coref_id: 50, bilou_tag: I)]
# 		[(level: 0, coref_id: 50, bilou_tag: B)]
# 13_25	remember	50)
# 		[(level: 0, coref_id: 50, bilou_tag: L)]
# 		[]
# 13_26	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_27	she	(2-person-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 13_28	began	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_29	to	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_30	cry	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 13_31	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 14_1	He	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 14_2	also	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 14_3	remembered	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 14_4	his	(51-abstract-new-cf2-4-sgl(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 51, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 51, bilou_tag: B)]
# 14_5	own	_
# 		[(level: 0, coref_id: 51, bilou_tag: I)]
# 		[(level: 0, coref_id: 51, bilou_tag: B)]
# 14_6	utter	_
# 		[(level: 0, coref_id: 51, bilou_tag: I)]
# 		[(level: 0, coref_id: 51, bilou_tag: B)]
# 14_7	confusion	51)
# 		[(level: 0, coref_id: 51, bilou_tag: L)]
# 		[]
# 14_8	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 15_1	His	(4-person-giv:inact-cf3-2-coref(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 4, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 4, bilou_tag: B)]
# 15_2	parents	4)
# 		[(level: 0, coref_id: 4, bilou_tag: L)]
# 		[]
# 15_3	did	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 15_4	not	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 15_5	have	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 15_6	much	(52-abstract-new-cf4-2-sgl
#
# 		[(level: 0, coref_id: 52, bilou_tag: B)]
# 		[(level: 0, coref_id: 52, bilou_tag: B)]
# 15_7	use	_
# 		[(level: 0, coref_id: 52, bilou_tag: I)]
# 		[(level: 0, coref_id: 52, bilou_tag: B)]
# 15_8	for	_
# 		[(level: 0, coref_id: 52, bilou_tag: I)]
# 		[(level: 0, coref_id: 52, bilou_tag: B)]
# 15_9	religion	(53-abstract-new-cf5-1-sgl)52)
#
# 		[(level: 0, coref_id: 52, bilou_tag: L) | (level: 1, coref_id: 53, bilou_tag: U)]
# 		[]
# 15_10	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 15_11	so	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 15_12	for	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 15_13	him	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 15_14	Hell	(54-abstract-new-cf2-1-coref)
# 		[(level: 0, coref_id: 54, bilou_tag: U)]
# 		[]
# 15_15	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 15_16	a	(54-abstract-giv:act-cf2-2-pred
#
# 		[(level: 0, coref_id: 54, bilou_tag: B)]
# 		[(level: 0, coref_id: 54, bilou_tag: B)]
# 15_17	word	_
# 		[(level: 0, coref_id: 54, bilou_tag: I)]
# 		[(level: 0, coref_id: 54, bilou_tag: B)]
# 15_18	without	_
# 		[(level: 0, coref_id: 54, bilou_tag: I)]
# 		[(level: 0, coref_id: 54, bilou_tag: B)]
# 15_19	much	(55-abstract-new-cf6-2-sgl
#
# 		[(level: 0, coref_id: 54, bilou_tag: I) | (level: 1, coref_id: 55, bilou_tag: B)]
# 		[(level: 0, coref_id: 54, bilou_tag: B) | (level: 1, coref_id: 55, bilou_tag: B)]
# 15_20	mystery	55)
#
# 		[(level: 0, coref_id: 54, bilou_tag: I) | (level: 1, coref_id: 55, bilou_tag: L)]
# 		[(level: 0, coref_id: 54, bilou_tag: B)]
# 15_21	or	_
# 		[(level: 0, coref_id: 54, bilou_tag: I)]
# 		[(level: 0, coref_id: 54, bilou_tag: B)]
# 15_22	power	(56-abstract-new-cf7-1-sgl)54)
# 		[(level: 0, coref_id: 54, bilou_tag: L) | (level: 1, coref_id: 56, bilou_tag: U)]
# 		[]
# 15_23	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 16_1	At	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 16_2	that	(57-time-acc:com-cf4-2-sgl
#
# 		[(level: 0, coref_id: 57, bilou_tag: B)]
# 		[(level: 0, coref_id: 57, bilou_tag: B)]
# 16_3	time	57)
#
# 		[(level: 0, coref_id: 57, bilou_tag: L)]
# 		[]
# 16_4	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 16_5	knew	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 16_6	only	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 16_7	vaguely	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 16_8	that	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 16_9	Hell	(46-place-giv:inact-cf2-1-coref-Hell)
#
# 		[(level: 0, coref_id: 46, bilou_tag: U)]
# 		[]
# 16_10	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 16_11	a	(46-place-giv:act-cf2-2-coref-Hell
#
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_12	place	_
# 		[(level: 0, coref_id: 46, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_13	you	(58-person-acc:com-cf3-1-sgl)
#
# 		[(level: 0, coref_id: 46, bilou_tag: I) | (level: 1, coref_id: 58, bilou_tag: U)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_14	did	_
# 		[(level: 0, coref_id: 46, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_15	not	_
# 		[(level: 0, coref_id: 46, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_16	want	_
# 		[(level: 0, coref_id: 46, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_17	to	_
# 		[(level: 0, coref_id: 46, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_18	go	_
# 		[(level: 0, coref_id: 46, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_19	,	_
# 		[(level: 0, coref_id: 46, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_20	like	_
# 		[(level: 0, coref_id: 46, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_21	the	(59-place-acc:com-cf5-3-sgl
#
# 		[(level: 0, coref_id: 46, bilou_tag: I) | (level: 1, coref_id: 59, bilou_tag: B)]
# 		[(level: 0, coref_id: 46, bilou_tag: B) | (level: 1, coref_id: 59, bilou_tag: B)]
# 16_22	dark	_
# 		[(level: 0, coref_id: 46, bilou_tag: I) | (level: 1, coref_id: 59, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B) | (level: 1, coref_id: 59, bilou_tag: B)]
# 16_23	basement	59)
# 		[(level: 0, coref_id: 46, bilou_tag: I) | (level: 1, coref_id: 59, bilou_tag: L)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_24	or	_
# 		[(level: 0, coref_id: 46, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B)]
# 16_25	the	(60-place-acc:com-cf6-4-sgl
#
# 		[(level: 0, coref_id: 46, bilou_tag: I) | (level: 1, coref_id: 60, bilou_tag: B)]
# 		[(level: 0, coref_id: 46, bilou_tag: B) | (level: 1, coref_id: 60, bilou_tag: B)]
# 16_26	even	_
# 		[(level: 0, coref_id: 46, bilou_tag: I) | (level: 1, coref_id: 60, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B) | (level: 1, coref_id: 60, bilou_tag: B)]
# 16_27	darker	_
# 		[(level: 0, coref_id: 46, bilou_tag: I) | (level: 1, coref_id: 60, bilou_tag: I)]
# 		[(level: 0, coref_id: 46, bilou_tag: B) | (level: 1, coref_id: 60, bilou_tag: B)]
# 16_28	attic	60)46)
# 		[(level: 0, coref_id: 46, bilou_tag: L) | (level: 1, coref_id: 60, bilou_tag: L)]
# 		[]
# 16_29	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_1	He	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 17_2	remembered	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_3	feeling	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_4	resentful	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_5	that	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_6	she	(2-person-giv:inact-cf2-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 17_7	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_8	crying	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_9	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_10	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 17_11	did	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_12	not	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_13	even	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_14	understand	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_15	why	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 17_16	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 18_1	Tyler	(1-person-giv:act-cf1*-1-coref)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 18_2	felt	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 18_3	the	(61-abstract-new-cf3-2-sgl
#
# 		[(level: 0, coref_id: 61, bilou_tag: B)]
# 		[(level: 0, coref_id: 61, bilou_tag: B)]
# 18_4	guilt	_
# 		[(level: 0, coref_id: 61, bilou_tag: I)]
# 		[(level: 0, coref_id: 61, bilou_tag: B)]
# 18_5	of	_
# 		[(level: 0, coref_id: 61, bilou_tag: I)]
# 		[(level: 0, coref_id: 61, bilou_tag: B)]
# 18_6	this	(36-abstract-giv:inact-cf2-2-coref
#
# 		[(level: 0, coref_id: 61, bilou_tag: I) | (level: 1, coref_id: 36, bilou_tag: B)]
# 		[(level: 0, coref_id: 61, bilou_tag: B) | (level: 1, coref_id: 36, bilou_tag: B)]
# 18_7	memory	36)61)
#
# 		[(level: 0, coref_id: 61, bilou_tag: L) | (level: 1, coref_id: 36, bilou_tag: L)]
# 		[]
# 18_8	even	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 18_9	in	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 18_10	his	(62-time-new-cf4-3-sgl(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 62, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 62, bilou_tag: B)]
# 18_11	teenage	_
# 		[(level: 0, coref_id: 62, bilou_tag: I)]
# 		[(level: 0, coref_id: 62, bilou_tag: B)]
# 18_12	years	62)
# 		[(level: 0, coref_id: 62, bilou_tag: L)]
# 		[]
# 18_13	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 19_1	For	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 19_2	him	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 19_3	it	(36-abstract-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 36, bilou_tag: U)]
# 		[]
# 19_4	summed	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 19_5	up	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 19_6	all	(63-abstract-new-cf3-3,5-sgl
#
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 19_7	his	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 19_8	insecurities	_
# 		[(level: 0, coref_id: 63, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 19_9	and	_
# 		[(level: 0, coref_id: 63, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 19_10	fears	_
# 		[(level: 0, coref_id: 63, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 19_11	about	_
# 		[(level: 0, coref_id: 63, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 19_12	his	(64-abstract-new-cf6-3-sgl(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 64, bilou_tag: B) | (level: 2, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 64, bilou_tag: B)]
# 19_13	own	_
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 64, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 64, bilou_tag: B)]
# 19_14	cruelty	64)
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 64, bilou_tag: L)]
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 19_15	,	_
# 		[(level: 0, coref_id: 63, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 19_16	ignorance	(65-abstract-new-cf7-1-sgl)
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 65, bilou_tag: U)]
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 19_17	,	_
# 		[(level: 0, coref_id: 63, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 19_18	and	_
# 		[(level: 0, coref_id: 63, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B)]
# 19_19	the	(66-abstract-new-cf4-2-sgl
#
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: B)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B)]
# 19_20	possibility	_
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B)]
# 19_21	that	_
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B)]
# 19_22	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: I) | (level: 2, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B)]
# 19_23	was	_
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B)]
# 19_24	,	_
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B)]
# 19_25	in	_
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B)]
# 19_26	reality	_
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B)]
# 19_27	,	_
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B)]
# 19_28	not	_
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B)]
# 19_29	a	(67-person-new-cf5-3-sgl
#
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: I) | (level: 2, coref_id: 67, bilou_tag: B)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B) | (level: 2, coref_id: 67, bilou_tag: B)]
# 19_30	good	_
# 		[(level: 0, coref_id: 63, bilou_tag: I) | (level: 1, coref_id: 66, bilou_tag: I) | (level: 2, coref_id: 67, bilou_tag: I)]
# 		[(level: 0, coref_id: 63, bilou_tag: B) | (level: 1, coref_id: 66, bilou_tag: B) | (level: 2, coref_id: 67, bilou_tag: B)]
# 19_31	person	67)66)63)
# 		[(level: 0, coref_id: 63, bilou_tag: L) | (level: 2, coref_id: 67, bilou_tag: L) | (level: 1, coref_id: 66, bilou_tag: L)]
# 		[]
# 19_32	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 20_1	The	(68-abstract-new-cf3-2-sgl
#
# 		[(level: 0, coref_id: 68, bilou_tag: B)]
# 		[(level: 0, coref_id: 68, bilou_tag: B)]
# 20_2	fact	_
# 		[(level: 0, coref_id: 68, bilou_tag: I)]
# 		[(level: 0, coref_id: 68, bilou_tag: B)]
# 20_3	that	_
# 		[(level: 0, coref_id: 68, bilou_tag: I)]
# 		[(level: 0, coref_id: 68, bilou_tag: B)]
# 20_4	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 68, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 68, bilou_tag: B)]
# 20_5	had	_
# 		[(level: 0, coref_id: 68, bilou_tag: I)]
# 		[(level: 0, coref_id: 68, bilou_tag: B)]
# 20_6	caused	_
# 		[(level: 0, coref_id: 68, bilou_tag: I)]
# 		[(level: 0, coref_id: 68, bilou_tag: B)]
# 20_7	someone	(2-person-giv:inact-cf2-1-coref
#
# 		[(level: 0, coref_id: 68, bilou_tag: I) | (level: 1, coref_id: 2, bilou_tag: B)]
# 		[(level: 0, coref_id: 68, bilou_tag: B) | (level: 1, coref_id: 2, bilou_tag: B)]
# 20_8	who	_
# 		[(level: 0, coref_id: 68, bilou_tag: I) | (level: 1, coref_id: 2, bilou_tag: I)]
# 		[(level: 0, coref_id: 68, bilou_tag: B) | (level: 1, coref_id: 2, bilou_tag: B)]
# 20_9	loved	_
# 		[(level: 0, coref_id: 68, bilou_tag: I) | (level: 1, coref_id: 2, bilou_tag: I)]
# 		[(level: 0, coref_id: 68, bilou_tag: B) | (level: 1, coref_id: 2, bilou_tag: B)]
# 20_10	him	(1-person-giv:act-cf1*-1-ana)2)
#
# 		[(level: 0, coref_id: 68, bilou_tag: I) | (level: 2, coref_id: 1, bilou_tag: U) | (level: 1, coref_id: 2, bilou_tag: L)]
# 		[(level: 0, coref_id: 68, bilou_tag: B)]
# 20_11	such	(69-abstract-new-cf4-2-sgl
#
# 		[(level: 0, coref_id: 68, bilou_tag: I) | (level: 1, coref_id: 69, bilou_tag: B)]
# 		[(level: 0, coref_id: 68, bilou_tag: B) | (level: 1, coref_id: 69, bilou_tag: B)]
# 20_12	pain	69)
#
# 		[(level: 0, coref_id: 68, bilou_tag: I) | (level: 1, coref_id: 69, bilou_tag: L)]
# 		[(level: 0, coref_id: 68, bilou_tag: B)]
# 20_13	with	_
# 		[(level: 0, coref_id: 68, bilou_tag: I)]
# 		[(level: 0, coref_id: 68, bilou_tag: B)]
# 20_14	so	(70-abstract-new-cf5-3,5-sgl
#
# 		[(level: 0, coref_id: 68, bilou_tag: I) | (level: 1, coref_id: 70, bilou_tag: B)]
# 		[(level: 0, coref_id: 68, bilou_tag: B) | (level: 1, coref_id: 70, bilou_tag: B)]
# 20_15	little	_
# 		[(level: 0, coref_id: 68, bilou_tag: I) | (level: 1, coref_id: 70, bilou_tag: I)]
# 		[(level: 0, coref_id: 68, bilou_tag: B) | (level: 1, coref_id: 70, bilou_tag: B)]
# 20_16	effort	_
# 		[(level: 0, coref_id: 68, bilou_tag: I) | (level: 1, coref_id: 70, bilou_tag: I)]
# 		[(level: 0, coref_id: 68, bilou_tag: B) | (level: 1, coref_id: 70, bilou_tag: B)]
# 20_17	and	_
# 		[(level: 0, coref_id: 68, bilou_tag: I) | (level: 1, coref_id: 70, bilou_tag: I)]
# 		[(level: 0, coref_id: 68, bilou_tag: B) | (level: 1, coref_id: 70, bilou_tag: B)]
# 20_18	understanding	70)68)
# 		[(level: 0, coref_id: 68, bilou_tag: L) | (level: 1, coref_id: 70, bilou_tag: L)]
# 		[]
# 20_19	troubled	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 20_20	him	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 20_21	deeply	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 20_22	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 21_1	One	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 21_2	day	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 21_3	Tyler	(1-person-giv:act-cf3*-1-coref)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 21_4	looked	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 21_5	through	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 21_6	an	(71-object-new-cf2-5-coref
#
# 		[(level: 0, coref_id: 71, bilou_tag: B)]
# 		[(level: 0, coref_id: 71, bilou_tag: B)]
# 21_7	old	_
# 		[(level: 0, coref_id: 71, bilou_tag: I)]
# 		[(level: 0, coref_id: 71, bilou_tag: B)]
# 21_8	family	(72-person-acc:inf-cf1-1-coref)
#
# 		[(level: 0, coref_id: 71, bilou_tag: I) | (level: 1, coref_id: 72, bilou_tag: U)]
# 		[(level: 0, coref_id: 71, bilou_tag: B)]
# 21_9	photo	(73-object-new-cf7-1-sgl)
#
# 		[(level: 0, coref_id: 71, bilou_tag: I) | (level: 1, coref_id: 73, bilou_tag: U)]
# 		[(level: 0, coref_id: 71, bilou_tag: B)]
# 21_10	album	71)
# 		[(level: 0, coref_id: 71, bilou_tag: L)]
# 		[]
# 21_11	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 21_12	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 21_13	in	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 21_14	it	(71-object-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 71, bilou_tag: U)]
# 		[]
# 21_15	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 21_16	a	(74-object-new-cf5-2-sgl
#
# 		[(level: 0, coref_id: 74, bilou_tag: B)]
# 		[(level: 0, coref_id: 74, bilou_tag: B)]
# 21_17	picture	_
# 		[(level: 0, coref_id: 74, bilou_tag: I)]
# 		[(level: 0, coref_id: 74, bilou_tag: B)]
# 21_18	of	_
# 		[(level: 0, coref_id: 74, bilou_tag: I)]
# 		[(level: 0, coref_id: 74, bilou_tag: B)]
# 21_19	the	(42-place-giv:inact-cf4-2-coref
#
# 		[(level: 0, coref_id: 74, bilou_tag: I) | (level: 1, coref_id: 42, bilou_tag: B)]
# 		[(level: 0, coref_id: 74, bilou_tag: B) | (level: 1, coref_id: 42, bilou_tag: B)]
# 21_20	kitchen	42)
#
# 		[(level: 0, coref_id: 74, bilou_tag: I) | (level: 1, coref_id: 42, bilou_tag: L)]
# 		[(level: 0, coref_id: 74, bilou_tag: B)]
# 21_21	in	_
# 		[(level: 0, coref_id: 74, bilou_tag: I)]
# 		[(level: 0, coref_id: 74, bilou_tag: B)]
# 21_22	the	(75-place-new-cf6-2-coref
#
# 		[(level: 0, coref_id: 74, bilou_tag: I) | (level: 1, coref_id: 75, bilou_tag: B)]
# 		[(level: 0, coref_id: 74, bilou_tag: B) | (level: 1, coref_id: 75, bilou_tag: B)]
# 21_23	house	_
# 		[(level: 0, coref_id: 74, bilou_tag: I) | (level: 1, coref_id: 75, bilou_tag: I)]
# 		[(level: 0, coref_id: 74, bilou_tag: B) | (level: 1, coref_id: 75, bilou_tag: B)]
# 21_24	they	(72-person-giv:act-cf1-1-ana)
#
# 		[(level: 0, coref_id: 74, bilou_tag: I) | (level: 1, coref_id: 75, bilou_tag: I) | (level: 2, coref_id: 72, bilou_tag: U)]
# 		[(level: 0, coref_id: 74, bilou_tag: B) | (level: 1, coref_id: 75, bilou_tag: B)]
# 21_25	used	_
# 		[(level: 0, coref_id: 74, bilou_tag: I) | (level: 1, coref_id: 75, bilou_tag: I)]
# ...
#
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 30_4	sort	_
# 		[(level: 0, coref_id: 36, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 30_5	of	_
# 		[(level: 0, coref_id: 36, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 30_6	fantasy	_
# 		[(level: 0, coref_id: 36, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 30_7	that	_
# 		[(level: 0, coref_id: 36, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 30_8	could	_
# 		[(level: 0, coref_id: 36, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 30_9	have	_
# 		[(level: 0, coref_id: 36, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 30_10	occurred	_
# 		[(level: 0, coref_id: 36, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 30_11	to	_
# 		[(level: 0, coref_id: 36, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B)]
# 30_12	any	(97-person-new-cf3-3-sgl
#
# 		[(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 97, bilou_tag: B)]
# 		[(level: 0, coref_id: 36, bilou_tag: B) | (level: 1, coref_id: 97, bilou_tag: B)]
# 30_13	young	_
# 		[(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 97, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B) | (level: 1, coref_id: 97, bilou_tag: B)]
# 30_14	child	_
# 		[(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 97, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B) | (level: 1, coref_id: 97, bilou_tag: B)]
# 30_15	who	_
# 		[(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 97, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B) | (level: 1, coref_id: 97, bilou_tag: B)]
# 30_16	lost	_
# 		[(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 97, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B) | (level: 1, coref_id: 97, bilou_tag: B)]
# 30_17	an	(98-person-new-cf2-3-sgl
#
# 		[(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 97, bilou_tag: I) | (level: 2, coref_id: 98, bilou_tag: B)]
# 		[(level: 0, coref_id: 36, bilou_tag: B) | (level: 1, coref_id: 97, bilou_tag: B) | (level: 2, coref_id: 98, bilou_tag: B)]
# 30_18	important	_
# 		[(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 97, bilou_tag: I) | (level: 2, coref_id: 98, bilou_tag: I)]
# 		[(level: 0, coref_id: 36, bilou_tag: B) | (level: 1, coref_id: 97, bilou_tag: B) | (level: 2, coref_id: 98, bilou_tag: B)]
# 30_19	relative	98)97)36)
# 		[(level: 0, coref_id: 36, bilou_tag: L) | (level: 2, coref_id: 98, bilou_tag: L) | (level: 1, coref_id: 97, bilou_tag: L)]
# 		[]
# 30_20	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 31_1	With	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 31_2	that	(76-event-giv:inact-cf2-2-coref
#
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 31_3	realization	76)
# 		[(level: 0, coref_id: 76, bilou_tag: L)]
# 		[]
# 31_4	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 31_5	the	(99-abstract-new-cf5-2-coref
#
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 31_6	image	_
# 		[(level: 0, coref_id: 99, bilou_tag: I)]
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 31_7	of	_
# 		[(level: 0, coref_id: 99, bilou_tag: I)]
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 31_8	his	(2-person-giv:inact-cf3-2-coref(1-person-giv:inact-cf1-1-ana)
#
# 		[(level: 0, coref_id: 99, bilou_tag: I) | (level: 1, coref_id: 2, bilou_tag: B) | (level: 2, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 99, bilou_tag: B) | (level: 1, coref_id: 2, bilou_tag: B)]
# 31_9	grandmother	2)
# 		[(level: 0, coref_id: 99, bilou_tag: I) | (level: 1, coref_id: 2, bilou_tag: L)]
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 31_10	crying	99)|MSeg=cry-ing
#
# 		[(level: 0, coref_id: 99, bilou_tag: L)]
# 		[]
# 31_11	faded	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 31_12	in	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 31_13	his	(80-abstract-giv:inact-cf4-2-coref(1-person-giv:act-cf1-1-ana)
#
# 		[(level: 0, coref_id: 80, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 80, bilou_tag: B)]
# 31_14	memory	80)
#
# 		[(level: 0, coref_id: 80, bilou_tag: L)]
# 		[]
# 31_15	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 31_16	became	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 31_17	less	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 31_18	and	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 31_19	less	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 31_20	believable	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 31_21	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 32_1	Tyler	(1-person-giv:act-cf1*-1-coref)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 32_2	thought	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 32_3	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 32_4	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 32_5	very	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 32_6	lucky	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 32_7	to	(76-event-giv:act-cf3-3-disc
#
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_8	have	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_9	discovered	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_10	the	(77-abstract-giv:inact-cf4-3-coref
#
# 		[(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: B)]
# 		[(level: 0, coref_id: 76, bilou_tag: B) | (level: 1, coref_id: 77, bilou_tag: B)]
# 32_11	single	_
# 		[(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B) | (level: 1, coref_id: 77, bilou_tag: B)]
# 32_12	error	_
# 		[(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B) | (level: 1, coref_id: 77, bilou_tag: B)]
# 32_13	in	_
# 		[(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B) | (level: 1, coref_id: 77, bilou_tag: B)]
# 32_14	his	(99-abstract-giv:act-cf2-3-coref(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: I) | (level: 2, coref_id: 99, bilou_tag: B) | (level: 3, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 76, bilou_tag: B) | (level: 1, coref_id: 77, bilou_tag: B) | (level: 2, coref_id: 99, bilou_tag: B)]
# 32_15	false	_
# 		[(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: I) | (level: 2, coref_id: 99, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B) | (level: 1, coref_id: 77, bilou_tag: B) | (level: 2, coref_id: 99, bilou_tag: B)]
# 32_16	memory	99)77)
# 		[(level: 0, coref_id: 76, bilou_tag: I) | (level: 2, coref_id: 99, bilou_tag: L) | (level: 1, coref_id: 77, bilou_tag: L)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_17	,	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_18	which	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_19	enabled	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_20	him	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_21	to	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_22	reason	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_23	his	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_24	way	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_25	into	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_26	distinguishing	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_27	between	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_28	reality	(100-abstract-new-cf5-1-sgl)
# 		[(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 100, bilou_tag: U)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_29	and	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 32_30	fantasy	(101-abstract-new-cf6-1-sgl)76)
# 		[(level: 0, coref_id: 76, bilou_tag: L) | (level: 1, coref_id: 101, bilou_tag: U)]
# 		[]
# 32_31	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 33_1	He	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 33_2	felt	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 33_3	that	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 33_4	it	(76-event-giv:act-cf2-1-coref)
#
# 		[(level: 0, coref_id: 76, bilou_tag: U)]
# 		[]
# 33_5	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 33_6	a	(76-event-giv:act-cf2-7-coref
#
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 33_7	coming	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 33_8	-	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 33_9	of	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 33_10	-	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 33_11	age	_
# 		[(level: 0, coref_id: 76, bilou_tag: I)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 33_12	moment	76)
# 		[(level: 0, coref_id: 76, bilou_tag: L)]
# 		[]
# 33_13	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_1	Nonetheless	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_2	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_3	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 34_4	admitted	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_5	to	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_6	himself	(1-person-giv:act-cf1*-1-ana)
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 34_7	that	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_8	he	(1-person-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 34_9	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_10	a	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_11	little	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_12	sad	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_13	also	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_14	at	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 34_15	the	(76-event-giv:act-cf2-2-coref
#
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 		[(level: 0, coref_id: 76, bilou_tag: B)]
# 34_16	discovery	76)
# 		[(level: 0, coref_id: 76, bilou_tag: L)]
# 		[]
# 34_17	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 35_1	For	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 35_2	however	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 35_3	imaginary	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 35_4	that	(99-abstract-giv:inact-cf1-2-coref
#
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 35_5	memory	99)
#
# 		[(level: 0, coref_id: 99, bilou_tag: L)]
# 		[]
# 35_6	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 35_7	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 35_8	it	(99-abstract-giv:act-cf1-1-ana)
#
# 		[(level: 0, coref_id: 99, bilou_tag: U)]
# 		[]
# 35_9	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 35_10	also	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 35_11	a	(99-abstract-giv:act-cf1-2-pred
#
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 35_12	part	_
# 		[(level: 0, coref_id: 99, bilou_tag: I)]
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 35_13	of	_
# 		[(level: 0, coref_id: 99, bilou_tag: I)]
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 35_14	his	(26-abstract-giv:inact-cf4-2-coref(1-person-giv:act-cf2*-1-ana)
#
# 		[(level: 0, coref_id: 99, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: B) | (level: 2, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 99, bilou_tag: B) | (level: 1, coref_id: 26, bilou_tag: B)]
# 35_15	love	_
# 		[(level: 0, coref_id: 99, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: I)]
# 		[(level: 0, coref_id: 99, bilou_tag: B) | (level: 1, coref_id: 26, bilou_tag: B)]
# 35_16	for	_
# 		[(level: 0, coref_id: 99, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: I)]
# 		[(level: 0, coref_id: 99, bilou_tag: B) | (level: 1, coref_id: 26, bilou_tag: B)]
# 35_17	his	(2-person-giv:inact-cf3-2-coref(1-person-giv:act-cf2*-1-ana)
#
# 		[(level: 0, coref_id: 99, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: I) | (level: 2, coref_id: 2, bilou_tag: B) | (level: 3, coref_id: 1, bilou_tag: U)]
# 		[(level: 0, coref_id: 99, bilou_tag: B) | (level: 1, coref_id: 26, bilou_tag: B) | (level: 2, coref_id: 2, bilou_tag: B)]
# 35_18	grandmother	2)26)99)
# 		[(level: 0, coref_id: 99, bilou_tag: L) | (level: 2, coref_id: 2, bilou_tag: L) | (level: 1, coref_id: 26, bilou_tag: L)]
# 		[]
# 35_19	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 36_1	When	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 36_2	that	(99-abstract-giv:act-cf1*-2-coref
#
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 		[(level: 0, coref_id: 99, bilou_tag: B)]
# 36_3	memory	99)
#
# 		[(level: 0, coref_id: 99, bilou_tag: L)]
# 		[]
# 36_4	lost	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 36_5	its	(102-abstract-new-cf3-3-sgl(99-abstract-giv:act-cf1*-1-ana)
# 		[(level: 0, coref_id: 102, bilou_tag: B) | (level: 1, coref_id: 99, bilou_tag: U)]
# 		[(level: 0, coref_id: 102, bilou_tag: B)]
# 36_6	compelling	_
# 		[(level: 0, coref_id: 102, bilou_tag: I)]
# 		[(level: 0, coref_id: 102, bilou_tag: B)]
# 36_7	aura	_
# 		[(level: 0, coref_id: 102, bilou_tag: I)]
# 		[(level: 0, coref_id: 102, bilou_tag: B)]
# 36_8	of	_
# 		[(level: 0, coref_id: 102, bilou_tag: I)]
# 		[(level: 0, coref_id: 102, bilou_tag: B)]
# 36_9	truth	(103-abstract-new-cf4-1-sgl)102)
# 		[(level: 0, coref_id: 102, bilou_tag: L) | (level: 1, coref_id: 103, bilou_tag: U)]
# 		[]
# 36_10	,	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 36_11	it	(99-abstract-giv:act-cf1*-1-ana)
#
# 		[(level: 0, coref_id: 99, bilou_tag: U)]
# 		[]
# 36_12	was	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 36_13	like	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 36_14	another	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 36_15	part	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 36_16	of	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 36_17	her	(2-person-giv:act-cf2-1-ana)
#
# 		[(level: 0, coref_id: 2, bilou_tag: U)]
# 		[]
# 36_18	died	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 36_19	with	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 36_20	it	(99-abstract-giv:act-cf1*-1-ana)
# 		[(level: 0, coref_id: 99, bilou_tag: U)]
# 		[]
# 36_21	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 37_1	He	(1-person-giv:inact-cf1-1-ana)
#
# 		[(level: 0, coref_id: 1, bilou_tag: U)]
# 		[]
# 37_2	had	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]
# 37_3	no	(104-abstract-new-cf3-5-sgl
#
# 		[(level: 0, coref_id: 104, bilou_tag: B)]
# 		[(level: 0, coref_id: 104, bilou_tag: B)]
# 37_4	name	_
# 		[(level: 0, coref_id: 104, bilou_tag: I)]
# 		[(level: 0, coref_id: 104, bilou_tag: B)]
# 37_5	for	_
# 		[(level: 0, coref_id: 104, bilou_tag: I)]
# 		[(level: 0, coref_id: 104, bilou_tag: B)]
# 37_6	the	(105-abstract-new-cf2-2-sgl
#
# 		[(level: 0, coref_id: 104, bilou_tag: I) | (level: 1, coref_id: 105, bilou_tag: B)]
# 		[(level: 0, coref_id: 104, bilou_tag: B) | (level: 1, coref_id: 105, bilou_tag: B)]
# 37_7	emptiness	_
# 		[(level: 0, coref_id: 104, bilou_tag: I) | (level: 1, coref_id: 105, bilou_tag: I)]
# 		[(level: 0, coref_id: 104, bilou_tag: B) | (level: 1, coref_id: 105, bilou_tag: B)]
# 37_8	that	_
# 		[(level: 0, coref_id: 104, bilou_tag: I) | (level: 1, coref_id: 105, bilou_tag: I)]
# 		[(level: 0, coref_id: 104, bilou_tag: B) | (level: 1, coref_id: 105, bilou_tag: B)]
# 37_9	remained	105)104)
# 		[(level: 0, coref_id: 104, bilou_tag: L) | (level: 1, coref_id: 105, bilou_tag: L)]
# 		[]
# 37_10	.	_
# 		[(level: 0, coref_id: 0, bilou_tag: O)]
# 		[]

# %%
a = text_to_labels(text)
print(a)
# Out:
# 1	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	1	When	when	ADV	advmod	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	2	Tyler	Tyler	PROPN	nsubj	5	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	3	was	be	AUX	cop	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	4	very	very	ADV	advmod	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	5	young	young	ADJ	advcl	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	6	,	,	PUNCT	punct	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	7	his	his	PRON	nmod:poss	8	2	B-person	1	U-person	-100	O	-100	O	-100	O	-100	O
# 1	8	grandmother	grandmother	NOUN	nsubj	12	2	L-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	9	was	be	AUX	cop	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	10	his	his	PRON	nmod:poss	12	2	B-person	1	U-person	-100	O	-100	O	-100	O	-100	O
# 1	11	favorite	favorite	ADJ	amod	12	2	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	12	person	person	NOUN	root	0	2	L-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	13	in	in	ADP	case	15	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	14	the	the	DET	det	15	3	B-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	15	world	world	NOUN	nmod	12	3	L-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	16	because	because	SCONJ	mark	39	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	17	,	,	PUNCT	punct	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	18	unlike	unlike	ADP	case	20	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	19	his	his	PRON	nmod:poss	20	4	B-person	1	U-person	-100	O	-100	O	-100	O	-100	O
# 1	20	parents	parent	NOUN	obl	39	4	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	21	,	,	PUNCT	punct	23	4	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	22	who	who	PRON	nsubj	23	4	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	23	believed	believe	VERB	acl:relcl	20	4	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	24	that	that	SCONJ	mark	29	4	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	25	children	child	NOUN	nsubj:pass	29	4	I-person	5	U-person	-100	O	-100	O	-100	O	-100	O
# 1	26	should	should	AUX	aux	29	4	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	27	always	always	ADV	advmod	29	4	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	28	be	be	AUX	aux:pass	29	4	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	29	told	tell	VERB	ccomp	23	4	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	30	the	the	DET	det	31	4	I-person	6	B-abstract	-100	O	-100	O	-100	O	-100	O
# 1	31	truth	truth	NOUN	obj	29	4	I-person	6	L-abstract	-100	O	-100	O	-100	O	-100	O
# 1	32	as	as	SCONJ	mark	34	4	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	33	adults	adult	NOUN	nsubj	34	4	I-person	7	U-person	-100	O	-100	O	-100	O	-100	O
# 1	34	understood	understand	VERB	advcl	29	4	I-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	35	it	it	PRON	obj	34	4	L-person	6	U-abstract	-100	O	-100	O	-100	O	-100	O
# 1	36	,	,	PUNCT	punct	20	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	37	she	she	PRON	nsubj	39	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	38	would	would	AUX	aux	39	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	39	fill	fill	VERB	advcl	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	40	in	in	ADP	compound:prt	39	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	41	the	the	DET	det	42	8	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	42	gaps	gap	NOUN	obj	39	8	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	43	in	in	ADP	case	45	8	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	44	his	his	PRON	nmod:poss	45	8	I-abstract	9	B-abstract	1	U-person	-100	O	-100	O	-100	O
# 1	45	knowledge	knowledge	NOUN	nmod	42	8	L-abstract	9	L-abstract	-100	O	-100	O	-100	O	-100	O
# 1	46	—	—	PUNCT	punct	47	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	47	Santa	Santa	PROPN	appos	42	10	B-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	48	Claus	Claus	PROPN	flat	47	10	L-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	49	,	,	PUNCT	punct	52	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	50	the	the	DET	det	52	11	B-animal	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	51	Easter	Easter	PROPN	compound	52	11	I-animal	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	52	Bunny	Bunny	PROPN	conj	47	11	L-animal	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	53	,	,	PUNCT	punct	54	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	54	God	God	PROPN	conj	47	12	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	55	.	.	PUNCT	punct	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 1	56	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	1	His	his	PRON	nmod:poss	2	4	B-person	1	U-person	-100	O	-100	O	-100	O	-100	O
# 2	2	parents	parent	NOUN	nsubj	6	4	L-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	3	were	be	AUX	cop	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	4	always	always	ADV	advmod	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	5	too	too	ADV	advmod	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	6	busy	busy	ADJ	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	7	and	and	CCONJ	cc	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	8	often	often	ADV	advmod	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	9	a	a	DET	det	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	10	little	little	ADJ	obl:npmod	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	11	too	too	ADV	advmod	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	12	serious	serious	ADJ	conj	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	13	,	,	PUNCT	punct	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	14	but	but	CCONJ	cc	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	15	his	his	PRON	nmod:poss	16	2	B-person	1	U-person	-100	O	-100	O	-100	O	-100	O
# 2	16	grandmother	grandmother	NOUN	nsubj	17	2	L-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	17	had	have	VERB	conj	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	18	a	a	DET	det	19	13	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	19	sense	sense	NOUN	obj	17	13	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	20	of	of	ADP	case	21	13	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	21	peace	peace	NOUN	nmod	19	13	L-abstract	14	U-abstract	-100	O	-100	O	-100	O	-100	O
# 2	22	about	about	ADP	case	23	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	23	her	she	PRON	obl	17	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	24	,	,	PUNCT	punct	23	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	25	a	a	DET	det	26	15	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	26	lightness	lightness	NOUN	appos	19	15	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	27	that	that	PRON	nsubj	28	15	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	28	lifted	lift	VERB	acl:relcl	26	15	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	29	his	his	PRON	nmod:poss	30	15	I-abstract	16	B-abstract	1	U-person	-100	O	-100	O	-100	O
# 2	30	spirit	spirit	NOUN	obj	28	15	L-abstract	16	L-abstract	-100	O	-100	O	-100	O	-100	O
# 2	31	.	.	PUNCT	punct	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 2	32	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	1	A	a	DET	det	3	17	B-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	2	few	few	ADJ	amod	3	17	I-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	3	times	time	NOUN	obl:tmod	13	17	L-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	4	,	,	PUNCT	punct	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	5	when	when	ADV	advmod	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	6-7	Tyler’s	_	_	_	_	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	6	Tyler	Tyler	PROPN	nmod:poss	8	4	B-person	1	B-person	-100	O	-100	O	-100	O	-100	O
# 3	7	’s	's	PART	case	6	4	I-person	1	L-person	-100	O	-100	O	-100	O	-100	O
# 3	8	parents	parent	NOUN	nsubj	10	4	L-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	9	were	be	AUX	cop	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	10	away	away	ADV	advcl	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	11	,	,	PUNCT	punct	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	12	she	she	PRON	nsubj	13	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	13	took	take	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	14	him	he	PRON	obj	13	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	15	with	with	ADP	case	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	16	her	she	PRON	obl	13	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	17	to	to	ADP	case	18	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	18	church	church	NOUN	obl	13	18	U-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	19	.	.	PUNCT	punct	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 3	21	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	1	He	he	PRON	nsubj	2	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	2	remembered	remember	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	3	liking	like	VERB	xcomp	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	4	the	the	DET	det	5	19	B-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	5	singing	singing	NOUN	obj	3	19	L-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	6	and	and	CCONJ	cc	9	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	7	the	the	DET	det	9	20	B-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	8	colorful	colorful	ADJ	amod	9	20	I-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	9	windows	window	NOUN	conj	5	20	L-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	10	,	,	PUNCT	punct	15	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	11	and	and	CCONJ	cc	15	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	12	how	how	ADV	advmod	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	13	safe	safe	ADJ	xcomp	15	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	14	he	he	PRON	nsubj	15	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	15	felt	feel	VERB	conj	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	16	there	there	ADV	advmod	15	18	U-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	17	,	,	PUNCT	punct	18	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	18	in	in	ADP	case	23	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	19	that	that	DET	det	23	18	B-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	20	large	large	ADJ	amod	23	18	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	21	,	,	PUNCT	punct	20	18	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	22	empty	empty	ADJ	amod	23	18	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	23	space	space	NOUN	obl	15	18	L-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	24	,	,	PUNCT	punct	25	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	25	sitting	sit	VERB	advcl	15	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	26	on	on	ADP	case	29	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	27	a	a	DET	det	29	21	B-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	28	hard	hard	ADJ	amod	29	21	I-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	29	bench	bench	NOUN	obl	25	21	L-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	30	next	next	ADV	advmod	25	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	31	to	to	ADP	case	33	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	32	her	her	PRON	nmod:poss	33	22	B-abstract	2	U-person	-100	O	-100	O	-100	O	-100	O
# 4	33	warmth	warmth	NOUN	obl	30	22	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	34	.	.	PUNCT	punct	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 4	35	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 5	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 5	1	When	when	ADV	advmod	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 5	2	she	she	PRON	nsubj	3	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 5	3	died	die	VERB	advcl	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 5	4	,	,	PUNCT	punct	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 5	5	grief	grief	NOUN	nsubj	6	23	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 5	6	overwhelmed	overwhelm	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 5	7	Tyler	Tyler	PROPN	obj	6	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 5	8	.	.	PUNCT	punct	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 5	9	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	1	But	but	CCONJ	cc	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	2	like	like	ADP	case	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	3	most	most	ADJ	amod	4	24	B-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	4	adults	adult	NOUN	obl	13	24	L-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	5	,	,	PUNCT	punct	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	6	when	when	ADV	advmod	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	7	he	he	PRON	nsubj	8	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	8	grew	grow	VERB	advcl	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	9	older	old	ADJ	xcomp	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	10	he	he	PRON	nsubj	13	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	11	could	could	AUX	aux	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	12	only	only	ADV	advmod	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	13	recall	recall	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	14	the	the	DET	det	15	25	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	15	intensity	intensity	NOUN	obj	13	25	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	16	of	of	ADP	case	18	25	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	17	that	that	DET	det	18	25	I-abstract	26	B-abstract	-100	O	-100	O	-100	O	-100	O
# 6	18	love	love	NOUN	nmod	15	25	I-abstract	26	L-abstract	-100	O	-100	O	-100	O	-100	O
# 6	19	in	in	ADP	case	20	25	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	20	childhood	childhood	NOUN	nmod	18	25	L-abstract	27	U-time	-100	O	-100	O	-100	O	-100	O
# 6	21	in	in	ADP	case	24	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	22	an	a	DET	det	24	28	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	23	abstract	abstract	ADJ	amod	24	28	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	24	way	way	NOUN	obl	13	28	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	25	.	.	PUNCT	punct	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 6	26	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	1	He	he	PRON	nsubj	2	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	2	made	make	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	3	the	the	DET	det	5	29	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	4	common	common	ADJ	amod	5	29	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	5	error	error	NOUN	obj	2	29	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	6	of	of	SCONJ	mark	7	29	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	7	identifying	identify	VERB	acl	5	29	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	8	maturity	maturity	NOUN	obj	7	29	I-abstract	30	U-abstract	-100	O	-100	O	-100	O	-100	O
# 7	9	with	with	ADP	case	10	29	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	10	worth	worth	NOUN	obl	7	29	L-abstract	31	U-abstract	-100	O	-100	O	-100	O	-100	O
# 7	11	,	,	PUNCT	punct	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	12	and	and	CCONJ	cc	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	13	assumed	assume	VERB	conj	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	14	that	that	SCONJ	mark	28	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	15	the	the	DET	det	16	26	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	16	love	love	NOUN	nsubj	28	26	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	17	he	he	PRON	nsubj	18	26	I-abstract	1	U-person	-100	O	-100	O	-100	O	-100	O
# 7	18	had	have	VERB	acl:relcl	16	26	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	19	for	for	ADP	case	20	26	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	20	her	she	PRON	obl	18	26	I-abstract	2	U-person	-100	O	-100	O	-100	O	-100	O
# 7	21	as	as	ADP	case	24	26	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	22	a	a	DET	det	24	26	I-abstract	1	B-person	-100	O	-100	O	-100	O	-100	O
# 7	23	young	young	ADJ	amod	24	26	I-abstract	1	I-person	-100	O	-100	O	-100	O	-100	O
# 7	24	child	child	NOUN	obl	18	26	L-abstract	1	L-person	-100	O	-100	O	-100	O	-100	O
# 7	25	must	must	AUX	aux	28	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	26	have	have	AUX	aux	28	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	27	been	be	AUX	aux	28	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	28	lacking	lack	VERB	ccomp	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	29	in	in	ADP	case	30	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	30	strength	strength	NOUN	obl	28	32	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	31	and	and	CCONJ	cc	32	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	32	depth	depth	NOUN	conj	30	33	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	33	.	.	PUNCT	punct	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 7	34	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	1	For	for	ADP	case	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	2	many	many	ADJ	amod	3	34	B-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	3	years	year	NOUN	obl	12	34	I-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	4	after	after	ADP	case	6	34	I-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	5	her	her	PRON	nmod:poss	6	34	I-time	35	B-event	2	U-person	-100	O	-100	O	-100	O
# 8	6	death	death	NOUN	nmod	3	34	L-time	35	L-event	-100	O	-100	O	-100	O	-100	O
# 8	7	,	,	PUNCT	punct	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	8	however	however	ADV	advmod	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	9	,	,	PUNCT	punct	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	10	Tyler	Tyler	PROPN	nsubj:pass	12	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	11	was	be	AUX	aux:pass	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	12	tortured	torture	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	13	by	by	ADP	case	15	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	14	the	the	DET	det	15	36	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	15	memory	memory	NOUN	obl:agent	12	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	16	of	of	ADP	case	19	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	17	a	a	DET	det	19	36	I-abstract	37	B-event	-100	O	-100	O	-100	O	-100	O
# 8	18	certain	certain	ADJ	amod	19	36	I-abstract	37	I-event	-100	O	-100	O	-100	O	-100	O
# 8	19	visit	visit	NOUN	nmod	15	36	I-abstract	37	I-event	-100	O	-100	O	-100	O	-100	O
# 8	20	from	from	ADP	case	21	36	I-abstract	37	I-event	-100	O	-100	O	-100	O	-100	O
# 8	21	her	she	PRON	nmod	19	36	L-abstract	2	U-person	37	L-event	-100	O	-100	O	-100	O
# 8	22	.	.	PUNCT	punct	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 8	23	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	1	He	he	PRON	nsubj	3	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	2	was	be	AUX	cop	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	3	five	five	NUM	root	0	38	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	4	or	or	CCONJ	cc	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	5	so	so	ADV	conj	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	6	,	,	PUNCT	punct	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	7	and	and	CCONJ	cc	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	8	they	they	PRON	nsubj	10	39	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	9	were	be	AUX	aux	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	10	playing	play	VERB	conj	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	11	some	some	DET	det	13	40	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	12	board	board	NOUN	compound	13	40	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	13	game	game	NOUN	obj	10	40	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	14	at	at	ADP	case	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	15	the	the	DET	det	17	41	B-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	16	kitchen	kitchen	NOUN	compound	17	41	I-object	42	U-place	-100	O	-100	O	-100	O	-100	O
# 9	17	table	table	NOUN	obl	10	41	L-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	18	.	.	PUNCT	punct	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 9	19	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	1	As	as	SCONJ	mark	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	2	he	he	PRON	nsubj	3	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	3	swung	swing	VERB	advcl	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	4	his	his	PRON	nmod:poss	5	43	B-object	1	U-person	-100	O	-100	O	-100	O	-100	O
# 10	5	legs	leg	NOUN	obj	3	43	L-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	6	in	in	ADP	case	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	7	his	his	PRON	nmod:poss	8	44	B-abstract	1	U-person	-100	O	-100	O	-100	O	-100	O
# 10	8	excitement	excitement	NOUN	obl	3	44	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	9	,	,	PUNCT	punct	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	10	he	he	PRON	nsubj	11	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	11	kicked	kick	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	12	her	she	PRON	obj	11	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	13	repeatedly	repeatedly	ADV	advmod	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	14	in	in	ADP	case	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	15	the	the	DET	det	16	45	B-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	16	shins	shin	NOUN	obl	11	45	L-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	17	.	.	PUNCT	punct	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 10	18	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	1	She	she	PRON	nsubj	2	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	2	asked	ask	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	3	him	he	PRON	iobj	2	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	4	to	to	PART	mark	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	5	stop	stop	VERB	xcomp	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	6	,	,	PUNCT	punct	9	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	7	and	and	CCONJ	cc	9	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	8	he	he	PRON	nsubj	9	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	9	refused	refuse	VERB	conj	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	10	,	,	PUNCT	punct	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	11	giggling	giggle	VERB	advcl	9	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	12	.	.	PUNCT	punct	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 11	13	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	1	When	when	ADV	advmod	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	2	she	she	PRON	nsubj	4	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	3	finally	finally	ADV	advmod	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	4	frowned	frown	VERB	advcl	18	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	5	at	at	ADP	case	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	6	him	he	PRON	obl	4	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	7	and	and	CCONJ	cc	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	8	threatened	threaten	VERB	conj	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	9	to	to	PART	mark	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	10	stop	stop	VERB	xcomp	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	11	playing	play	VERB	xcomp	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	12	if	if	SCONJ	mark	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	13	he	he	PRON	nsubj	16	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	14-15	didn’t	_	_	_	_	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	14	did	do	AUX	aux	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	15	n’t	not	PART	advmod	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	16	stop	stop	VERB	advcl	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	17	he	he	PRON	nsubj	18	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	18	told	tell	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	19	her	she	PRON	iobj	18	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	20	to	to	PART	mark	21	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	21	go	go	VERB	xcomp	18	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	22	to	to	ADP	case	23	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	23	Hell	Hell	PROPN	obl	21	46	U-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	24	.	.	PUNCT	punct	18	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 12	26	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	1	In	in	ADP	case	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	2-3	Tyler’s	_	_	_	_	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	2	Tyler	Tyler	PROPN	nmod:poss	4	47	B-abstract	1	B-person	-100	O	-100	O	-100	O	-100	O
# 13	3	’s	's	PART	case	2	47	I-abstract	1	L-person	-100	O	-100	O	-100	O	-100	O
# 13	4	mind	mind	NOUN	obl	7	47	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	5	he	he	PRON	nsubj	7	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	6	could	could	AUX	aux	7	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	7	see	see	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	8	her	her	PRON	nmod:poss	9	48	B-object	2	U-person	-100	O	-100	O	-100	O	-100	O
# 13	9	face	face	NOUN	obj	7	48	L-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	10	grow	grow	VERB	xcomp	7	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	11	taut	taut	ADJ	xcomp	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	12	,	,	PUNCT	punct	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	13	lose	lose	VERB	conj	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	14	color	color	NOUN	obj	13	49	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	15	,	,	PUNCT	punct	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	16	and	and	CCONJ	cc	28	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	17	then	then	ADV	advmod	28	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	18	,	,	PUNCT	punct	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	19	for	for	ADP	case	22	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	20	the	the	DET	det	22	50	B-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	21	only	only	ADJ	amod	22	50	I-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	22	time	time	NOUN	obl	28	50	I-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	23	he	he	PRON	nsubj	25	50	I-time	1	U-person	-100	O	-100	O	-100	O	-100	O
# 13	24	could	could	AUX	aux	25	50	I-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	25	remember	remember	VERB	acl:relcl	22	50	L-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	26	,	,	PUNCT	punct	22	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	27	she	she	PRON	nsubj	28	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	28	began	begin	VERB	conj	7	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	29	to	to	PART	mark	30	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	30	cry	cry	VERB	xcomp	28	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	31	.	.	PUNCT	punct	7	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 13	33	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 14	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 14	1	He	he	PRON	nsubj	3	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 14	2	also	also	ADV	advmod	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 14	3	remembered	remember	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 14	4	his	his	PRON	nmod:poss	7	51	B-abstract	1	U-person	-100	O	-100	O	-100	O	-100	O
# 14	5	own	own	ADJ	amod	7	51	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 14	6	utter	utter	ADJ	amod	7	51	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 14	7	confusion	confusion	NOUN	obj	3	51	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 14	8	.	.	PUNCT	punct	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 14	9	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	1	His	his	PRON	nmod:poss	2	4	B-person	1	U-person	-100	O	-100	O	-100	O	-100	O
# 15	2	parents	parent	NOUN	nsubj	5	4	L-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	3	did	do	AUX	aux	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	4	not	not	PART	advmod	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	5	have	have	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	6	much	much	ADJ	amod	7	52	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	7	use	use	NOUN	obj	5	52	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	8	for	for	ADP	case	9	52	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	9	religion	religion	NOUN	nmod	7	52	L-abstract	53	U-abstract	-100	O	-100	O	-100	O	-100	O
# 15	10	and	and	CCONJ	cc	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	11	so	so	ADV	advmod	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	12	for	for	ADP	case	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	13	him	he	PRON	nmod	17	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	14	Hell	Hell	PROPN	nsubj	17	54	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	15	was	be	AUX	cop	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	16	a	a	DET	det	17	54	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	17	word	word	NOUN	conj	5	54	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	18	without	without	ADP	case	20	54	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	19	much	much	ADJ	amod	20	54	I-abstract	55	B-abstract	-100	O	-100	O	-100	O	-100	O
# 15	20	mystery	mystery	NOUN	nmod	17	54	I-abstract	55	L-abstract	-100	O	-100	O	-100	O	-100	O
# 15	21	or	or	CCONJ	cc	22	54	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	22	power	power	NOUN	conj	20	54	L-abstract	56	U-abstract	-100	O	-100	O	-100	O	-100	O
# 15	23	.	.	PUNCT	punct	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 15	24	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	1	At	at	ADP	case	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	2	that	that	DET	det	3	57	B-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	3	time	time	NOUN	obl	5	57	L-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	4	he	he	PRON	nsubj	5	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	5	knew	know	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	6	only	only	ADV	advmod	7	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	7	vaguely	vaguely	ADV	advmod	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	8	that	that	SCONJ	mark	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	9	Hell	Hell	PROPN	nsubj	12	46	U-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	10	was	be	AUX	cop	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	11	a	a	DET	det	12	46	B-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	12	place	place	NOUN	ccomp	5	46	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	13	you	you	PRON	nsubj	16	46	I-place	58	U-person	-100	O	-100	O	-100	O	-100	O
# 16	14	did	do	AUX	aux	16	46	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	15	not	not	PART	advmod	16	46	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	16	want	want	VERB	acl:relcl	12	46	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	17	to	to	PART	mark	18	46	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	18	go	go	VERB	xcomp	16	46	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	19	,	,	PUNCT	punct	23	46	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	20	like	like	ADP	case	23	46	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	21	the	the	DET	det	23	46	I-place	59	B-place	-100	O	-100	O	-100	O	-100	O
# 16	22	dark	dark	ADJ	amod	23	46	I-place	59	I-place	-100	O	-100	O	-100	O	-100	O
# 16	23	basement	basement	NOUN	obl	12	46	I-place	59	L-place	-100	O	-100	O	-100	O	-100	O
# 16	24	or	or	CCONJ	cc	28	46	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	25	the	the	DET	det	28	46	I-place	60	B-place	-100	O	-100	O	-100	O	-100	O
# 16	26	even	even	ADV	advmod	27	46	I-place	60	I-place	-100	O	-100	O	-100	O	-100	O
# 16	27	darker	dark	ADJ	amod	28	46	I-place	60	I-place	-100	O	-100	O	-100	O	-100	O
# 16	28	attic	attic	NOUN	conj	23	46	L-place	60	L-place	-100	O	-100	O	-100	O	-100	O
# 16	29	.	.	PUNCT	punct	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 16	30	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	1	He	he	PRON	nsubj	2	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	2	remembered	remember	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	3	feeling	feel	VERB	ccomp	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	4	resentful	resentful	ADJ	xcomp	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	5	that	that	SCONJ	mark	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	6	she	she	PRON	nsubj	8	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	7	was	be	AUX	aux	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	8	crying	cry	VERB	ccomp	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	9	and	and	CCONJ	cc	14	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	10	he	he	PRON	nsubj	14	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	11	did	do	AUX	aux	14	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	12	not	not	PART	advmod	14	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	13	even	even	ADV	advmod	14	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	14	understand	understand	VERB	conj	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	15	why	why	ADV	ccomp	14	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	16	.	.	PUNCT	punct	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 17	17	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	1	Tyler	Tyler	PROPN	nsubj	2	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	2	felt	feel	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	3	the	the	DET	det	4	61	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	4	guilt	guilt	NOUN	obj	2	61	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	5	of	of	ADP	case	7	61	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	6	this	this	DET	det	7	61	I-abstract	36	B-abstract	-100	O	-100	O	-100	O	-100	O
# 18	7	memory	memory	NOUN	nmod	4	61	L-abstract	36	L-abstract	-100	O	-100	O	-100	O	-100	O
# 18	8	even	even	ADV	advmod	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	9	in	in	ADP	case	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	10	his	his	PRON	nmod:poss	12	62	B-time	1	U-person	-100	O	-100	O	-100	O	-100	O
# 18	11	teenage	teenage	ADJ	amod	12	62	I-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	12	years	year	NOUN	obl	2	62	L-time	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	13	.	.	PUNCT	punct	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 18	14	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	1	For	for	ADP	case	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	2	him	he	PRON	obl	4	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	3	it	it	PRON	nsubj	4	36	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	4	summed	sum	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	5	up	up	ADP	compound:prt	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	6	all	all	DET	det:predet	8	63	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	7	his	his	PRON	nmod:poss	8	63	I-abstract	1	U-person	-100	O	-100	O	-100	O	-100	O
# 19	8	insecurities	insecurity	NOUN	obj	4	63	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	9	and	and	CCONJ	cc	10	63	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	10	fears	fear	NOUN	conj	8	63	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	11	about	about	ADP	case	14	63	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	12	his	his	PRON	nmod:poss	14	63	I-abstract	64	B-abstract	1	U-person	-100	O	-100	O	-100	O
# 19	13	own	own	ADJ	amod	14	63	I-abstract	64	I-abstract	-100	O	-100	O	-100	O	-100	O
# 19	14	cruelty	cruelty	NOUN	nmod	8	63	I-abstract	64	L-abstract	-100	O	-100	O	-100	O	-100	O
# 19	15	,	,	PUNCT	punct	16	63	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	16	ignorance	ignorance	NOUN	conj	14	63	I-abstract	65	U-abstract	-100	O	-100	O	-100	O	-100	O
# 19	17	,	,	PUNCT	punct	20	63	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	18	and	and	CCONJ	cc	20	63	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	19	the	the	DET	det	20	63	I-abstract	66	B-abstract	-100	O	-100	O	-100	O	-100	O
# 19	20	possibility	possibility	NOUN	conj	14	63	I-abstract	66	I-abstract	-100	O	-100	O	-100	O	-100	O
# 19	21	that	that	SCONJ	mark	31	63	I-abstract	66	I-abstract	-100	O	-100	O	-100	O	-100	O
# 19	22	he	he	PRON	nsubj	31	63	I-abstract	66	I-abstract	1	U-person	-100	O	-100	O	-100	O
# 19	23	was	be	AUX	cop	31	63	I-abstract	66	I-abstract	-100	O	-100	O	-100	O	-100	O
# 19	24	,	,	PUNCT	punct	23	63	I-abstract	66	I-abstract	-100	O	-100	O	-100	O	-100	O
# 19	25	in	in	ADP	case	26	63	I-abstract	66	I-abstract	-100	O	-100	O	-100	O	-100	O
# 19	26	reality	reality	NOUN	obl	31	63	I-abstract	66	I-abstract	-100	O	-100	O	-100	O	-100	O
# 19	27	,	,	PUNCT	punct	26	63	I-abstract	66	I-abstract	-100	O	-100	O	-100	O	-100	O
# 19	28	not	not	PART	advmod	31	63	I-abstract	66	I-abstract	-100	O	-100	O	-100	O	-100	O
# 19	29	a	a	DET	det	31	63	I-abstract	66	I-abstract	67	B-person	-100	O	-100	O	-100	O
# 19	30	good	good	ADJ	amod	31	63	I-abstract	66	I-abstract	67	I-person	-100	O	-100	O	-100	O
# 19	31	person	person	NOUN	acl	20	63	L-abstract	67	L-person	66	L-abstract	-100	O	-100	O	-100	O
# 19	32	.	.	PUNCT	punct	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 19	33	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	1	The	the	DET	det	2	68	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	2	fact	fact	NOUN	nsubj	19	68	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	3	that	that	SCONJ	mark	6	68	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	4	he	he	PRON	nsubj	6	68	I-abstract	1	U-person	-100	O	-100	O	-100	O	-100	O
# 20	5	had	have	AUX	aux	6	68	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	6	caused	cause	VERB	acl	2	68	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	7	someone	someone	PRON	iobj	6	68	I-abstract	2	B-person	-100	O	-100	O	-100	O	-100	O
# 20	8	who	who	PRON	nsubj	9	68	I-abstract	2	I-person	-100	O	-100	O	-100	O	-100	O
# 20	9	loved	love	VERB	acl:relcl	7	68	I-abstract	2	I-person	-100	O	-100	O	-100	O	-100	O
# 20	10	him	he	PRON	obj	9	68	I-abstract	1	U-person	2	L-person	-100	O	-100	O	-100	O
# 20	11	such	such	ADJ	amod	12	68	I-abstract	69	B-abstract	-100	O	-100	O	-100	O	-100	O
# 20	12	pain	pain	NOUN	obj	6	68	I-abstract	69	L-abstract	-100	O	-100	O	-100	O	-100	O
# 20	13	with	with	ADP	case	16	68	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	14	so	so	ADV	advmod	15	68	I-abstract	70	B-abstract	-100	O	-100	O	-100	O	-100	O
# 20	15	little	little	ADJ	amod	16	68	I-abstract	70	I-abstract	-100	O	-100	O	-100	O	-100	O
# 20	16	effort	effort	NOUN	obl	6	68	I-abstract	70	I-abstract	-100	O	-100	O	-100	O	-100	O
# 20	17	and	and	CCONJ	cc	18	68	I-abstract	70	I-abstract	-100	O	-100	O	-100	O	-100	O
# 20	18	understanding	understanding	NOUN	conj	16	68	L-abstract	70	L-abstract	-100	O	-100	O	-100	O	-100	O
# 20	19	troubled	trouble	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	20	him	he	PRON	obj	19	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	21	deeply	deeply	ADV	advmod	19	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	22	.	.	PUNCT	punct	19	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 20	23	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	1	One	one	NUM	nummod	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	2	day	day	NOUN	obl:tmod	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	3	Tyler	Tyler	PROPN	nsubj	4	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	4	looked	look	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	5	through	through	ADP	case	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	6	an	a	DET	det	10	71	B-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	7	old	old	ADJ	amod	10	71	I-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	8	family	family	NOUN	compound	10	71	I-object	72	U-person	-100	O	-100	O	-100	O	-100	O
# 21	9	photo	photo	NOUN	compound	10	71	I-object	73	U-object	-100	O	-100	O	-100	O	-100	O
# 21	10	album	album	NOUN	obl	4	71	L-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	11	,	,	PUNCT	punct	14	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	12	and	and	CCONJ	cc	14	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	13	in	in	ADP	case	14	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	14	it	it	PRON	conj	4	71	U-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	15	was	be	AUX	cop	14	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	16	a	a	DET	det	17	74	B-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	17	picture	picture	NOUN	nsubj	14	74	I-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	18	of	of	ADP	case	20	74	I-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	19	the	the	DET	det	20	74	I-object	42	B-place	-100	O	-100	O	-100	O	-100	O
# 21	20	kitchen	kitchen	NOUN	nmod	17	74	I-object	42	L-place	-100	O	-100	O	-100	O	-100	O
# 21	21	in	in	ADP	case	23	74	I-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	22	the	the	DET	det	23	74	I-object	75	B-place	-100	O	-100	O	-100	O	-100	O
# 21	23	house	house	NOUN	nmod	20	74	I-object	75	I-place	-100	O	-100	O	-100	O	-100	O
# 21	24	they	they	PRON	nsubj	25	74	I-object	75	I-place	72	U-person	-100	O	-100	O	-100	O
# 21	25	used	use	VERB	acl:relcl	23	74	I-object	75	I-place	-100	O	-100	O	-100	O	-100	O
# 21	26	to	to	PART	mark	27	74	I-object	75	I-place	-100	O	-100	O	-100	O	-100	O
# 21	27	live	live	VERB	xcomp	25	74	I-object	75	I-place	-100	O	-100	O	-100	O	-100	O
# 21	28	in	in	ADP	obl	27	74	L-object	75	L-place	-100	O	-100	O	-100	O	-100	O
# 21	29	.	.	PUNCT	punct	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 21	30	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 22	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 22	1	He	he	PRON	nsubj:pass	3	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 22	2	was	be	AUX	aux:pass	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 22	3	surprised	surprise	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 22	4	to	to	PART	mark	5	76	B-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 22	5	discover	discover	VERB	xcomp	3	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 22	6	that	that	SCONJ	mark	10	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 22	7	the	the	DET	det	9	76	I-event	77	B-abstract	42	B-place	-100	O	-100	O	-100	O
# 22	8	small	small	ADJ	amod	9	76	I-event	77	I-abstract	42	I-place	-100	O	-100	O	-100	O
# 22	9	kitchen	kitchen	NOUN	nsubj	10	76	I-event	77	I-abstract	42	L-place	-100	O	-100	O	-100	O
# 22	10	contained	contain	VERB	ccomp	5	76	I-event	77	I-abstract	-100	O	-100	O	-100	O	-100	O
# 22	11	a	a	DET	det	13	76	I-event	77	I-abstract	78	B-object	-100	O	-100	O	-100	O
# 22	12	central	central	ADJ	amod	13	76	I-event	77	I-abstract	78	I-object	-100	O	-100	O	-100	O
# 22	13	island	island	NOUN	obj	10	76	I-event	77	I-abstract	78	L-object	-100	O	-100	O	-100	O
# 22	14	,	,	PUNCT	punct	16	76	I-event	77	I-abstract	-100	O	-100	O	-100	O	-100	O
# 22	15	and	and	CCONJ	cc	16	76	I-event	77	I-abstract	-100	O	-100	O	-100	O	-100	O
# 22	16	had	have	VERB	conj	10	76	I-event	77	I-abstract	-100	O	-100	O	-100	O	-100	O
# 22	17	no	no	DET	det	18	76	I-event	77	I-abstract	79	B-place	-100	O	-100	O	-100	O
# 22	18	space	space	NOUN	obj	16	76	I-event	77	I-abstract	79	I-place	-100	O	-100	O	-100	O
# 22	19	for	for	ADP	case	21	76	I-event	77	I-abstract	79	I-place	-100	O	-100	O	-100	O
# 22	20	the	the	DET	det	21	76	I-event	77	I-abstract	79	I-place	41	B-object	-100	O	-100	O
# 22	21	table	table	NOUN	nmod	18	76	I-event	77	I-abstract	79	I-place	41	I-object	-100	O	-100	O
# 22	22	in	in	ADP	case	24	76	I-event	77	I-abstract	79	I-place	41	I-object	-100	O	-100	O
# 22	23	his	his	PRON	nmod:poss	24	76	I-event	77	I-abstract	79	I-place	41	I-object	80	B-abstract	1	U-person
# 22	24	memory	memory	NOUN	nmod	21	76	I-event	77	I-abstract	80	L-abstract	41	L-object	79	L-place	-100	O
# 22	25	at	at	ADP	case	26	76	I-event	77	I-abstract	-100	O	-100	O	-100	O	-100	O
# 22	26	all	all	DET	obl	16	76	L-event	77	L-abstract	-100	O	-100	O	-100	O	-100	O
# 22	27	.	.	PUNCT	punct	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 22	28	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 23	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 23	1	With	with	ADP	case	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 23	2	the	the	DET	det	3	76	B-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 23	3	discovery	discovery	NOUN	obl	11	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 23	4	of	of	ADP	case	7	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 23	5	that	that	DET	det	7	76	I-event	77	B-abstract	-100	O	-100	O	-100	O	-100	O
# 23	6	single	single	ADJ	amod	7	76	I-event	77	I-abstract	-100	O	-100	O	-100	O	-100	O
# 23	7	error	error	NOUN	nmod	3	76	I-event	77	I-abstract	-100	O	-100	O	-100	O	-100	O
# 23	8	in	in	ADP	case	10	76	I-event	77	I-abstract	-100	O	-100	O	-100	O	-100	O
# 23	9	his	his	PRON	nmod:poss	10	76	I-event	77	I-abstract	80	B-abstract	1	U-person	-100	O	-100	O
# 23	10	memory	memory	NOUN	nmod	7	76	L-event	80	L-abstract	77	L-abstract	-100	O	-100	O	-100	O
# 23	11	came	come	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 23	12	a	a	DET	det	13	81	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 23	13	cascade	cascade	NOUN	obj	11	81	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 23	14	of	of	ADP	case	16	81	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 23	15	other	other	ADJ	amod	16	81	I-abstract	82	B-abstract	-100	O	-100	O	-100	O	-100	O
# 23	16	revelations	revelation	NOUN	nmod	13	81	L-abstract	82	L-abstract	-100	O	-100	O	-100	O	-100	O
# 23	17	.	.	PUNCT	punct	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 23	18	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	1	Now	now	ADV	advmod	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	2	he	he	PRON	nsubj	3	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	3	remembered	remember	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	4	that	that	SCONJ	mark	7	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	5	they	they	PRON	nsubj	7	72	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	6	always	always	ADV	advmod	7	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	7	ate	eat	VERB	ccomp	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	8	in	in	ADP	case	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	9	the	the	DET	det	11	83	B-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	10	dining	dining	NOUN	compound	11	83	I-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	11	room	room	NOUN	obl	7	83	L-place	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	12	,	,	PUNCT	punct	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	13	and	and	CCONJ	cc	27	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	14	when	when	ADV	advmod	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	15	they	they	PRON	nsubj	17	72	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	16	did	do	AUX	aux	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	17	play	play	VERB	advcl	27	84	B-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	18	board	board	NOUN	compound	19	84	I-event	85	B-abstract	-100	O	-100	O	-100	O	-100	O
# 24	19	games	game	NOUN	obj	17	84	L-event	85	L-abstract	-100	O	-100	O	-100	O	-100	O
# 24	20	,	,	PUNCT	punct	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	21	it	it	PRON	nsubj	27	84	U-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	22	was	be	AUX	cop	27	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	23	always	always	ADV	advmod	27	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	24	on	on	ADP	case	27	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	25	the	the	DET	det	27	86	B-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	26	coffee	coffee	NOUN	compound	27	86	I-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	27	table	table	NOUN	conj	3	86	I-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	28	in	in	ADP	case	31	86	I-object	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	29	the	the	DET	det	31	86	I-object	87	B-place	-100	O	-100	O	-100	O	-100	O
# 24	30	living	living	NOUN	compound	31	86	I-object	87	I-place	-100	O	-100	O	-100	O	-100	O
# 24	31	room	room	NOUN	nmod	27	86	L-object	87	L-place	-100	O	-100	O	-100	O	-100	O
# 24	32	.	.	PUNCT	punct	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 24	33	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	1	The	the	DET	det	2	36	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	2	memory	memory	NOUN	nsubj	16	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	3	that	that	PRON	nsubj	5	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	4	had	have	AUX	aux	5	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	5	caused	cause	VERB	acl:relcl	2	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	6	him	he	PRON	iobj	5	36	I-abstract	1	U-person	-100	O	-100	O	-100	O	-100	O
# 25	7	such	such	ADJ	amod	8	36	I-abstract	88	B-abstract	-100	O	-100	O	-100	O	-100	O
# 25	8	pain	pain	NOUN	obj	5	36	I-abstract	88	L-abstract	-100	O	-100	O	-100	O	-100	O
# 25	9	over	over	ADP	case	11	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	10	the	the	DET	det	11	36	I-abstract	34	B-time	-100	O	-100	O	-100	O	-100	O
# 25	11	years	year	NOUN	obl	5	36	L-abstract	34	L-time	-100	O	-100	O	-100	O	-100	O
# 25	12	could	could	AUX	aux	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	13	not	not	PART	advmod	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	14	possibly	possibly	ADV	advmod	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	15	have	have	AUX	aux	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	16	occurred	occur	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	17	.	.	PUNCT	punct	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 25	18	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 26	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 26	1	Somehow	somehow	ADV	advmod	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 26	2	,	,	PUNCT	punct	1	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 26	3	he	he	PRON	nsubj	6	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 26	4	must	must	AUX	aux	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 26	5	have	have	AUX	aux	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 26	6	manufactured	manufacture	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 26	7	the	the	DET	det	9	36	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 26	8	whole	whole	ADJ	amod	9	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 26	9	scene	scene	NOUN	obj	6	36	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# ...
# 27	9	really	really	ADV	advmod	10	90	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 27	10	happened	happen	VERB	acl:relcl	8	90	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 27	11	,	,	PUNCT	punct	13	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 27	12	he	he	PRON	nsubj	13	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 27	13	thought	think	VERB	parataxis	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 27	14	.	.	PUNCT	punct	5	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 27	15	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	1	The	the	DET	det	2	35	B-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	2	death	death	NOUN	nsubj	8	35	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	3	of	of	ADP	case	5	35	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	4	his	his	PRON	nmod:poss	5	35	I-event	2	B-person	1	U-person	-100	O	-100	O	-100	O
# 28	5	grandmother	grandmother	NOUN	nmod	2	35	L-event	2	L-person	-100	O	-100	O	-100	O	-100	O
# 28	6	had	have	AUX	aux	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	7	probably	probably	ADV	advmod	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	8	caused	cause	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	9	in	in	ADP	case	10	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	10	him	he	PRON	obl	8	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	11	feelings	feeling	NOUN	obj	8	91	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	12	of	of	ADP	case	13	91	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	13	abandonment	abandonment	NOUN	nmod	11	91	I-abstract	92	U-abstract	-100	O	-100	O	-100	O	-100	O
# 28	14	and	and	CCONJ	cc	15	91	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	15	guilt	guilt	NOUN	conj	13	91	L-abstract	93	U-abstract	-100	O	-100	O	-100	O	-100	O
# 28	16	.	.	PUNCT	punct	8	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 28	17	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	1	In	in	ADP	case	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	2	his	his	PRON	nmod:poss	3	94	B-abstract	1	U-person	-100	O	-100	O	-100	O	-100	O
# 29	3	confusion	confusion	NOUN	obl	6	94	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	4	he	he	PRON	nsubj	6	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	5	had	have	AUX	aux	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	6	taken	take	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	7	elements	element	NOUN	obj	6	95	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	8	from	from	ADP	case	9	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	9	storybooks	storybook	NOUN	obl	6	96	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	10	and	and	CCONJ	cc	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	11	imagined	imagine	VERB	conj	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	12	out	out	ADP	case	14	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	13	of	of	ADP	fixed	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	14	nothing	nothing	PRON	obl	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	15	this	this	DET	det	16	36	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	16	memory	memory	NOUN	obj	11	36	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	17	to	to	PART	mark	18	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	18	punish	punish	VERB	advcl	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	19	himself	himself	PRON	obj	18	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	20	.	.	PUNCT	punct	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 29	21	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	1	This	this	PRON	nsubj	4	36	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	2	was	be	AUX	cop	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	3	the	the	DET	det	4	36	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	4	sort	sort	NOUN	root	0	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	5	of	of	ADP	case	6	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	6	fantasy	fantasy	NOUN	nmod	4	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	7	that	that	PRON	nsubj	10	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	8	could	could	AUX	aux	10	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	9	have	have	AUX	aux	10	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	10	occurred	occur	VERB	acl:relcl	6	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	11	to	to	ADP	case	14	36	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	12	any	any	DET	det	14	36	I-abstract	97	B-person	-100	O	-100	O	-100	O	-100	O
# 30	13	young	young	ADJ	amod	14	36	I-abstract	97	I-person	-100	O	-100	O	-100	O	-100	O
# 30	14	child	child	NOUN	obl	10	36	I-abstract	97	I-person	-100	O	-100	O	-100	O	-100	O
# 30	15	who	who	PRON	nsubj	16	36	I-abstract	97	I-person	-100	O	-100	O	-100	O	-100	O
# 30	16	lost	lose	VERB	acl:relcl	14	36	I-abstract	97	I-person	-100	O	-100	O	-100	O	-100	O
# 30	17	an	a	DET	det	19	36	I-abstract	97	I-person	98	B-person	-100	O	-100	O	-100	O
# 30	18	important	important	ADJ	amod	19	36	I-abstract	97	I-person	98	I-person	-100	O	-100	O	-100	O
# 30	19	relative	relative	NOUN	obj	16	36	L-abstract	98	L-person	97	L-person	-100	O	-100	O	-100	O
# 30	20	.	.	PUNCT	punct	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 30	21	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	1	With	with	ADP	case	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	2	that	that	DET	det	3	76	B-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	3	realization	realization	NOUN	obl	11	76	L-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	4	,	,	PUNCT	punct	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	5	the	the	DET	det	6	99	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	6	image	image	NOUN	nsubj	11	99	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	7	of	of	ADP	case	9	99	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	8	his	his	PRON	nmod:poss	9	99	I-abstract	2	B-person	1	U-person	-100	O	-100	O	-100	O
# 31	9	grandmother	grandmother	NOUN	nmod	6	99	I-abstract	2	L-person	-100	O	-100	O	-100	O	-100	O
# 31	10	crying	cry	VERB	acl	9	99	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	11	faded	fade	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	12	in	in	ADP	case	14	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	13	his	his	PRON	nmod:poss	14	80	B-abstract	1	U-person	-100	O	-100	O	-100	O	-100	O
# 31	14	memory	memory	NOUN	obl	11	80	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	15	and	and	CCONJ	cc	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	16	became	become	VERB	conj	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	17	less	less	ADV	advmod	20	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	18	and	and	CCONJ	cc	19	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	19	less	less	ADV	conj	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	20	believable	believable	ADJ	xcomp	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	21	.	.	PUNCT	punct	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 31	22	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	1	Tyler	Tyler	PROPN	nsubj	2	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	2	thought	think	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	3	he	he	PRON	nsubj	6	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	4	was	be	AUX	cop	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	5	very	very	ADV	advmod	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	6	lucky	lucky	ADJ	ccomp	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	7	to	to	PART	mark	9	76	B-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	8	have	have	AUX	aux	9	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	9	discovered	discover	VERB	xcomp	6	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	10	the	the	DET	det	12	76	I-event	77	B-abstract	-100	O	-100	O	-100	O	-100	O
# 32	11	single	single	ADJ	amod	12	76	I-event	77	I-abstract	-100	O	-100	O	-100	O	-100	O
# 32	12	error	error	NOUN	obj	9	76	I-event	77	I-abstract	-100	O	-100	O	-100	O	-100	O
# 32	13	in	in	ADP	case	16	76	I-event	77	I-abstract	-100	O	-100	O	-100	O	-100	O
# 32	14	his	his	PRON	nmod:poss	16	76	I-event	77	I-abstract	99	B-abstract	1	U-person	-100	O	-100	O
# 32	15	false	false	ADJ	amod	16	76	I-event	77	I-abstract	99	I-abstract	-100	O	-100	O	-100	O
# 32	16	memory	memory	NOUN	nmod	12	76	I-event	99	L-abstract	77	L-abstract	-100	O	-100	O	-100	O
# 32	17	,	,	PUNCT	punct	19	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	18	which	which	PRON	nsubj	19	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	19	enabled	enable	VERB	advcl:relcl	9	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	20	him	he	PRON	obj	19	76	I-event	1	U-person	-100	O	-100	O	-100	O	-100	O
# 32	21	to	to	PART	mark	22	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	22	reason	reason	VERB	xcomp	19	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	23	his	his	PRON	nmod:poss	24	76	I-event	1	U-person	-100	O	-100	O	-100	O	-100	O
# 32	24	way	way	NOUN	obj	22	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	25	into	into	SCONJ	mark	26	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	26	distinguishing	distinguish	VERB	xcomp	22	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	27	between	between	ADP	case	28	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	28	reality	reality	NOUN	obl	26	76	I-event	100	U-abstract	-100	O	-100	O	-100	O	-100	O
# 32	29	and	and	CCONJ	cc	30	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	30	fantasy	fantasy	NOUN	conj	28	76	L-event	101	U-abstract	-100	O	-100	O	-100	O	-100	O
# 32	31	.	.	PUNCT	punct	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 32	32	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	1	He	he	PRON	nsubj	2	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	2	felt	feel	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	3	that	that	SCONJ	mark	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	4	it	it	PRON	nsubj	12	76	U-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	5	was	be	AUX	cop	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	6	a	a	DET	det	12	76	B-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	7	coming	coming	NOUN	compound	12	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	8	-	-	PUNCT	punct	9	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	9	of	of	ADP	case	11	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	10	-	-	PUNCT	punct	9	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	11	age	age	NOUN	nmod	7	76	I-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	12	moment	moment	NOUN	ccomp	2	76	L-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	13	.	.	PUNCT	punct	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 33	14	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	1	Nonetheless	nonetheless	ADV	advmod	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	2	,	,	PUNCT	punct	1	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	3	he	he	PRON	nsubj	4	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	4	admitted	admit	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	5	to	to	ADP	case	6	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	6	himself	himself	PRON	obl	4	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	7	that	that	SCONJ	mark	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	8	he	he	PRON	nsubj	12	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	9	was	be	AUX	cop	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	10	a	a	DET	det	11	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	11	little	little	ADJ	obl:npmod	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	12	sad	sad	ADJ	ccomp	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	13	also	also	ADV	advmod	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	14	at	at	ADP	case	16	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	15	the	the	DET	det	16	76	B-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	16	discovery	discovery	NOUN	obl	12	76	L-event	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	17	.	.	PUNCT	punct	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 34	18	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	1	For	for	SCONJ	mark	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	2	however	however	ADV	advmod	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	3	imaginary	imaginary	ADJ	advcl	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	4	that	that	DET	det	5	99	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	5	memory	memory	NOUN	nsubj	3	99	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	6	was	be	AUX	cop	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	7	,	,	PUNCT	punct	3	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	8	it	it	PRON	nsubj	12	99	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	9	was	be	AUX	cop	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	10	also	also	ADV	advmod	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	11	a	a	DET	det	12	99	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	12	part	part	NOUN	root	0	99	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	13	of	of	ADP	case	15	99	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	14	his	his	PRON	nmod:poss	15	99	I-abstract	26	B-abstract	1	U-person	-100	O	-100	O	-100	O
# 35	15	love	love	NOUN	nmod	12	99	I-abstract	26	I-abstract	-100	O	-100	O	-100	O	-100	O
# 35	16	for	for	ADP	case	18	99	I-abstract	26	I-abstract	-100	O	-100	O	-100	O	-100	O
# 35	17	his	his	PRON	nmod:poss	18	99	I-abstract	26	I-abstract	2	B-person	1	U-person	-100	O	-100	O
# 35	18	grandmother	grandmother	NOUN	nmod	15	99	L-abstract	2	L-person	26	L-abstract	-100	O	-100	O	-100	O
# 35	19	.	.	PUNCT	punct	12	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 35	20	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	1	When	when	ADV	advmod	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	2	that	that	DET	det	3	99	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	3	memory	memory	NOUN	nsubj	4	99	L-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	4	lost	lose	VERB	advcl	18	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	5	its	its	PRON	nmod:poss	7	102	B-abstract	99	U-abstract	-100	O	-100	O	-100	O	-100	O
# 36	6	compelling	compelling	ADJ	amod	7	102	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	7	aura	aura	NOUN	obj	4	102	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	8	of	of	ADP	case	9	102	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	9	truth	truth	NOUN	nmod	7	102	L-abstract	103	U-abstract	-100	O	-100	O	-100	O	-100	O
# 36	10	,	,	PUNCT	punct	4	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	11	it	it	PRON	nsubj:outer	18	99	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	12	was	be	AUX	cop	18	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	13	like	like	SCONJ	mark	18	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	14	another	another	DET	det	15	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	15	part	part	NOUN	nsubj	18	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	16	of	of	ADP	case	17	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	17	her	she	PRON	nmod	15	2	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	18	died	die	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	19	with	with	ADP	case	20	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	20	it	it	PRON	obl	18	99	U-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	21	.	.	PUNCT	punct	18	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 36	22	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 37	0	[CLS]	[CLS]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 37	1	He	he	PRON	nsubj	2	1	U-person	-100	O	-100	O	-100	O	-100	O	-100	O
# 37	2	had	have	VERB	root	0	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 37	3	no	no	DET	det	4	104	B-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 37	4	name	name	NOUN	obj	2	104	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 37	5	for	for	ADP	case	7	104	I-abstract	-100	O	-100	O	-100	O	-100	O	-100	O
# 37	6	the	the	DET	det	7	104	I-abstract	105	B-abstract	-100	O	-100	O	-100	O	-100	O
# 37	7	emptiness	emptiness	NOUN	obl	2	104	I-abstract	105	I-abstract	-100	O	-100	O	-100	O	-100	O
# 37	8	that	that	PRON	nsubj	9	104	I-abstract	105	I-abstract	-100	O	-100	O	-100	O	-100	O
# 37	9	remained	remain	VERB	acl:relcl	7	104	L-abstract	105	L-abstract	-100	O	-100	O	-100	O	-100	O
# 37	10	.	.	PUNCT	punct	2	-1	O	-100	O	-100	O	-100	O	-100	O	-100	O
# 37	11	[SEP]	[SEP]	_	_	-1	-100	O	-100	O	-100	O	-100	O	-100	O	-100	O

# %%
text.coref_entities
# Out:
# {1: 'person',
#  2: 'person',
#  3: 'place',
#  4: 'person',
#  5: 'person',
#  6: 'abstract',
#  7: 'person',
#  8: 'abstract',
#  9: 'abstract',
#  10: 'person',
#  11: 'animal',
#  12: 'person',
#  13: 'abstract',
#  14: 'abstract',
#  15: 'abstract',
#  16: 'abstract',
#  17: 'time',
#  18: 'place',
#  19: 'event',
#  20: 'object',
#  21: 'object',
#  22: 'abstract',
#  23: 'abstract',
#  24: 'person',
#  25: 'abstract',
#  26: 'abstract',
#  27: 'time',
#  28: 'abstract',
#  29: 'abstract',
#  30: 'abstract',
#  31: 'abstract',
#  32: 'abstract',
#  33: 'abstract',
#  34: 'time',
#  35: 'event',
#  36: 'abstract',
#  37: 'event',
#  38: 'abstract',
#  39: 'person',
#  40: 'abstract',
#  41: 'object',
#  42: 'place',
#  43: 'object',
#  44: 'abstract',
#  45: 'object',
#  46: 'place',
#  47: 'abstract',
#  48: 'object',
#  49: 'abstract',
#  50: 'time',
#  51: 'abstract',
#  52: 'abstract',
#  53: 'abstract',
#  54: 'abstract',
#  55: 'abstract',
#  56: 'abstract',
#  57: 'time',
#  58: 'person',
#  59: 'place',
#  60: 'place',
#  61: 'abstract',
#  62: 'time',
#  63: 'abstract',
#  64: 'abstract',
#  65: 'abstract',
#  66: 'abstract',
#  67: 'person',
#  68: 'abstract',
#  69: 'abstract',
#  70: 'abstract',
#  71: 'object',
#  72: 'person',
#  73: 'object',
#  74: 'object',
#  75: 'place',
#  76: 'event',
#  77: 'abstract',
#  78: 'object',
#  79: 'place',
#  80: 'abstract',
#  81: 'abstract',
#  82: 'abstract',
#  83: 'place',
#  84: 'event',
#  85: 'abstract',
#  86: 'object',
#  87: 'place',
#  88: 'abstract',
#  89: 'abstract',
#  90: 'abstract',
#  91: 'abstract',
#  92: 'abstract',
#  93: 'abstract',
#  94: 'abstract',
#  95: 'abstract',
#  96: 'abstract',
#  97: 'person',
#  98: 'person',
#  99: 'abstract',
#  100: 'abstract',
#  101: 'abstract',
#  102: 'abstract',
#  103: 'abstract',
#  104: 'abstract',
#  105: 'abstract'}

# %%
import scene_desc as sd
import conllu_converter
import re

converter = conllu_converter.ConlluFilesConverter(max_level=3) 
converter.convert_and_save_file(source_file_path='../datasets/gum/dep/GUM_fiction_error.conllu',
                                target_text_file_path='../datasets/gum_parsed/texts/1.txt',
                                target_labels_file_path='../datasets/gum_parsed/labels/1.txt',
                                coref_dict_file_path='../datasets/gum_parsed/coref_dict/1.txt')
