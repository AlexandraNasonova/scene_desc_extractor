# %%
import re

# %% [markdown]
# # Entity marks ##

# %% [markdown]
# For flat entities:
#
# I - Word is inside a phrase of type TYPE
# B - If two phrases of the same type immediately follow each other, the first word of the second phrase will have tag B-TYPE
# O - Word is not part of a phrase
# E - End ( E will not appear in a prefix-only partial match )
# S - Single

# %% [markdown]
# For nested entities:
#
# B - Begin: The first word of a multi-word entity.
# I - Inside: Any non-initial word of a multi-word entity. (M - middle)
# L - Last: The last word of a multi-word entity. (E - end)
# U - Unit: A single-word entity.
# O - Outside: A word that is not part of any entity. (S / Single)
#
# BILOU or IOBES

# %%
# Define BILOU tags
bilou_tags = ["B", "I", "L", "U", "O"]

# %% [markdown]
# ## Dependencies ##
#
# https://wiki.gucorpling.org/gum/dependencies
#
# List of dependency function labels used in GUM
#
#     acl
#     acl:relcl
#     advcl
#     advcl:relcl
#     advmod
#     amod
#     appos
#     aux
#     aux:pass
#     case
#     cc
#     cc:preconj
#     ccomp
#     compound
#     compound:prt
#     conj
#     cop
#     csubj
#     csubj:pass
#     dep
#     det
#     det:predet
#     discourse
#     dislocated
#     expl
#     fixed
#     flat
#     goeswith
#     iobj
#     list
#     mark
#     nmod
#     nmod:npmod
#     nmod:tmod
#     nmod:poss
#     nsubj
#     nsubj:pass
#     nummod
#     obj
#     obl
#     obl:agent
#     obl:npmod
#     obl:tmod
#     orphan
#     parataxis
#     punct
#     reparandum
#     root
#     vocative
#     xcomp

# %% [markdown]
# ## Entities types
#
# https://wiki.gucorpling.org/gum/entities
#
# There are 10 entity type:
#
#     person - any person, including fictitious figures, groups of people, and semi-human entities (Pinocchio)
#     place - a country (Iceland), region (Sahara)), or other place being referred to as a location (the factory - when used as a place, not to refer to the physical building)
#     organization - a company, government, sports team and others
#     object - a concrete tangible object
#     event - includes reference to nouns ('War', 'the performance') and clauses that are referred back to ('that John came')
#     time - dates, times of day, days, years...
#     substance - water, mercury, gas, poison ... includes context-dependent substances, such as Skittles or baking chocolate
#     animal - any animal, potentially including bacteria, aliens and others construed as animals
#     plant - interpreted broadly to include fruits, seeds and other living plant parts, but not substances (e.g. 'wood' is not classified as a plant)
#     abstract - abstract notions (luck), emotions (excitement) or intangible properties (predisposition)

# %% [markdown]
# ## Entity salience
#
# https://wiki.gucorpling.org/gum/entities
#
# An entity is considered salient if and only if it appears in the summary of a document
# Annotate the first mention of a salient entity as salient, there is no need to annotate subsequent mentions as salient
#
# In the header:
#
# meta::salientEntities = 1, 2, 36, 41, 42, 46, 76, 99

# %% [markdown]
# ## Coreference
#
# https://wiki.gucorpling.org/gum/entities

# %%
import scene_desc as sd
import re

# %%
TEXT_MARKER = "# text = "
SENTENCE_ID_MARKER = "# sent_id = "
TEXT_MARKER_LEN = len(TEXT_MARKER)
ENTITY_START_MARKER = "Entity="
ENTITY_STOP_MARKER = "|"

entity_marker_len = len(ENTITY_START_MARKER)

def extract_entity_info(text: str) -> (str, list[(str,str)]):
    entity_start_mark_index = text.find(ENTITY_START_MARKER)
    if entity_start_mark_index == -1:
        return '_', []
    
    entity_stop_mark_index = text.find(ENTITY_STOP_MARKER)          
    if entity_stop_mark_index > entity_start_mark_index:
         entity_tag = text[entity_start_mark_index + entity_marker_len:entity_stop_mark_index]
    else:
        entity_tag = text[entity_start_mark_index + entity_marker_len:]
    entity_matches = re.findall(r'(\(\d+-\w+)(?=-|\:)|(\d*?\))', entity_tag)
    
    return entity_tag, entity_matches

def append_to_open_entities(word_id: int,
                            open_entities: list[sd.Entity], 
                            result_entities = list[sd.Entity]):    
    for entity in open_entities:
        if entity.word_id == word_id:
                continue
            
        result_entities.append(
            sd.Entity(word_id=word_id,coref_id=entity.coref_id,
                      bilou_tag='I', level=entity.level))
    
        
def convert_entity_matches(word_id: int,
                           entity_matches: list[(str,str)],
                           coref_entities: dict[int, str],
                           open_entities: list[sd.Entity]) -> list[sd.Entity]:
    
    result_entities = []
    #if no openings or closings for entities
    if len(entity_matches) == 0:
        #if no already opened entities - return BILOU tag  - O - Outside
        if len(open_entities) == 0:      
            return [sd.Entity(word_id=word_id, 
                              coref_id=0, bilou_tag='O', level=0)]
        
        #update already opened entities with nested info
        else:
            append_to_open_entities(word_id=word_id,
                                    open_entities=open_entities, 
                                    result_entities=result_entities)
            return result_entities 
    
    #if there are some openings or closings for entities
    for match in entity_matches:
        entity_start = match[0]
        entity_end = match[1]
        # for an opening
        if entity_start != '':
            spl = entity_start[1:].split('-')
            (coref_id, entity_type) = int(spl[0]), spl[1]
            
            # if opening is newly mentioned, update coreference dictionary
            if coref_id not in coref_entities:
                coref_entities[coref_id] = entity_type
            
            #update already opened entities with nested info
            append_to_open_entities(word_id=word_id,
                                    open_entities=open_entities, 
                                    result_entities=result_entities)
            #get new level
            level = 0
            if len(open_entities) > 0:
                level = open_entities[-1].level + 1
            
            #create a new entity with B - Begin BILOU tag as default
            entity = sd.Entity(word_id=word_id,
                               coref_id=coref_id, bilou_tag='B', level=level)
            open_entities.append(entity) 
            result_entities.append(entity)
        # for a closing            
        else:
            spl = entity_end[:-1]
            # if not links to coref_if then the last opening should be closed and it's 
            # tag is U - Unique (in BILOU terms)
            if spl == '':                
                result_entities[-1].bilou_tag = 'U'
            
            # if there is the link to coref_if, then it is not unique, 
            # so L - Last BILOU tag should be used
            else:
                coref_id = int(spl)
                result_entities.append(
                    sd.Entity(word_id=word_id,
                              coref_id=coref_id, bilou_tag='L',
                              level=open_entities[-1].level))
            
            # remove the last entity from the open entities 
            open_entities.pop()            
    return  result_entities 
            
        
    
def convert_from_conllu_file(file_path):      
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()      
        
        text = sd.Text(text_full="", sentences=[], coref_entities={})
        open_entities = []     
        sentence_id = 0
        sentence_text = ''  
        sentence = None
        # Iterate through each line in the file
        for line in lines:
            # collect text
            if line.startswith(TEXT_MARKER):
                sentence_text = line[TEXT_MARKER_LEN:-1]
                text.text_full += sentence_text + " "
            
            # init new sentence
            if line.startswith(SENTENCE_ID_MARKER):
                if sentence is not None:
                    text.sentences.append(sentence)
                sentence_id = int(line[(line.rfind('-') + 1):])
                sentence = sd.Sentence(sentence_id = sentence_id, sentence_text = sentence_text,
                                       words=[])
                
            # collect line info for words and punctuation
            if line[0].isdigit():                
                parts = line.split("\t")
                word_id=parts[0]
                entity_tag, entity_matches = extract_entity_info(text=parts[9])
                # get BILOU entities for each words 
                entities = convert_entity_matches(word_id=word_id, 
                                                  entity_matches=entity_matches, 
                                                  coref_entities=text.coref_entities, 
                                                  open_entities=open_entities)
                # collect word info
                word = sd.Word(word_id=word_id, word=parts[1], lemma_init=parts[2],
                                pos_tag=parts[3], dep_type=parts[7], dep_parent_id=parts[6],
                                entities=entities)           
                
                # print(f'{sentence_id}_{word_id}\t{parts[1]}\t{entity_tag}\n'
                #       f'\t\t[{" | ".join("(" + str(e) + ")" for e in entities)}]\n'
                #       f'\t\t[{" | ".join("(" + str(e) + ")" for e in open_entities)}]'
                #       )
                
                #append word to current sentence
                sentence.words.append(word)
        
        text.text_full = text.text_full.strip()
        return text

# %%
entity_tag = 'Entity=(4-place-giv:act-cf3-1-coref-Russia)14)'
re.findall(r'(\(\d+-\w+)(?=-|\:)|(\d*?\))', entity_tag)
# Out:
# [('(4-place', ''), ('', ')'), ('', '14)')]

# %%
text = convert_from_conllu_file('../datasets/gum/dep/GUM_fiction_error.conllu')
# for word_number, word, entity_tag in word_info_list:
#     print(f"Word Number: {word_number}, Word: {word}, Entity Tag: {entity_tag}")
# for x in word_info_list:
#     print(x)

# %%
for s in text.sentences:
    for w in s.words:
        print(w)
# Out:
# word_id : 1, word: When, lemma_init: when, pos_tag: ADV, dep_type: advmod, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 2, word: Tyler, lemma_init: Tyler, pos_tag: PROPN, dep_type: nsubj, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 3, word: was, lemma_init: be, pos_tag: AUX, dep_type: cop, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 4, word: very, lemma_init: very, pos_tag: ADV, dep_type: advmod, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 5, word: young, lemma_init: young, pos_tag: ADJ, dep_type: advcl, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 6, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 7, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 8,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)'}])
# word_id : 8, word: grandmother, lemma_init: grandmother, pos_tag: NOUN, dep_type: nsubj, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: L)'}])
# word_id : 9, word: was, lemma_init: be, pos_tag: AUX, dep_type: cop, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 10, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)'}])
# word_id : 11, word: favorite, lemma_init: favorite, pos_tag: ADJ, dep_type: amod, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: I)'}])
# word_id : 12, word: person, lemma_init: person, pos_tag: NOUN, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: L)'}])
# word_id : 13, word: in, lemma_init: in, pos_tag: ADP, dep_type: case, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 14, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 3, bilou_tag: B)'}])
# word_id : 15, word: world, lemma_init: world, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 3, bilou_tag: L)'}])
# word_id : 16, word: because, lemma_init: because, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 39,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 17, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 18, word: unlike, lemma_init: unlike, pos_tag: ADP, dep_type: case, dep_parent_id: 20,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 19, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 20,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)'}])
# word_id : 20, word: parents, lemma_init: parent, pos_tag: NOUN, dep_type: obl, dep_parent_id: 39,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I)'}])
# word_id : 21, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 23,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I)'}])
# word_id : 22, word: who, lemma_init: who, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 23,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I)'}])
# word_id : 23, word: believed, lemma_init: believe, pos_tag: VERB, dep_type: acl:relcl, dep_parent_id: 20,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I)'}])
# word_id : 24, word: that, lemma_init: that, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 29,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I)'}])
# word_id : 25, word: children, lemma_init: child, pos_tag: NOUN, dep_type: nsubj:pass, dep_parent_id: 29,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I) | (level: 1, coref_id: 5, bilou_tag: U)'}])
# word_id : 26, word: should, lemma_init: should, pos_tag: AUX, dep_type: aux, dep_parent_id: 29,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I)'}])
# word_id : 27, word: always, lemma_init: always, pos_tag: ADV, dep_type: advmod, dep_parent_id: 29,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I)'}])
# word_id : 28, word: be, lemma_init: be, pos_tag: AUX, dep_type: aux:pass, dep_parent_id: 29,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I)'}])
# word_id : 29, word: told, lemma_init: tell, pos_tag: VERB, dep_type: ccomp, dep_parent_id: 23,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I)'}])
# word_id : 30, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 31,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I) | (level: 1, coref_id: 6, bilou_tag: B)'}])
# word_id : 31, word: truth, lemma_init: truth, pos_tag: NOUN, dep_type: obj, dep_parent_id: 29,
# entities: [{'(level: 1, coref_id: 6, bilou_tag: L)'}])
# word_id : 32, word: as, lemma_init: as, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 34,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I)'}])
# word_id : 33, word: adults, lemma_init: adult, pos_tag: NOUN, dep_type: nsubj, dep_parent_id: 34,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I) | (level: 1, coref_id: 7, bilou_tag: U)'}])
# word_id : 34, word: understood, lemma_init: understand, pos_tag: VERB, dep_type: advcl, dep_parent_id: 29,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I)'}])
# word_id : 35, word: it, lemma_init: it, pos_tag: PRON, dep_type: obj, dep_parent_id: 34,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: I) | (level: 1, coref_id: 6, bilou_tag: U) | (level: 0, coref_id: 4, bilou_tag: L)'}])
# word_id : 36, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 20,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 37, word: she, lemma_init: she, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 39,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: U)'}])
# word_id : 38, word: would, lemma_init: would, pos_tag: AUX, dep_type: aux, dep_parent_id: 39,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 39, word: fill, lemma_init: fill, pos_tag: VERB, dep_type: advcl, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 40, word: in, lemma_init: in, pos_tag: ADP, dep_type: compound:prt, dep_parent_id: 39,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 41, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 42,
# entities: [{'(level: 0, coref_id: 8, bilou_tag: B)'}])
# word_id : 42, word: gaps, lemma_init: gap, pos_tag: NOUN, dep_type: obj, dep_parent_id: 39,
# entities: [{'(level: 0, coref_id: 8, bilou_tag: I)'}])
# word_id : 43, word: in, lemma_init: in, pos_tag: ADP, dep_type: case, dep_parent_id: 45,
# entities: [{'(level: 0, coref_id: 8, bilou_tag: I)'}])
# word_id : 44, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 45,
# entities: [{'(level: 0, coref_id: 8, bilou_tag: I) | (level: 1, coref_id: 9, bilou_tag: B) | (level: 0, coref_id: 8, bilou_tag: I) | (level: 2, coref_id: 1, bilou_tag: U)'}])
# word_id : 45, word: knowledge, lemma_init: knowledge, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 42,
# entities: [{'(level: 1, coref_id: 9, bilou_tag: L) | (level: 0, coref_id: 8, bilou_tag: L)'}])
# word_id : 46, word: —, lemma_init: —, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 47,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 47, word: Santa, lemma_init: Santa, pos_tag: PROPN, dep_type: appos, dep_parent_id: 42,
# entities: [{'(level: 0, coref_id: 10, bilou_tag: B)'}])
# word_id : 48, word: Claus, lemma_init: Claus, pos_tag: PROPN, dep_type: flat, dep_parent_id: 47,
# entities: [{'(level: 0, coref_id: 10, bilou_tag: L)'}])
# word_id : 49, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 52,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 50, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 52,
# entities: [{'(level: 0, coref_id: 11, bilou_tag: B)'}])
# word_id : 51, word: Easter, lemma_init: Easter, pos_tag: PROPN, dep_type: compound, dep_parent_id: 52,
# entities: [{'(level: 0, coref_id: 11, bilou_tag: I)'}])
# word_id : 52, word: Bunny, lemma_init: Bunny, pos_tag: PROPN, dep_type: conj, dep_parent_id: 47,
# entities: [{'(level: 0, coref_id: 11, bilou_tag: L)'}])
# word_id : 53, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 54,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 54, word: God, lemma_init: God, pos_tag: PROPN, dep_type: conj, dep_parent_id: 47,
# entities: [{'(level: 0, coref_id: 12, bilou_tag: U)'}])
# word_id : 55, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: His, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)'}])
# word_id : 2, word: parents, lemma_init: parent, pos_tag: NOUN, dep_type: nsubj, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: L)'}])
# word_id : 3, word: were, lemma_init: be, pos_tag: AUX, dep_type: cop, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 4, word: always, lemma_init: always, pos_tag: ADV, dep_type: advmod, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 5, word: too, lemma_init: too, pos_tag: ADV, dep_type: advmod, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 6, word: busy, lemma_init: busy, pos_tag: ADJ, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 7, word: and, lemma_init: and, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 8, word: often, lemma_init: often, pos_tag: ADV, dep_type: advmod, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 9, word: a, lemma_init: a, pos_tag: DET, dep_type: det, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 10, word: little, lemma_init: little, pos_tag: ADJ, dep_type: obl:npmod, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 11, word: too, lemma_init: too, pos_tag: ADV, dep_type: advmod, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 12, word: serious, lemma_init: serious, pos_tag: ADJ, dep_type: conj, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 13, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 17,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 14, word: but, lemma_init: but, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 17,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 15, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)'}])
# word_id : 16, word: grandmother, lemma_init: grandmother, pos_tag: NOUN, dep_type: nsubj, dep_parent_id: 17,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: L)'}])
# word_id : 17, word: had, lemma_init: have, pos_tag: VERB, dep_type: conj, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 18, word: a, lemma_init: a, pos_tag: DET, dep_type: det, dep_parent_id: 19,
# entities: [{'(level: 0, coref_id: 13, bilou_tag: B)'}])
# word_id : 19, word: sense, lemma_init: sense, pos_tag: NOUN, dep_type: obj, dep_parent_id: 17,
# entities: [{'(level: 0, coref_id: 13, bilou_tag: I)'}])
# word_id : 20, word: of, lemma_init: of, pos_tag: ADP, dep_type: case, dep_parent_id: 21,
# entities: [{'(level: 0, coref_id: 13, bilou_tag: I)'}])
# word_id : 21, word: peace, lemma_init: peace, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 19,
# entities: [{'(level: 0, coref_id: 13, bilou_tag: I) | (level: 1, coref_id: 14, bilou_tag: U) | (level: 0, coref_id: 13, bilou_tag: L)'}])
# word_id : 22, word: about, lemma_init: about, pos_tag: ADP, dep_type: case, dep_parent_id: 23,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 23, word: her, lemma_init: she, pos_tag: PRON, dep_type: obl, dep_parent_id: 17,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: U)'}])
# word_id : 24, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 23,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 25, word: a, lemma_init: a, pos_tag: DET, dep_type: det, dep_parent_id: 26,
# entities: [{'(level: 0, coref_id: 15, bilou_tag: B)'}])
# word_id : 26, word: lightness, lemma_init: lightness, pos_tag: NOUN, dep_type: appos, dep_parent_id: 19,
# entities: [{'(level: 0, coref_id: 15, bilou_tag: I)'}])
# word_id : 27, word: that, lemma_init: that, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 28,
# entities: [{'(level: 0, coref_id: 15, bilou_tag: I)'}])
# word_id : 28, word: lifted, lemma_init: lift, pos_tag: VERB, dep_type: acl:relcl, dep_parent_id: 26,
# entities: [{'(level: 0, coref_id: 15, bilou_tag: I)'}])
# word_id : 29, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 30,
# entities: [{'(level: 0, coref_id: 15, bilou_tag: I) | (level: 1, coref_id: 16, bilou_tag: B) | (level: 0, coref_id: 15, bilou_tag: I) | (level: 2, coref_id: 1, bilou_tag: U)'}])
# word_id : 30, word: spirit, lemma_init: spirit, pos_tag: NOUN, dep_type: obj, dep_parent_id: 28,
# entities: [{'(level: 1, coref_id: 16, bilou_tag: L) | (level: 0, coref_id: 15, bilou_tag: L)'}])
# word_id : 31, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: A, lemma_init: a, pos_tag: DET, dep_type: det, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 17, bilou_tag: B)'}])
# word_id : 2, word: few, lemma_init: few, pos_tag: ADJ, dep_type: amod, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 17, bilou_tag: I)'}])
# word_id : 3, word: times, lemma_init: time, pos_tag: NOUN, dep_type: obl:tmod, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 17, bilou_tag: L)'}])
# word_id : 4, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 5, word: when, lemma_init: when, pos_tag: ADV, dep_type: advmod, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 6-7, word: Tyler’s, lemma_init: _, pos_tag: _, dep_type: _, dep_parent_id: _,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 6, word: Tyler, lemma_init: Tyler, pos_tag: PROPN, dep_type: nmod:poss, dep_parent_id: 8,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: B)'}])
# word_id : 7, word: ’s, lemma_init: 's, pos_tag: PART, dep_type: case, dep_parent_id: 6,
# entities: [{'(level: 1, coref_id: 1, bilou_tag: L)'}])
# word_id : 8, word: parents, lemma_init: parent, pos_tag: NOUN, dep_type: nsubj, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 4, bilou_tag: L)'}])
# word_id : 9, word: were, lemma_init: be, pos_tag: AUX, dep_type: cop, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 10, word: away, lemma_init: away, pos_tag: ADV, dep_type: advcl, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 11, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 12, word: she, lemma_init: she, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: U)'}])
# word_id : 13, word: took, lemma_init: take, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 14, word: him, lemma_init: he, pos_tag: PRON, dep_type: obj, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 15, word: with, lemma_init: with, pos_tag: ADP, dep_type: case, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 16, word: her, lemma_init: she, pos_tag: PRON, dep_type: obl, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: U)'}])
# word_id : 17, word: to, lemma_init: to, pos_tag: ADP, dep_type: case, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 18, word: church, lemma_init: church, pos_tag: NOUN, dep_type: obl, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 18, bilou_tag: U)'}])
# word_id : 19, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: He, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 2, word: remembered, lemma_init: remember, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 3, word: liking, lemma_init: like, pos_tag: VERB, dep_type: xcomp, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 4, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 19, bilou_tag: B)'}])
# word_id : 5, word: singing, lemma_init: singing, pos_tag: NOUN, dep_type: obj, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 19, bilou_tag: L)'}])
# word_id : 6, word: and, lemma_init: and, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 7, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 20, bilou_tag: B)'}])
# word_id : 8, word: colorful, lemma_init: colorful, pos_tag: ADJ, dep_type: amod, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 20, bilou_tag: I)'}])
# word_id : 9, word: windows, lemma_init: window, pos_tag: NOUN, dep_type: conj, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 20, bilou_tag: L)'}])
# word_id : 10, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 11, word: and, lemma_init: and, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 12, word: how, lemma_init: how, pos_tag: ADV, dep_type: advmod, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 13, word: safe, lemma_init: safe, pos_tag: ADJ, dep_type: xcomp, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 14, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 15, word: felt, lemma_init: feel, pos_tag: VERB, dep_type: conj, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 16, word: there, lemma_init: there, pos_tag: ADV, dep_type: advmod, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 18, bilou_tag: U)'}])
# word_id : 17, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 18, word: in, lemma_init: in, pos_tag: ADP, dep_type: case, dep_parent_id: 23,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 19, word: that, lemma_init: that, pos_tag: DET, dep_type: det, dep_parent_id: 23,
# entities: [{'(level: 0, coref_id: 18, bilou_tag: B)'}])
# word_id : 20, word: large, lemma_init: large, pos_tag: ADJ, dep_type: amod, dep_parent_id: 23,
# entities: [{'(level: 0, coref_id: 18, bilou_tag: I)'}])
# word_id : 21, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 20,
# entities: [{'(level: 0, coref_id: 18, bilou_tag: I)'}])
# word_id : 22, word: empty, lemma_init: empty, pos_tag: ADJ, dep_type: amod, dep_parent_id: 23,
# entities: [{'(level: 0, coref_id: 18, bilou_tag: I)'}])
# word_id : 23, word: space, lemma_init: space, pos_tag: NOUN, dep_type: obl, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 18, bilou_tag: L)'}])
# word_id : 24, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 25,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 25, word: sitting, lemma_init: sit, pos_tag: VERB, dep_type: advcl, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 26, word: on, lemma_init: on, pos_tag: ADP, dep_type: case, dep_parent_id: 29,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 27, word: a, lemma_init: a, pos_tag: DET, dep_type: det, dep_parent_id: 29,
# entities: [{'(level: 0, coref_id: 21, bilou_tag: B)'}])
# word_id : 28, word: hard, lemma_init: hard, pos_tag: ADJ, dep_type: amod, dep_parent_id: 29,
# entities: [{'(level: 0, coref_id: 21, bilou_tag: I)'}])
# word_id : 29, word: bench, lemma_init: bench, pos_tag: NOUN, dep_type: obl, dep_parent_id: 25,
# entities: [{'(level: 0, coref_id: 21, bilou_tag: L)'}])
# word_id : 30, word: next, lemma_init: next, pos_tag: ADV, dep_type: advmod, dep_parent_id: 25,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 31, word: to, lemma_init: to, pos_tag: ADP, dep_type: case, dep_parent_id: 33,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 32, word: her, lemma_init: her, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 33,
# entities: [{'(level: 0, coref_id: 22, bilou_tag: B) | (level: 1, coref_id: 2, bilou_tag: U)'}])
# word_id : 33, word: warmth, lemma_init: warmth, pos_tag: NOUN, dep_type: obl, dep_parent_id: 30,
# entities: [{'(level: 0, coref_id: 22, bilou_tag: L)'}])
# word_id : 34, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: When, lemma_init: when, pos_tag: ADV, dep_type: advmod, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 2, word: she, lemma_init: she, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: U)'}])
# word_id : 3, word: died, lemma_init: die, pos_tag: VERB, dep_type: advcl, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 4, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 5, word: grief, lemma_init: grief, pos_tag: NOUN, dep_type: nsubj, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 23, bilou_tag: U)'}])
# word_id : 6, word: overwhelmed, lemma_init: overwhelm, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 7, word: Tyler, lemma_init: Tyler, pos_tag: PROPN, dep_type: obj, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 8, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: But, lemma_init: but, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 2, word: like, lemma_init: like, pos_tag: ADP, dep_type: case, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 3, word: most, lemma_init: most, pos_tag: ADJ, dep_type: amod, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 24, bilou_tag: B)'}])
# word_id : 4, word: adults, lemma_init: adult, pos_tag: NOUN, dep_type: obl, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 24, bilou_tag: L)'}])
# word_id : 5, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 6, word: when, lemma_init: when, pos_tag: ADV, dep_type: advmod, dep_parent_id: 8,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 7, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 8,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 8, word: grew, lemma_init: grow, pos_tag: VERB, dep_type: advcl, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 9, word: older, lemma_init: old, pos_tag: ADJ, dep_type: xcomp, dep_parent_id: 8,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 10, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 11, word: could, lemma_init: could, pos_tag: AUX, dep_type: aux, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 12, word: only, lemma_init: only, pos_tag: ADV, dep_type: advmod, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 13, word: recall, lemma_init: recall, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 14, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 25, bilou_tag: B)'}])
# word_id : 15, word: intensity, lemma_init: intensity, pos_tag: NOUN, dep_type: obj, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 25, bilou_tag: I)'}])
# word_id : 16, word: of, lemma_init: of, pos_tag: ADP, dep_type: case, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 25, bilou_tag: I)'}])
# word_id : 17, word: that, lemma_init: that, pos_tag: DET, dep_type: det, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 25, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: B)'}])
# word_id : 18, word: love, lemma_init: love, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 15,
# entities: [{'(level: 1, coref_id: 26, bilou_tag: L)'}])
# word_id : 19, word: in, lemma_init: in, pos_tag: ADP, dep_type: case, dep_parent_id: 20,
# entities: [{'(level: 0, coref_id: 25, bilou_tag: I)'}])
# word_id : 20, word: childhood, lemma_init: childhood, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 25, bilou_tag: I) | (level: 1, coref_id: 27, bilou_tag: U) | (level: 0, coref_id: 25, bilou_tag: L)'}])
# word_id : 21, word: in, lemma_init: in, pos_tag: ADP, dep_type: case, dep_parent_id: 24,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 22, word: an, lemma_init: a, pos_tag: DET, dep_type: det, dep_parent_id: 24,
# entities: [{'(level: 0, coref_id: 28, bilou_tag: B)'}])
# word_id : 23, word: abstract, lemma_init: abstract, pos_tag: ADJ, dep_type: amod, dep_parent_id: 24,
# entities: [{'(level: 0, coref_id: 28, bilou_tag: I)'}])
# word_id : 24, word: way, lemma_init: way, pos_tag: NOUN, dep_type: obl, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 28, bilou_tag: L)'}])
# word_id : 25, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: He, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 2, word: made, lemma_init: make, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 3, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 29, bilou_tag: B)'}])
# word_id : 4, word: common, lemma_init: common, pos_tag: ADJ, dep_type: amod, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 29, bilou_tag: I)'}])
# word_id : 5, word: error, lemma_init: error, pos_tag: NOUN, dep_type: obj, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 29, bilou_tag: I)'}])
# word_id : 6, word: of, lemma_init: of, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 7,
# entities: [{'(level: 0, coref_id: 29, bilou_tag: I)'}])
# word_id : 7, word: identifying, lemma_init: identify, pos_tag: VERB, dep_type: acl, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 29, bilou_tag: I)'}])
# word_id : 8, word: maturity, lemma_init: maturity, pos_tag: NOUN, dep_type: obj, dep_parent_id: 7,
# entities: [{'(level: 0, coref_id: 29, bilou_tag: I) | (level: 1, coref_id: 30, bilou_tag: U)'}])
# word_id : 9, word: with, lemma_init: with, pos_tag: ADP, dep_type: case, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 29, bilou_tag: I)'}])
# word_id : 10, word: worth, lemma_init: worth, pos_tag: NOUN, dep_type: obl, dep_parent_id: 7,
# entities: [{'(level: 0, coref_id: 29, bilou_tag: I) | (level: 1, coref_id: 31, bilou_tag: U) | (level: 0, coref_id: 29, bilou_tag: L)'}])
# word_id : 11, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 12, word: and, lemma_init: and, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 13, word: assumed, lemma_init: assume, pos_tag: VERB, dep_type: conj, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 14, word: that, lemma_init: that, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 28,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 15, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 26, bilou_tag: B)'}])
# word_id : 16, word: love, lemma_init: love, pos_tag: NOUN, dep_type: nsubj, dep_parent_id: 28,
# entities: [{'(level: 0, coref_id: 26, bilou_tag: I)'}])
# word_id : 17, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 26, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: U)'}])
# word_id : 18, word: had, lemma_init: have, pos_tag: VERB, dep_type: acl:relcl, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 26, bilou_tag: I)'}])
# word_id : 19, word: for, lemma_init: for, pos_tag: ADP, dep_type: case, dep_parent_id: 20,
# entities: [{'(level: 0, coref_id: 26, bilou_tag: I)'}])
# word_id : 20, word: her, lemma_init: she, pos_tag: PRON, dep_type: obl, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 26, bilou_tag: I) | (level: 1, coref_id: 2, bilou_tag: U)'}])
# word_id : 21, word: as, lemma_init: as, pos_tag: ADP, dep_type: case, dep_parent_id: 24,
# entities: [{'(level: 0, coref_id: 26, bilou_tag: I)'}])
# word_id : 22, word: a, lemma_init: a, pos_tag: DET, dep_type: det, dep_parent_id: 24,
# entities: [{'(level: 0, coref_id: 26, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: B)'}])
# word_id : 23, word: young, lemma_init: young, pos_tag: ADJ, dep_type: amod, dep_parent_id: 24,
# entities: [{'(level: 0, coref_id: 26, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: I)'}])
# word_id : 24, word: child, lemma_init: child, pos_tag: NOUN, dep_type: obl, dep_parent_id: 18,
# entities: [{'(level: 1, coref_id: 1, bilou_tag: L) | (level: 0, coref_id: 26, bilou_tag: L)'}])
# word_id : 25, word: must, lemma_init: must, pos_tag: AUX, dep_type: aux, dep_parent_id: 28,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 26, word: have, lemma_init: have, pos_tag: AUX, dep_type: aux, dep_parent_id: 28,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 27, word: been, lemma_init: be, pos_tag: AUX, dep_type: aux, dep_parent_id: 28,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 28, word: lacking, lemma_init: lack, pos_tag: VERB, dep_type: ccomp, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 29, word: in, lemma_init: in, pos_tag: ADP, dep_type: case, dep_parent_id: 30,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 30, word: strength, lemma_init: strength, pos_tag: NOUN, dep_type: obl, dep_parent_id: 28,
# entities: [{'(level: 0, coref_id: 32, bilou_tag: U)'}])
# word_id : 31, word: and, lemma_init: and, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 32,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 32, word: depth, lemma_init: depth, pos_tag: NOUN, dep_type: conj, dep_parent_id: 30,
# entities: [{'(level: 0, coref_id: 33, bilou_tag: U)'}])
# word_id : 33, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: For, lemma_init: for, pos_tag: ADP, dep_type: case, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 2, word: many, lemma_init: many, pos_tag: ADJ, dep_type: amod, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 34, bilou_tag: B)'}])
# word_id : 3, word: years, lemma_init: year, pos_tag: NOUN, dep_type: obl, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 34, bilou_tag: I)'}])
# word_id : 4, word: after, lemma_init: after, pos_tag: ADP, dep_type: case, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 34, bilou_tag: I)'}])
# word_id : 5, word: her, lemma_init: her, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 34, bilou_tag: I) | (level: 1, coref_id: 35, bilou_tag: B) | (level: 0, coref_id: 34, bilou_tag: I) | (level: 2, coref_id: 2, bilou_tag: U)'}])
# word_id : 6, word: death, lemma_init: death, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 3,
# entities: [{'(level: 1, coref_id: 35, bilou_tag: L) | (level: 0, coref_id: 34, bilou_tag: L)'}])
# word_id : 7, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 8, word: however, lemma_init: however, pos_tag: ADV, dep_type: advmod, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 9, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 8,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 10, word: Tyler, lemma_init: Tyler, pos_tag: PROPN, dep_type: nsubj:pass, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 11, word: was, lemma_init: be, pos_tag: AUX, dep_type: aux:pass, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 12, word: tortured, lemma_init: torture, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 13, word: by, lemma_init: by, pos_tag: ADP, dep_type: case, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 14, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 36, bilou_tag: B)'}])
# word_id : 15, word: memory, lemma_init: memory, pos_tag: NOUN, dep_type: obl:agent, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 36, bilou_tag: I)'}])
# word_id : 16, word: of, lemma_init: of, pos_tag: ADP, dep_type: case, dep_parent_id: 19,
# entities: [{'(level: 0, coref_id: 36, bilou_tag: I)'}])
# word_id : 17, word: a, lemma_init: a, pos_tag: DET, dep_type: det, dep_parent_id: 19,
# entities: [{'(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 37, bilou_tag: B)'}])
# word_id : 18, word: certain, lemma_init: certain, pos_tag: ADJ, dep_type: amod, dep_parent_id: 19,
# entities: [{'(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 37, bilou_tag: I)'}])
# word_id : 19, word: visit, lemma_init: visit, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 37, bilou_tag: I)'}])
# word_id : 20, word: from, lemma_init: from, pos_tag: ADP, dep_type: case, dep_parent_id: 21,
# entities: [{'(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 37, bilou_tag: I)'}])
# word_id : 21, word: her, lemma_init: she, pos_tag: PRON, dep_type: nmod, dep_parent_id: 19,
# entities: [{'(level: 0, coref_id: 36, bilou_tag: I) | (level: 1, coref_id: 37, bilou_tag: I) | (level: 2, coref_id: 2, bilou_tag: U) | (level: 1, coref_id: 37, bilou_tag: L) | (level: 0, coref_id: 36, bilou_tag: L)'}])
# word_id : 22, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: He, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 2, word: was, lemma_init: be, pos_tag: AUX, dep_type: cop, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 3, word: five, lemma_init: five, pos_tag: NUM, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 38, bilou_tag: U)'}])
# word_id : 4, word: or, lemma_init: or, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 5, word: so, lemma_init: so, pos_tag: ADV, dep_type: conj, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 6, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 7, word: and, lemma_init: and, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 8, word: they, lemma_init: they, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 39, bilou_tag: U)'}])
# word_id : 9, word: were, lemma_init: be, pos_tag: AUX, dep_type: aux, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 10, word: playing, lemma_init: play, pos_tag: VERB, dep_type: conj, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 11, word: some, lemma_init: some, pos_tag: DET, dep_type: det, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 40, bilou_tag: B)'}])
# word_id : 12, word: board, lemma_init: board, pos_tag: NOUN, dep_type: compound, dep_parent_id: 13,
# entities: [{'(level: 0, coref_id: 40, bilou_tag: I)'}])
# word_id : 13, word: game, lemma_init: game, pos_tag: NOUN, dep_type: obj, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 40, bilou_tag: L)'}])
# word_id : 14, word: at, lemma_init: at, pos_tag: ADP, dep_type: case, dep_parent_id: 17,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 15, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 17,
# entities: [{'(level: 0, coref_id: 41, bilou_tag: B)'}])
# word_id : 16, word: kitchen, lemma_init: kitchen, pos_tag: NOUN, dep_type: compound, dep_parent_id: 17,
# entities: [{'(level: 0, coref_id: 41, bilou_tag: I) | (level: 1, coref_id: 42, bilou_tag: U)'}])
# word_id : 17, word: table, lemma_init: table, pos_tag: NOUN, dep_type: obl, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 41, bilou_tag: L)'}])
# word_id : 18, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: As, lemma_init: as, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 2, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 3, word: swung, lemma_init: swing, pos_tag: VERB, dep_type: advcl, dep_parent_id: 11,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 4, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 43, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)'}])
# word_id : 5, word: legs, lemma_init: leg, pos_tag: NOUN, dep_type: obj, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 43, bilou_tag: L)'}])
# word_id : 6, word: in, lemma_init: in, pos_tag: ADP, dep_type: case, dep_parent_id: 8,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 7, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 8,
# entities: [{'(level: 0, coref_id: 44, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: U)'}])
# word_id : 8, word: excitement, lemma_init: excitement, pos_tag: NOUN, dep_type: obl, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 44, bilou_tag: L)'}])
# word_id : 9, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 10, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 11,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 11, word: kicked, lemma_init: kick, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 12, word: her, lemma_init: she, pos_tag: PRON, dep_type: obj, dep_parent_id: 11,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: U)'}])
# word_id : 13, word: repeatedly, lemma_init: repeatedly, pos_tag: ADV, dep_type: advmod, dep_parent_id: 11,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 14, word: in, lemma_init: in, pos_tag: ADP, dep_type: case, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 15, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 45, bilou_tag: B)'}])
# word_id : 16, word: shins, lemma_init: shin, pos_tag: NOUN, dep_type: obl, dep_parent_id: 11,
# entities: [{'(level: 0, coref_id: 45, bilou_tag: L)'}])
# word_id : 17, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 11,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: She, lemma_init: she, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: U)'}])
# word_id : 2, word: asked, lemma_init: ask, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 3, word: him, lemma_init: he, pos_tag: PRON, dep_type: iobj, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 4, word: to, lemma_init: to, pos_tag: PART, dep_type: mark, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 5, word: stop, lemma_init: stop, pos_tag: VERB, dep_type: xcomp, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 6, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 7, word: and, lemma_init: and, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 8, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 9, word: refused, lemma_init: refuse, pos_tag: VERB, dep_type: conj, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 10, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 11,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 11, word: giggling, lemma_init: giggle, pos_tag: VERB, dep_type: advcl, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 12, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: When, lemma_init: when, pos_tag: ADV, dep_type: advmod, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 2, word: she, lemma_init: she, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: U)'}])
# word_id : 3, word: finally, lemma_init: finally, pos_tag: ADV, dep_type: advmod, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 4, word: frowned, lemma_init: frown, pos_tag: VERB, dep_type: advcl, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 5, word: at, lemma_init: at, pos_tag: ADP, dep_type: case, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 6, word: him, lemma_init: he, pos_tag: PRON, dep_type: obl, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 7, word: and, lemma_init: and, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 8,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 8, word: threatened, lemma_init: threaten, pos_tag: VERB, dep_type: conj, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 9, word: to, lemma_init: to, pos_tag: PART, dep_type: mark, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 10, word: stop, lemma_init: stop, pos_tag: VERB, dep_type: xcomp, dep_parent_id: 8,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 11, word: playing, lemma_init: play, pos_tag: VERB, dep_type: xcomp, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 12, word: if, lemma_init: if, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 13, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 14-15, word: didn’t, lemma_init: _, pos_tag: _, dep_type: _, dep_parent_id: _,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 14, word: did, lemma_init: do, pos_tag: AUX, dep_type: aux, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 15, word: n’t, lemma_init: not, pos_tag: PART, dep_type: advmod, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 16, word: stop, lemma_init: stop, pos_tag: VERB, dep_type: advcl, dep_parent_id: 10,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 17, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 18, word: told, lemma_init: tell, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 19, word: her, lemma_init: she, pos_tag: PRON, dep_type: iobj, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: U)'}])
# word_id : 20, word: to, lemma_init: to, pos_tag: PART, dep_type: mark, dep_parent_id: 21,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 21, word: go, lemma_init: go, pos_tag: VERB, dep_type: xcomp, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 22, word: to, lemma_init: to, pos_tag: ADP, dep_type: case, dep_parent_id: 23,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 23, word: Hell, lemma_init: Hell, pos_tag: PROPN, dep_type: obl, dep_parent_id: 21,
# entities: [{'(level: 0, coref_id: 46, bilou_tag: U)'}])
# word_id : 24, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: In, lemma_init: in, pos_tag: ADP, dep_type: case, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 2-3, word: Tyler’s, lemma_init: _, pos_tag: _, dep_type: _, dep_parent_id: _,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 2, word: Tyler, lemma_init: Tyler, pos_tag: PROPN, dep_type: nmod:poss, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 47, bilou_tag: B) | (level: 1, coref_id: 1, bilou_tag: B)'}])
# word_id : 3, word: ’s, lemma_init: 's, pos_tag: PART, dep_type: case, dep_parent_id: 2,
# entities: [{'(level: 1, coref_id: 1, bilou_tag: L)'}])
# word_id : 4, word: mind, lemma_init: mind, pos_tag: NOUN, dep_type: obl, dep_parent_id: 7,
# entities: [{'(level: 0, coref_id: 47, bilou_tag: L)'}])
# word_id : 5, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 7,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 6, word: could, lemma_init: could, pos_tag: AUX, dep_type: aux, dep_parent_id: 7,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 7, word: see, lemma_init: see, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# ...
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 5, word: very, lemma_init: very, pos_tag: ADV, dep_type: advmod, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 6, word: lucky, lemma_init: lucky, pos_tag: ADJ, dep_type: ccomp, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 7, word: to, lemma_init: to, pos_tag: PART, dep_type: mark, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: B)'}])
# word_id : 8, word: have, lemma_init: have, pos_tag: AUX, dep_type: aux, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 9, word: discovered, lemma_init: discover, pos_tag: VERB, dep_type: xcomp, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 10, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: B)'}])
# word_id : 11, word: single, lemma_init: single, pos_tag: ADJ, dep_type: amod, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: I)'}])
# word_id : 12, word: error, lemma_init: error, pos_tag: NOUN, dep_type: obj, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: I)'}])
# word_id : 13, word: in, lemma_init: in, pos_tag: ADP, dep_type: case, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: I)'}])
# word_id : 14, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: I) | (level: 2, coref_id: 99, bilou_tag: B) | (level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: I) | (level: 3, coref_id: 1, bilou_tag: U)'}])
# word_id : 15, word: false, lemma_init: false, pos_tag: ADJ, dep_type: amod, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 77, bilou_tag: I) | (level: 2, coref_id: 99, bilou_tag: I)'}])
# word_id : 16, word: memory, lemma_init: memory, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 12,
# entities: [{'(level: 2, coref_id: 99, bilou_tag: L) | (level: 1, coref_id: 77, bilou_tag: L)'}])
# word_id : 17, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 19,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 18, word: which, lemma_init: which, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 19,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 19, word: enabled, lemma_init: enable, pos_tag: VERB, dep_type: advcl:relcl, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 20, word: him, lemma_init: he, pos_tag: PRON, dep_type: obj, dep_parent_id: 19,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: U)'}])
# word_id : 21, word: to, lemma_init: to, pos_tag: PART, dep_type: mark, dep_parent_id: 22,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 22, word: reason, lemma_init: reason, pos_tag: VERB, dep_type: xcomp, dep_parent_id: 19,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 23, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 24,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 1, bilou_tag: U)'}])
# word_id : 24, word: way, lemma_init: way, pos_tag: NOUN, dep_type: obj, dep_parent_id: 22,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 25, word: into, lemma_init: into, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 26,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 26, word: distinguishing, lemma_init: distinguish, pos_tag: VERB, dep_type: xcomp, dep_parent_id: 22,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 27, word: between, lemma_init: between, pos_tag: ADP, dep_type: case, dep_parent_id: 28,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 28, word: reality, lemma_init: reality, pos_tag: NOUN, dep_type: obl, dep_parent_id: 26,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 100, bilou_tag: U)'}])
# word_id : 29, word: and, lemma_init: and, pos_tag: CCONJ, dep_type: cc, dep_parent_id: 30,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 30, word: fantasy, lemma_init: fantasy, pos_tag: NOUN, dep_type: conj, dep_parent_id: 28,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I) | (level: 1, coref_id: 101, bilou_tag: U) | (level: 0, coref_id: 76, bilou_tag: L)'}])
# word_id : 31, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: He, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 2, word: felt, lemma_init: feel, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 3, word: that, lemma_init: that, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 4, word: it, lemma_init: it, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: U)'}])
# word_id : 5, word: was, lemma_init: be, pos_tag: AUX, dep_type: cop, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 6, word: a, lemma_init: a, pos_tag: DET, dep_type: det, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: B)'}])
# word_id : 7, word: coming, lemma_init: coming, pos_tag: NOUN, dep_type: compound, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 8, word: -, lemma_init: -, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 9, word: of, lemma_init: of, pos_tag: ADP, dep_type: case, dep_parent_id: 11,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 10, word: -, lemma_init: -, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 11, word: age, lemma_init: age, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 7,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: I)'}])
# word_id : 12, word: moment, lemma_init: moment, pos_tag: NOUN, dep_type: ccomp, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: L)'}])
# word_id : 13, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 2,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: Nonetheless, lemma_init: nonetheless, pos_tag: ADV, dep_type: advmod, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 2, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 1,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 3, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 4, word: admitted, lemma_init: admit, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 5, word: to, lemma_init: to, pos_tag: ADP, dep_type: case, dep_parent_id: 6,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 6, word: himself, lemma_init: himself, pos_tag: PRON, dep_type: obl, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 7, word: that, lemma_init: that, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 8, word: he, lemma_init: he, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 1, bilou_tag: U)'}])
# word_id : 9, word: was, lemma_init: be, pos_tag: AUX, dep_type: cop, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 10, word: a, lemma_init: a, pos_tag: DET, dep_type: det, dep_parent_id: 11,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 11, word: little, lemma_init: little, pos_tag: ADJ, dep_type: obl:npmod, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 12, word: sad, lemma_init: sad, pos_tag: ADJ, dep_type: ccomp, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 13, word: also, lemma_init: also, pos_tag: ADV, dep_type: advmod, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 14, word: at, lemma_init: at, pos_tag: ADP, dep_type: case, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 15, word: the, lemma_init: the, pos_tag: DET, dep_type: det, dep_parent_id: 16,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: B)'}])
# word_id : 16, word: discovery, lemma_init: discovery, pos_tag: NOUN, dep_type: obl, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 76, bilou_tag: L)'}])
# word_id : 17, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: For, lemma_init: for, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 2, word: however, lemma_init: however, pos_tag: ADV, dep_type: advmod, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 3, word: imaginary, lemma_init: imaginary, pos_tag: ADJ, dep_type: advcl, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 4, word: that, lemma_init: that, pos_tag: DET, dep_type: det, dep_parent_id: 5,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: B)'}])
# word_id : 5, word: memory, lemma_init: memory, pos_tag: NOUN, dep_type: nsubj, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: L)'}])
# word_id : 6, word: was, lemma_init: be, pos_tag: AUX, dep_type: cop, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 7, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 8, word: it, lemma_init: it, pos_tag: PRON, dep_type: nsubj, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: U)'}])
# word_id : 9, word: was, lemma_init: be, pos_tag: AUX, dep_type: cop, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 10, word: also, lemma_init: also, pos_tag: ADV, dep_type: advmod, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 11, word: a, lemma_init: a, pos_tag: DET, dep_type: det, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: B)'}])
# word_id : 12, word: part, lemma_init: part, pos_tag: NOUN, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: I)'}])
# word_id : 13, word: of, lemma_init: of, pos_tag: ADP, dep_type: case, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: I)'}])
# word_id : 14, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: B) | (level: 0, coref_id: 99, bilou_tag: I) | (level: 2, coref_id: 1, bilou_tag: U)'}])
# word_id : 15, word: love, lemma_init: love, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: I)'}])
# word_id : 16, word: for, lemma_init: for, pos_tag: ADP, dep_type: case, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: I)'}])
# word_id : 17, word: his, lemma_init: his, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: I) | (level: 2, coref_id: 2, bilou_tag: B) | (level: 0, coref_id: 99, bilou_tag: I) | (level: 1, coref_id: 26, bilou_tag: I) | (level: 3, coref_id: 1, bilou_tag: U)'}])
# word_id : 18, word: grandmother, lemma_init: grandmother, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 15,
# entities: [{'(level: 2, coref_id: 2, bilou_tag: L) | (level: 1, coref_id: 26, bilou_tag: L) | (level: 0, coref_id: 99, bilou_tag: L)'}])
# word_id : 19, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 12,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 1, word: When, lemma_init: when, pos_tag: ADV, dep_type: advmod, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 2, word: that, lemma_init: that, pos_tag: DET, dep_type: det, dep_parent_id: 3,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: B)'}])
# word_id : 3, word: memory, lemma_init: memory, pos_tag: NOUN, dep_type: nsubj, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: L)'}])
# word_id : 4, word: lost, lemma_init: lose, pos_tag: VERB, dep_type: advcl, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 5, word: its, lemma_init: its, pos_tag: PRON, dep_type: nmod:poss, dep_parent_id: 7,
# entities: [{'(level: 0, coref_id: 102, bilou_tag: B) | (level: 1, coref_id: 99, bilou_tag: U)'}])
# word_id : 6, word: compelling, lemma_init: compelling, pos_tag: ADJ, dep_type: amod, dep_parent_id: 7,
# entities: [{'(level: 0, coref_id: 102, bilou_tag: I)'}])
# word_id : 7, word: aura, lemma_init: aura, pos_tag: NOUN, dep_type: obj, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 102, bilou_tag: I)'}])
# word_id : 8, word: of, lemma_init: of, pos_tag: ADP, dep_type: case, dep_parent_id: 9,
# entities: [{'(level: 0, coref_id: 102, bilou_tag: I)'}])
# word_id : 9, word: truth, lemma_init: truth, pos_tag: NOUN, dep_type: nmod, dep_parent_id: 7,
# entities: [{'(level: 0, coref_id: 102, bilou_tag: I) | (level: 1, coref_id: 103, bilou_tag: U) | (level: 0, coref_id: 102, bilou_tag: L)'}])
# word_id : 10, word: ,, lemma_init: ,, pos_tag: PUNCT, dep_type: punct, dep_parent_id: 4,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 11, word: it, lemma_init: it, pos_tag: PRON, dep_type: nsubj:outer, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: U)'}])
# word_id : 12, word: was, lemma_init: be, pos_tag: AUX, dep_type: cop, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 13, word: like, lemma_init: like, pos_tag: SCONJ, dep_type: mark, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 14, word: another, lemma_init: another, pos_tag: DET, dep_type: det, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 15, word: part, lemma_init: part, pos_tag: NOUN, dep_type: nsubj, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 16, word: of, lemma_init: of, pos_tag: ADP, dep_type: case, dep_parent_id: 17,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 17, word: her, lemma_init: she, pos_tag: PRON, dep_type: nmod, dep_parent_id: 15,
# entities: [{'(level: 0, coref_id: 2, bilou_tag: U)'}])
# word_id : 18, word: died, lemma_init: die, pos_tag: VERB, dep_type: root, dep_parent_id: 0,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 19, word: with, lemma_init: with, pos_tag: ADP, dep_type: case, dep_parent_id: 20,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])
# word_id : 20, word: it, lemma_init: it, pos_tag: PRON, dep_type: obl, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 99, bilou_tag: U)'}])
# word_id : 21, word: ., lemma_init: ., pos_tag: PUNCT, dep_type: punct, dep_parent_id: 18,
# entities: [{'(level: 0, coref_id: 0, bilou_tag: O)'}])

# %%
text.coref_entities
# Out:
# {1: 'person',
#  2: 'person',
#  3: 'place',
#  4: 'person',
#  5: 'person',
#  6: 'abstract',
#  7: 'person',
#  8: 'abstract',
#  9: 'abstract',
#  10: 'person',
#  11: 'animal',
#  12: 'person',
#  13: 'abstract',
#  14: 'abstract',
#  15: 'abstract',
#  16: 'abstract',
#  17: 'time',
#  18: 'place',
#  19: 'event',
#  20: 'object',
#  21: 'object',
#  22: 'abstract',
#  23: 'abstract',
#  24: 'person',
#  25: 'abstract',
#  26: 'abstract',
#  27: 'time',
#  28: 'abstract',
#  29: 'abstract',
#  30: 'abstract',
#  31: 'abstract',
#  32: 'abstract',
#  33: 'abstract',
#  34: 'time',
#  35: 'event',
#  36: 'abstract',
#  37: 'event',
#  38: 'abstract',
#  39: 'person',
#  40: 'abstract',
#  41: 'object',
#  42: 'place',
#  43: 'object',
#  44: 'abstract',
#  45: 'object',
#  46: 'place',
#  47: 'abstract',
#  48: 'object',
#  49: 'abstract',
#  50: 'time',
#  51: 'abstract',
#  52: 'abstract',
#  53: 'abstract',
#  54: 'abstract',
#  55: 'abstract',
#  56: 'abstract',
#  57: 'time',
#  58: 'person',
#  59: 'place',
#  60: 'place',
#  61: 'abstract',
#  62: 'time',
#  63: 'abstract',
#  64: 'abstract',
#  65: 'abstract',
#  66: 'abstract',
#  67: 'person',
#  68: 'abstract',
#  69: 'abstract',
#  70: 'abstract',
#  71: 'object',
#  72: 'person',
#  73: 'object',
#  74: 'object',
#  75: 'place',
#  76: 'event',
#  77: 'abstract',
#  78: 'object',
#  79: 'place',
#  80: 'abstract',
#  81: 'abstract',
#  82: 'abstract',
#  83: 'place',
#  84: 'event',
#  85: 'abstract',
#  86: 'object',
#  87: 'place',
#  88: 'abstract',
#  89: 'abstract',
#  90: 'abstract',
#  91: 'abstract',
#  92: 'abstract',
#  93: 'abstract',
#  94: 'abstract',
#  95: 'abstract',
#  96: 'abstract',
#  97: 'person',
#  98: 'person',
#  99: 'abstract',
#  100: 'abstract',
#  101: 'abstract',
#  102: 'abstract',
#  103: 'abstract',
#  104: 'abstract',
#  105: 'abstract'}
